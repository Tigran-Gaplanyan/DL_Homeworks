# %% [markdown]
# # Pytorch Lightning Introduction
#
# Welcome to the introduction to [`PyTorchLightning`](https://www.pytorchlightning.ai/). PyTorch Lightning is a wrapper for PyTorch that is focused towards building neural networks model quickly by removing the boilerplate code. It also extends the functionality of PyTorch, for example, with model Callbacks and automatic porting to GPU to accelerate computations.
#
# In its essence, pytorch lightning provides a controlled setup where you are forced to in its specific partly automated library setup, but are able to customize/de-automatate each process if you so desire. You can both rely on a variety of already implemented functionalities and the fact that your code is by definition structured clearly, but at the cost of having to delve into their code structure and figuring out which functions to use.
#
# Our suggestion is to try it out. If you don't like it, you can just stick to pytorch and build up your own library of functions you will use throughout your Deep Learning journey.
#
# Let's get started by installing PyTorch Lightning.

# %% [markdown]
# ## (Optional) Mount folder in Colab
#
# Uncomment thefollowing cell to mount your gdrive if you are using the notebook in google colab:

# %%
"""
from google.colab import drive
import os

gdrive_path='/content/gdrive/MyDrive/DL_homeworks/homework_06'

# This will mount your google drive under 'MyDrive'
drive.mount('/content/gdrive', force_remount=True)
# In order to access the files in this notebook we have to navigate to the correct folder
os.chdir(gdrive_path)
# Check manually if all files are present
print(sorted(os.listdir()))
"""
# Out:
# "\nfrom google.colab import drive\nimport os\n\ngdrive_path='/content/gdrive/MyDrive/DL_homeworks/homework_06'\n\n# This will mount your google drive under 'MyDrive'\ndrive.mount('/content/gdrive', force_remount=True)\n# In order to access the files in this notebook we have to navigate to the correct folder\nos.chdir(gdrive_path)\n# Check manually if all files are present\nprint(sorted(os.listdir()))\n"

# %%
# Optional: install correct libraries in google colab
# !python -m pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 -f https://download.pytorch.org/whl/torch_stable.html
# !python -m pip install tensorboard==2.9.1

# %% [markdown]
# ### Installing Pytorch Lightning

# %%
# For automatic file reloading as usual
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys

# For google colab
# !python -m pip install pytorch-lightning==1.6.0 > /dev/null

# For anaconda/regular python
# !{sys.executable} -m pip install --ignore-installed pytorch-lightning==1.6.0
# Out:
# Collecting pytorch-lightning==1.6.0
#   Using cached pytorch_lightning-1.6.0-py3-none-any.whl (582 kB)
# Collecting numpy>=1.17.2 (from pytorch-lightning==1.6.0)
#   Using cached numpy-1.26.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (61 kB)
# Collecting torch>=1.8.* (from pytorch-lightning==1.6.0)
#   Using cached torch-2.1.0-cp310-none-macosx_11_0_arm64.whl.metadata (24 kB)
# Collecting tqdm>=4.41.0 (from pytorch-lightning==1.6.0)
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Collecting PyYAML>=5.4 (from pytorch-lightning==1.6.0)
#   Using cached PyYAML-6.0.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting fsspec!=2021.06.0,>=2021.05.0 (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0)
#   Using cached fsspec-2023.10.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting tensorboard>=2.2.0 (from pytorch-lightning==1.6.0)
#   Using cached tensorboard-2.15.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting torchmetrics>=0.4.1 (from pytorch-lightning==1.6.0)
#   Using cached torchmetrics-1.2.0-py3-none-any.whl.metadata (21 kB)
# Collecting pyDeprecate<0.4.0,>=0.3.1 (from pytorch-lightning==1.6.0)
#   Using cached pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting packaging>=17.0 (from pytorch-lightning==1.6.0)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting typing-extensions>=4.0.0 (from pytorch-lightning==1.6.0)
#   Using cached typing_extensions-4.8.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting requests (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0)
#   Using cached aiohttp-3.8.6-cp310-cp310-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting absl-py>=0.4 (from tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached grpcio-1.59.2-cp310-cp310-macosx_12_0_universal2.whl.metadata (4.0 kB)
# Collecting google-auth<3,>=1.6.3 (from tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached google_auth-2.23.4-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-auth-oauthlib<2,>=0.5 (from tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached google_auth_oauthlib-1.1.0-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached Markdown-3.5.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting protobuf<4.24,>=3.19.6 (from tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached protobuf-4.23.4-cp37-abi3-macosx_10_9_universal2.whl.metadata (540 bytes)
# Collecting setuptools>=41.0.0 (from tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached setuptools-68.2.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting six>1.9 (from tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached werkzeug-3.0.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting filelock (from torch>=1.8.*->pytorch-lightning==1.6.0)
#   Using cached filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting sympy (from torch>=1.8.*->pytorch-lightning==1.6.0)
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Collecting networkx (from torch>=1.8.*->pytorch-lightning==1.6.0)
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting jinja2 (from torch>=1.8.*->pytorch-lightning==1.6.0)
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics>=0.4.1->pytorch-lightning==1.6.0)
#   Using cached lightning_utilities-0.9.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0)
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting charset-normalizer<4.0,>=2.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (33 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0)
#   Using cached multidict-6.0.4-cp310-cp310-macosx_11_0_arm64.whl (29 kB)
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0)
#   Using cached yarl-1.9.2-cp310-cp310-macosx_11_0_arm64.whl (62 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0)
#   Using cached frozenlist-1.4.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0)
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0 (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting idna<4,>=2.5 (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0)
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0)
#   Using cached urllib3-2.0.7-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0)
#   Using cached certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting MarkupSafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached MarkupSafe-2.1.3-cp310-cp310-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Collecting mpmath>=0.19 (from sympy->torch>=1.8.*->pytorch-lightning==1.6.0)
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.2.0->pytorch-lightning==1.6.0)
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached fsspec-2023.10.0-py3-none-any.whl (166 kB)
# Using cached numpy-1.26.1-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Using cached PyYAML-6.0.1-cp310-cp310-macosx_11_0_arm64.whl (169 kB)
# Using cached tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
# Using cached torch-2.1.0-cp310-none-macosx_11_0_arm64.whl (59.5 MB)
# Using cached torchmetrics-1.2.0-py3-none-any.whl (805 kB)
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Using cached typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Using cached absl_py-2.0.0-py3-none-any.whl (130 kB)
# Using cached aiohttp-3.8.6-cp310-cp310-macosx_11_0_arm64.whl (347 kB)
# Using cached google_auth-2.23.4-py2.py3-none-any.whl (183 kB)
# Using cached google_auth_oauthlib-1.1.0-py2.py3-none-any.whl (19 kB)
# Using cached grpcio-1.59.2-cp310-cp310-macosx_12_0_universal2.whl (9.5 MB)
# Using cached lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Using cached Markdown-3.5.1-py3-none-any.whl (102 kB)
# Using cached protobuf-4.23.4-cp37-abi3-macosx_10_9_universal2.whl (400 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached setuptools-68.2.2-py3-none-any.whl (807 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached werkzeug-3.0.1-py3-none-any.whl (226 kB)
# Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-macosx_11_0_arm64.whl (120 kB)
# Using cached frozenlist-1.4.0-cp310-cp310-macosx_11_0_arm64.whl (46 kB)
# Using cached MarkupSafe-2.1.3-cp310-cp310-macosx_10_9_universal2.whl (17 kB)
# Using cached urllib3-2.0.7-py3-none-any.whl (124 kB)
# DEPRECATION: pytorch-lightning 1.6.0 has a non-standard dependency specifier torch>=1.8.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: mpmath, urllib3, typing-extensions, tqdm, tensorboard-data-server, sympy, six, setuptools, PyYAML, pyDeprecate, pyasn1, protobuf, packaging, oauthlib, numpy, networkx, multidict, MarkupSafe, markdown, idna, grpcio, fsspec, frozenlist, filelock, charset-normalizer, certifi, cachetools, attrs, async-timeout, absl-py, yarl, werkzeug, rsa, requests, pyasn1-modules, lightning-utilities, jinja2, aiosignal, torch, requests-oauthlib, google-auth, aiohttp, torchmetrics, google-auth-oauthlib, tensorboard, pytorch-lightning
# Successfully installed MarkupSafe-2.1.1 PyYAML-6.0.1 absl-py-2.0.0 aiohttp-3.8.6 aiosignal-1.3.1 async-timeout-4.0.3 attrs-23.1.0 cachetools-5.3.2 certifi-2023.7.22 charset-normalizer-3.3.2 filelock-3.13.1 frozenlist-1.4.0 fsspec-2023.10.0 google-auth-2.23.4 google-auth-oauthlib-0.4.6 grpcio-1.59.2 idna-3.4 jinja2-3.1.2 lightning-utilities-0.9.0 markdown-3.5.1 mpmath-1.3.0 multidict-6.0.4 networkx-3.2.1 numpy-1.26.0 oauthlib-3.2.2 packaging-23.1 protobuf-3.19.6 pyDeprecate-0.3.2 pyasn1-0.5.0 pyasn1-modules-0.3.0 pytorch-lightning-1.6.0 requests-2.31.0 requests-oauthlib-1.3.1 rsa-4.9 setuptools-68.0.0 six-1.16.0 sympy-1.12 tensorboard-2.15.1 tensorboard-data-server-0.6.1 torch-2.1.0 torchmetrics-1.2.0 tqdm-4.65.0 typing-extensions-4.7.1 urllib3-2.0.7 werkzeug-3.0.1 yarl-1.9.2

# %%
import pytorch_lightning as PL
print(f"Lightning version: {PL.__version__}")
if not PL.__version__.startswith("2.0"):
    print("You are using another version of pytorch lightning. We expect > pytorch lightning 2.0. You can continue with your version but it"
          " might cause dependency and compatibility issues.")

import tensorboard
import torch
import torchvision
print(f"Tensorboard version: {tensorboard.__version__}")
if not tensorboard.__version__.startswith("2.1"):
    print("You are using an another version of Tensorboard. We expect > Tensorboard 2.1 You may continue using your version but it"
          " might cause dependency and compatibility issues.")
print(f"PyTorch version Installed: {torch.__version__}\nTorchvision version Installed: {torchvision.__version__}\n")
if not torch.__version__.startswith("1.13"):
    print("you are using an another version of PyTorch. We expect > PyTorch 1.13. You may continue using your version but it"
          " might cause dependency and compatibility issues.")
if not torchvision.__version__.startswith("0.12"):
    print("you are using an another version of torchvision. We expect torchvision 0.12. You can continue with your version but it"
          " might cause dependency and compatibility issues.")
# Out:
# Lightning version: 2.1.1
# You are using another version of pytorch lightning. We expect > pytorch lightning 2.0. You can continue with your version but it might cause dependency and compatibility issues.
# Tensorboard version: 2.15.1
# PyTorch version Installed: 2.1.0
# Torchvision version Installed: 0.16.0
#
# you are using an another version of PyTorch. We expect > PyTorch 1.13. You may continue using your version but it might cause dependency and compatibility issues.
# you are using an another version of torchvision. We expect torchvision 0.12. You can continue with your version but it might cause dependency and compatibility issues.

# %% [markdown]
# # 1. Idea behind PyTorch Lightning
#
# Codes in a Deep learning project consists of three main categories:
#
# 1. **Research code**
#     This is the exciting part of the experiment where you configure the model architecture and try out different optimizers and target task. This is managed by the `LightningModule` of PyTorch Lightning.
#
# 2. **Engineering code**
#     This is the same set of code that remain the same for all deep learning projects.Recall the training block of previous notebooks where we loop through the epochs and mini-batches. The `Trainer` class of PyTorch Lightning takes care of this part of code.
#
# 3. **Non-essential code**
#     It is very important that we log our training metrics and organize different training runs to have purposeful experimentation of models. The `Callbacks` class PyTorch Lightning helps us with this section.
#
# Let's look at each of these modules in detail.
#
# 1. **LightningModules** contain all model related code. This is the part where we are working on when creating a new project. The idea is to have all important code in one module, e.g., the model's architecture and the evaluation of training and validation metrics. This provides a better overview as repeated elements, such as the training procedure, are not stored in the code that we work on. The lightning module also handles the calls `.to(device)` or `.train()` and `.eval()`. Hence, there is no need anymore to switch between the cpu and gpu and to take care of the model's mode as this is automated by the LightningModule. The framework also enables easy parallel computation on multiple gpus.
#
# 2. **Trainer** contains all code needed for training our neural networks that doesn't change for each project ("one size fits all"). Usually, we don't touch the code automated by this class. The arguments that are specific for one training such as learning rate and batch size are provided as initialization arguments for the LightningModule.
#
# 3. **Callbacks** automate all parts needed for logging hyperparameters or training results such as the tensorboard logger. Logging becomes very important for research later since the results of experiments need to be reproducible.
#
# All in all, PyTorch is a framework that handles all (annoying) "engineering" stuff for you such that you have more time for exciting research and scientific coding. This also results in the advantage that automated parts are guaranteed to be bug-free. Hence, you can't include a bug in a part of your code that is often used but not often checked.

# %% [markdown]
# # 2. Overview of the PyTorch Lightning code

# %% [markdown]
# Research relevant code goes into the `LightningModule`. The advantage is that we have all the model building, training & validation steps within a single class. These are the components that usually change based on the projects and tasks.

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1FqwrbgfMQD8Axowyq6zu3PeeNjjue4lK)

# %% [markdown]
# The remaining code is automated by the `Trainer` class which takes care of the tasks of our mechanical training loops components such as iterating through the minibatches and gradient updating steps.

# %% [markdown]
# ![alt text](https://miro.medium.com/max/700/1*b81_j__xv8M0Bb6nFTXbAA.png)

# %% [markdown]
# We could already see how much more readable and concise our code is, after being transformed by PyTorch Lightning.
#
# Let us now train a neural network model with PyTorch Lightning.

# %% [markdown]
# # 4. Training with PyTorch Lightning
#
# We will build a two-layer neural network to train on the the [`Fashion-MNIST`](https://research.zalando.com/welcome/mission/research-projects/fashion-mnist/) dataset for this notebook.
#
# ## 4.1 Define A LightningModule
#
# We define our network as an instance of `L.LightningModule` which replaces our `PyTorch` network based on the class `nn.Module`. Additionally, it contains all the relevant parts that are used for training and evaluating different models on various tasks.
#
# Let's have a look at the implementation of `TwoLayerNet` in `exercise_code.lightning_models`.

# %% [markdown]
# The `__init__()` and `forward()` function defining the forward  pass remain the same. Hence, we can just copy the code from the `nn.Module`.

# %% [markdown]
# ```python
# class TwoLayerNet(L.LightningModule):
#     def __init__(self, hparams, input_size=1 * 28 * 28, hidden_size=512, num_classes=10):
#         super().__init__()
#         self.save_hyperparameters(hparams)
#
#         self.model = nn.Sequential(
#             nn.Linear(input_size, hidden_size),
#             nn.Sigmoid(),
#             nn.Linear(hidden_size, num_classes),
#         )
#
#     def forward(self, x):
#         # flatten the image  before sending as input to the model
#         N, _, _, _ = x.shape
#         x = x.view(N, -1)
#
#         x = self.model(x)
#
#         return x
# ```

# %% [markdown]
# We will now define the training  and validation steps since they also vary with different tasks and projects. Consequently, it is useful to integrate these parts into our instance of `LightningModule`. Validation loss is returned for each validation mini-batch and averaged at the end of the epoch.

# %% [markdown]
# ```python
#     def training_step(self, batch, batch_idx):
#         images, targets = batch
#
#         # Perform a forward pass on the network with inputs
#         out = self.forward(images)
#
#         # calculate the loss with the network predictions and ground truth targets
#         loss = F.cross_entropy(out, targets)
#
#         # Find the predicted class from probabilities of the image belonging to each of the classes
#         # from the network output
#         _, preds = torch.max(out, 1)
#
#         # Calculate the accuracy of predictions
#         acc = preds.eq(targets).sum().float() / targets.size(0)
#
#         # Log the accuracy and loss values to the tensorboard
#         self.log('loss', loss)
#         self.log('acc', acc)
#
#         return {'loss': loss}
#
#     def validation_step(self, batch, batch_idx):
#         images, targets = batch
#
#         # Perform a forward pass on the network with inputs
#         out = self.forward(images)
#
#         # calculate the loss with the network predictions and ground truth targets
#         loss = F.cross_entropy(out, targets)
#
#         # Find the predicted class from probabilities of the image belonging to each of the classes
#         # from the network output
#         _, preds = torch.max(out, 1)
#
#         # Calculate the accuracy of predictions
#         acc = preds.eq(targets).sum().float() / targets.size(0)
#
#         # Visualise the predictions  of the model
#         if batch_idx == 0:
#             self.visualize_predictions(images, out.detach(), targets)
#
#         return {'val_loss': loss, 'val_acc': acc}
#
#     def validation_epoch_end(self, outputs):
#
#         # Average the loss over the entire validation data from it's mini-batches
#         avg_loss = torch.stack([x['val_loss'] for x in outputs]).mean()
#         avg_acc = torch.stack([x['val_acc'] for x in outputs]).mean()
#
#         # Log the validation accuracy and loss values to the tensorboard
#         self.log('val_loss', avg_loss)
#         self.log('val_acc', avg_acc)
# ```

# %% [markdown]
# The last step missing in our `LightningModule` is the optimizer. This method needs to be defined in every `LightningModule`.

# %% [markdown]
# ```python
#     def configure_optimizers(self):
#         optim = torch.optim.SGD(self.model.parameters(), self.hparams["learning_rate"], momentum=0.9)
#
#         return optim
# ```

# %% [markdown]
# Now that we have set up the model and the training steps, we will now establish the data pipeline. PyTorch Lightning provides the `LightningDataModule` for setting up the dataloaders.
#
# Let's have a look at the implementation of `FashionMNISTDataModule` in `exercise_code.data_class`.
#
# The `prepare_data()` function intends to set up the dataset and the related transforms for it. As previously, we download the `FashionMNIST` dataset using `torchvision` and split the total training data into a training and validation set for tuning hyperparameters.

# %% [markdown]
# ```python
# class FashionMNISTDataModule(L.LightningDataModule):
#
#     def __init__(self, batch_size=4):
#         super().__init__()
#         self.batch_size = batch_size
#
#     def prepare_data(self):
#
#         # Define the transform
#         transform = transforms.Compose([transforms.ToTensor(),
#                                         transforms.Normalize((0.5,), (0.5,))])
#
#         # Download the Fashion-MNIST dataset
#         fashion_mnist_train_val = torchvision.datasets.FashionMNIST(root='../datasets', train=True,
#                                                                    download=True, transform=transform)
#
#         self.fashion_mnist_test = torchvision.datasets.FashionMNIST(root='../datasets', train=False,
#                                                                  download=True, transform=transform)
#
#         # Apply the Transforms
#         transform = transforms.Compose([transforms.ToTensor(),
#                                         transforms.Normalize((0.5,), (0.5,))])
#
#         # Perform the training and validation split
#         self.train_dataset, self.val_dataset = random_split(
#             fashion_mnist_train_val, [50000, 10000])
# ```

# %% [markdown]
# We shall now define `Dataloaders` for each of the data-splits. These data loaders can be directly called during model training.

# %% [markdown]
# ```python
#
#     def train_dataloader(self):
#         return DataLoader(self.train_dataset, batch_size=self.batch_size)
#
#     def val_dataloader(self):
#         return DataLoader(self.val_dataset, batch_size=self.batch_size)
#
#     def test_dataloader(self):
#         return DataLoader(self.fashion_mnist_test, batch_size=self.batch_size)
#
# ```

# %% [markdown]
# You can notice now that most of the code of these steps can be directly copied from a Vanilla PyTorch code. Lightning just rearranges them. This marks the end of the research part of the code.
#
# Let's see now how the `Trainer` class works:

# %% [markdown]
# ##  4.2 Fitting the model with a Trainer

# %% [markdown]
# We will initialize the model and the data  with a set of hyperparameters given in the dictionary `hparams`.

# %%
from IPython.display import clear_output 

from exercise_code.lightning_models import TwoLayerNet
from exercise_code.data_class import FashionMNISTDataModule

hparams = {
    "batch_size": 16,
    "learning_rate": 1e-3,
    "input_size": 1 * 28 * 28,
    "hidden_size": 512,
    "num_classes": 10,
    "num_workers": 2,    # used by the dataloader, more workers means faster data preparation, but for us this is not a bottleneck here
}


model = TwoLayerNet(hparams)
data=FashionMNISTDataModule(hparams)
data.prepare_data()

# %% [markdown]
#  PyTorch Lightning provides ample flexibility for training using [`Trainer`](https://pytorch-lightning.readthedocs.io/en/latest/trainer.html) class.
# Have a look at the documentation to know more about them.
#
# Let's initialize it now.

# %%
trainer = PL.Trainer(
    max_epochs=2,
    # Uncomment to use GPU if available, if multiple you can select all indices, otherwise we use the first, -1 is CPU
    # devices="0"
)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs

# %% [markdown]
# The argument `max_epochs` sets the maximum number of epochs for training.
# The argument `weights_summary` prints a summary of the number of weights per layer at the beginning of the training. Set it to None if the summary is not required.

# %% [markdown]
# Here comes the actual training cell. The [`fit`](https://pytorch-lightning.readthedocs.io/en/latest/_modules/pytorch_lightning/trainer/trainer.html#Trainer.fit) function takes in the model and data to train the model with a lot more optional arguments for customization.

# %%
trainer = trainer.fit(model, data)
# Out:
#   | Name  | Type       | Params
# -------------------------------------
# 0 | model | Sequential | 407 K
# -------------------------------------
# 407 K     Trainable params
# 0         Non-trainable params
# 407 K     Total params
# 1.628     Total estimated model params size (MB)
# Sanity Checking: |                                        | 0/? [00:00<?, ?it/s]
# /Users/tigrangaplanyan/anaconda3/envs/Homeworks/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:436: Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# /Users/tigrangaplanyan/anaconda3/envs/Homeworks/lib/python3.10/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:436: Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Epoch 0: 100%|█████████| 3125/3125 [00:17<00:00, 175.89it/s, v_num=6, acc=0.688]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/625 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/625 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                  | 1/625 [00:00<02:23,  4.34it/s]
# Validation DataLoader 0:   0%|                  | 2/625 [00:00<01:19,  7.86it/s]
# Validation DataLoader 0:   0%|                  | 3/625 [00:00<00:57, 10.85it/s]
# Validation DataLoader 0:   1%|                  | 4/625 [00:00<00:45, 13.62it/s]
# Validation DataLoader 0:   1%|▏                 | 5/625 [00:00<00:37, 16.60it/s]
# Validation DataLoader 0:   1%|▏                 | 6/625 [00:00<00:31, 19.46it/s]
# Validation DataLoader 0:   1%|▏                 | 7/625 [00:00<00:27, 22.16it/s]
# Validation DataLoader 0:   1%|▏                 | 8/625 [00:00<00:24, 24.79it/s]
# Validation DataLoader 0:   1%|▎                 | 9/625 [00:00<00:22, 27.33it/s]
# Validation DataLoader 0:   2%|▎                | 10/625 [00:00<00:20, 29.72it/s]
# Validation DataLoader 0:   2%|▎                | 11/625 [00:00<00:19, 32.06it/s]
# Validation DataLoader 0:   2%|▎                | 12/625 [00:00<00:17, 34.28it/s]
# Validation DataLoader 0:   2%|▎                | 13/625 [00:00<00:16, 36.38it/s]
# Validation DataLoader 0:   2%|▍                | 14/625 [00:00<00:15, 38.74it/s]
# Validation DataLoader 0:   2%|▍                | 15/625 [00:00<00:14, 41.01it/s]
# Validation DataLoader 0:   3%|▍                | 16/625 [00:00<00:14, 43.31it/s]
# Validation DataLoader 0:   3%|▍                | 17/625 [00:00<00:13, 45.51it/s]
# Validation DataLoader 0:   3%|▍                | 18/625 [00:00<00:12, 47.67it/s]
# Validation DataLoader 0:   3%|▌                | 19/625 [00:00<00:12, 49.68it/s]
# Validation DataLoader 0:   3%|▌                | 20/625 [00:00<00:11, 51.73it/s]
# Validation DataLoader 0:   3%|▌                | 21/625 [00:00<00:11, 53.73it/s]
# Validation DataLoader 0:   4%|▌                | 22/625 [00:00<00:10, 55.63it/s]
# Validation DataLoader 0:   4%|▋                | 23/625 [00:00<00:10, 57.45it/s]
# Validation DataLoader 0:   4%|▋                | 24/625 [00:00<00:10, 59.22it/s]
# Validation DataLoader 0:   4%|▋                | 25/625 [00:00<00:09, 61.06it/s]
# Validation DataLoader 0:   4%|▋                | 26/625 [00:00<00:09, 62.72it/s]
# Validation DataLoader 0:   4%|▋                | 27/625 [00:00<00:09, 64.44it/s]
# Validation DataLoader 0:   4%|▊                | 28/625 [00:00<00:09, 66.18it/s]
# Validation DataLoader 0:   5%|▊                | 29/625 [00:00<00:08, 67.88it/s]
# Validation DataLoader 0:   5%|▊                | 30/625 [00:00<00:08, 69.36it/s]
# Validation DataLoader 0:   5%|▊                | 31/625 [00:00<00:08, 70.93it/s]
# Validation DataLoader 0:   5%|▊                | 32/625 [00:00<00:08, 72.58it/s]
# Validation DataLoader 0:   5%|▉                | 33/625 [00:00<00:07, 74.18it/s]
# Validation DataLoader 0:   5%|▉                | 34/625 [00:00<00:07, 75.57it/s]
# Validation DataLoader 0:   6%|▉                | 35/625 [00:00<00:07, 76.99it/s]
# Validation DataLoader 0:   6%|▉                | 36/625 [00:00<00:07, 78.56it/s]
# Validation DataLoader 0:   6%|█                | 37/625 [00:00<00:07, 80.03it/s]
# Validation DataLoader 0:   6%|█                | 38/625 [00:00<00:07, 81.44it/s]
# Validation DataLoader 0:   6%|█                | 39/625 [00:00<00:07, 82.89it/s]
# Validation DataLoader 0:   6%|█                | 40/625 [00:00<00:06, 84.37it/s]
# Validation DataLoader 0:   7%|█                | 41/625 [00:00<00:06, 85.69it/s]
# Validation DataLoader 0:   7%|█▏               | 42/625 [00:00<00:06, 86.84it/s]
# Validation DataLoader 0:   7%|█▏               | 43/625 [00:00<00:06, 88.15it/s]
# Validation DataLoader 0:   7%|█▏               | 44/625 [00:00<00:06, 89.52it/s]
# Validation DataLoader 0:   7%|█▏               | 45/625 [00:00<00:06, 90.75it/s]
# Validation DataLoader 0:   7%|█▎               | 46/625 [00:00<00:06, 91.89it/s]
# Validation DataLoader 0:   8%|█▎               | 47/625 [00:00<00:06, 93.13it/s]
# Validation DataLoader 0:   8%|█▎               | 48/625 [00:00<00:06, 94.28it/s]
# Validation DataLoader 0:   8%|█▎               | 49/625 [00:00<00:06, 95.21it/s]
# Validation DataLoader 0:   8%|█▎               | 50/625 [00:00<00:05, 96.39it/s]
# Validation DataLoader 0:   8%|█▍               | 51/625 [00:00<00:05, 97.51it/s]
# Validation DataLoader 0:   8%|█▍               | 52/625 [00:00<00:05, 98.70it/s]
# Validation DataLoader 0:   8%|█▍               | 53/625 [00:00<00:05, 99.66it/s]
# Validation DataLoader 0:   9%|█▍              | 54/625 [00:00<00:05, 100.75it/s]
# Validation DataLoader 0:   9%|█▍              | 55/625 [00:00<00:05, 101.94it/s]
# Validation DataLoader 0:   9%|█▍              | 56/625 [00:00<00:05, 103.05it/s]
# Validation DataLoader 0:   9%|█▍              | 57/625 [00:00<00:05, 103.90it/s]
# Validation DataLoader 0:   9%|█▍              | 58/625 [00:00<00:05, 104.90it/s]
# Validation DataLoader 0:   9%|█▌              | 59/625 [00:00<00:05, 105.90it/s]
# Validation DataLoader 0:  10%|█▌              | 60/625 [00:00<00:05, 106.93it/s]
# Validation DataLoader 0:  10%|█▌              | 61/625 [00:00<00:05, 107.92it/s]
# Validation DataLoader 0:  10%|█▌              | 62/625 [00:00<00:05, 108.74it/s]
# Validation DataLoader 0:  10%|█▌              | 63/625 [00:00<00:05, 109.71it/s]
# Validation DataLoader 0:  10%|█▋              | 64/625 [00:00<00:05, 110.69it/s]
# Validation DataLoader 0:  10%|█▋              | 65/625 [00:00<00:05, 111.61it/s]
# Validation DataLoader 0:  11%|█▋              | 66/625 [00:00<00:04, 112.45it/s]
# Validation DataLoader 0:  11%|█▋              | 67/625 [00:00<00:04, 113.38it/s]
# Validation DataLoader 0:  11%|█▋              | 68/625 [00:00<00:04, 114.31it/s]
# Validation DataLoader 0:  11%|█▊              | 69/625 [00:00<00:04, 115.19it/s]
# Validation DataLoader 0:  11%|█▊              | 70/625 [00:00<00:04, 116.06it/s]
# Validation DataLoader 0:  11%|█▊              | 71/625 [00:00<00:04, 116.84it/s]
# Validation DataLoader 0:  12%|█▊              | 72/625 [00:00<00:04, 117.67it/s]
# Validation DataLoader 0:  12%|█▊              | 73/625 [00:00<00:04, 118.33it/s]
# Validation DataLoader 0:  12%|█▉              | 74/625 [00:00<00:04, 119.10it/s]
# Validation DataLoader 0:  12%|█▉              | 75/625 [00:00<00:04, 119.95it/s]
# Validation DataLoader 0:  12%|█▉              | 76/625 [00:00<00:04, 120.72it/s]
# Validation DataLoader 0:  12%|█▉              | 77/625 [00:00<00:04, 121.34it/s]
# Validation DataLoader 0:  12%|█▉              | 78/625 [00:00<00:04, 122.13it/s]
# Validation DataLoader 0:  13%|██              | 79/625 [00:00<00:04, 122.90it/s]
# Validation DataLoader 0:  13%|██              | 80/625 [00:00<00:04, 123.42it/s]
# Validation DataLoader 0:  13%|██              | 81/625 [00:00<00:04, 124.01it/s]
# Validation DataLoader 0:  13%|██              | 82/625 [00:00<00:04, 124.70it/s]
# Validation DataLoader 0:  13%|██              | 83/625 [00:00<00:04, 125.47it/s]
# Validation DataLoader 0:  13%|██▏             | 84/625 [00:00<00:04, 126.09it/s]
# Validation DataLoader 0:  14%|██▏             | 85/625 [00:00<00:04, 126.63it/s]
# Validation DataLoader 0:  14%|██▏             | 86/625 [00:00<00:04, 127.30it/s]
# Validation DataLoader 0:  14%|██▏             | 87/625 [00:00<00:04, 127.98it/s]
# Validation DataLoader 0:  14%|██▎             | 88/625 [00:00<00:04, 128.53it/s]
# Validation DataLoader 0:  14%|██▎             | 89/625 [00:00<00:04, 129.13it/s]
# Validation DataLoader 0:  14%|██▎             | 90/625 [00:00<00:04, 129.90it/s]
# Validation DataLoader 0:  15%|██▎             | 91/625 [00:00<00:04, 130.52it/s]
# Validation DataLoader 0:  15%|██▎             | 92/625 [00:00<00:04, 131.19it/s]
# Validation DataLoader 0:  15%|██▍             | 93/625 [00:00<00:04, 131.85it/s]
# Validation DataLoader 0:  15%|██▍             | 94/625 [00:00<00:04, 132.63it/s]
# Validation DataLoader 0:  15%|██▍             | 95/625 [00:00<00:03, 133.31it/s]
# Validation DataLoader 0:  15%|██▍             | 96/625 [00:00<00:03, 133.86it/s]
# Validation DataLoader 0:  16%|██▍             | 97/625 [00:00<00:03, 134.37it/s]
# Validation DataLoader 0:  16%|██▌             | 98/625 [00:00<00:03, 135.02it/s]
# Validation DataLoader 0:  16%|██▌             | 99/625 [00:00<00:03, 135.65it/s]
# Validation DataLoader 0:  16%|██▍            | 100/625 [00:00<00:03, 136.18it/s]
# Validation DataLoader 0:  16%|██▍            | 101/625 [00:00<00:03, 136.74it/s]
# Validation DataLoader 0:  16%|██▍            | 102/625 [00:00<00:03, 137.42it/s]
# Validation DataLoader 0:  16%|██▍            | 103/625 [00:00<00:03, 138.00it/s]
# Validation DataLoader 0:  17%|██▍            | 104/625 [00:00<00:03, 138.56it/s]
# Validation DataLoader 0:  17%|██▌            | 105/625 [00:00<00:03, 139.07it/s]
# Validation DataLoader 0:  17%|██▌            | 106/625 [00:00<00:03, 139.71it/s]
# Validation DataLoader 0:  17%|██▌            | 107/625 [00:00<00:03, 140.35it/s]
# Validation DataLoader 0:  17%|██▌            | 108/625 [00:00<00:03, 140.90it/s]
# Validation DataLoader 0:  17%|██▌            | 109/625 [00:00<00:03, 141.26it/s]
# Validation DataLoader 0:  18%|██▋            | 110/625 [00:00<00:03, 141.80it/s]
# Validation DataLoader 0:  18%|██▋            | 111/625 [00:00<00:03, 142.36it/s]
# Validation DataLoader 0:  18%|██▋            | 112/625 [00:00<00:03, 142.84it/s]
# Validation DataLoader 0:  18%|██▋            | 113/625 [00:00<00:03, 143.33it/s]
# Validation DataLoader 0:  18%|██▋            | 114/625 [00:00<00:03, 143.93it/s]
# Validation DataLoader 0:  18%|██▊            | 115/625 [00:00<00:03, 144.48it/s]
# Validation DataLoader 0:  19%|██▊            | 116/625 [00:00<00:03, 144.99it/s]
# Validation DataLoader 0:  19%|██▊            | 117/625 [00:00<00:03, 145.44it/s]
# Validation DataLoader 0:  19%|██▊            | 118/625 [00:00<00:03, 145.94it/s]
# Validation DataLoader 0:  19%|██▊            | 119/625 [00:00<00:03, 146.44it/s]
# Validation DataLoader 0:  19%|██▉            | 120/625 [00:00<00:03, 146.88it/s]
# Validation DataLoader 0:  19%|██▉            | 121/625 [00:00<00:03, 147.28it/s]
# Validation DataLoader 0:  20%|██▉            | 122/625 [00:00<00:03, 147.83it/s]
# Validation DataLoader 0:  20%|██▉            | 123/625 [00:00<00:03, 148.31it/s]
# Validation DataLoader 0:  20%|██▉            | 124/625 [00:00<00:03, 148.78it/s]
# Validation DataLoader 0:  59%|████████▊      | 366/625 [00:01<00:01, 198.66it/s]
# Validation DataLoader 0:  59%|████████▊      | 367/625 [00:01<00:01, 198.75it/s]
# Validation DataLoader 0:  59%|████████▊      | 368/625 [00:01<00:01, 198.81it/s]
# Validation DataLoader 0:  59%|████████▊      | 369/625 [00:01<00:01, 198.92it/s]
# Validation DataLoader 0:  59%|████████▉      | 370/625 [00:01<00:01, 199.00it/s]
# Validation DataLoader 0:  59%|████████▉      | 371/625 [00:01<00:01, 199.11it/s]
# Validation DataLoader 0:  60%|████████▉      | 372/625 [00:01<00:01, 199.16it/s]
# Validation DataLoader 0:  60%|████████▉      | 373/625 [00:01<00:01, 199.28it/s]
# Validation DataLoader 0:  60%|████████▉      | 374/625 [00:01<00:01, 199.42it/s]
# Validation DataLoader 0:  60%|█████████      | 375/625 [00:01<00:01, 199.53it/s]
# Validation DataLoader 0:  60%|█████████      | 376/625 [00:01<00:01, 199.58it/s]
# Validation DataLoader 0:  60%|█████████      | 377/625 [00:01<00:01, 199.67it/s]
# Validation DataLoader 0:  60%|█████████      | 378/625 [00:01<00:01, 199.85it/s]
# Validation DataLoader 0:  61%|█████████      | 379/625 [00:01<00:01, 199.98it/s]
# Validation DataLoader 0:  61%|█████████      | 380/625 [00:01<00:01, 200.08it/s]
# Validation DataLoader 0:  61%|█████████▏     | 381/625 [00:01<00:01, 200.08it/s]
# Validation DataLoader 0:  61%|█████████▏     | 382/625 [00:01<00:01, 200.19it/s]
# Validation DataLoader 0:  61%|█████████▏     | 383/625 [00:01<00:01, 200.35it/s]
# Validation DataLoader 0:  61%|█████████▏     | 384/625 [00:01<00:01, 200.43it/s]
# Validation DataLoader 0:  62%|█████████▏     | 385/625 [00:01<00:01, 200.52it/s]
# Validation DataLoader 0:  62%|█████████▎     | 386/625 [00:01<00:01, 200.61it/s]
# Validation DataLoader 0:  62%|█████████▎     | 387/625 [00:01<00:01, 200.74it/s]
# Validation DataLoader 0:  62%|█████████▎     | 388/625 [00:01<00:01, 200.82it/s]
# Validation DataLoader 0:  62%|█████████▎     | 389/625 [00:01<00:01, 200.92it/s]
# Validation DataLoader 0:  62%|█████████▎     | 390/625 [00:01<00:01, 201.04it/s]
# Validation DataLoader 0:  63%|█████████▍     | 391/625 [00:01<00:01, 201.21it/s]
# Validation DataLoader 0:  63%|█████████▍     | 392/625 [00:01<00:01, 201.27it/s]
# Validation DataLoader 0:  63%|█████████▍     | 393/625 [00:01<00:01, 201.37it/s]
# Validation DataLoader 0:  63%|█████████▍     | 394/625 [00:01<00:01, 201.49it/s]
# Validation DataLoader 0:  63%|█████████▍     | 395/625 [00:01<00:01, 201.63it/s]
# Validation DataLoader 0:  63%|█████████▌     | 396/625 [00:01<00:01, 201.69it/s]
# Validation DataLoader 0:  64%|█████████▌     | 397/625 [00:01<00:01, 201.78it/s]
# Validation DataLoader 0:  64%|█████████▌     | 398/625 [00:01<00:01, 201.85it/s]
# Validation DataLoader 0:  64%|█████████▌     | 399/625 [00:01<00:01, 201.95it/s]
# Validation DataLoader 0:  75%|███████████▏   | 467/625 [00:02<00:00, 206.71it/s]
# Validation DataLoader 0:  75%|███████████▏   | 468/625 [00:02<00:00, 206.74it/s]
# Validation DataLoader 0:  75%|███████████▎   | 469/625 [00:02<00:00, 206.83it/s]
# Validation DataLoader 0:  75%|███████████▎   | 470/625 [00:02<00:00, 206.90it/s]
# Validation DataLoader 0:  75%|███████████▎   | 471/625 [00:02<00:00, 207.02it/s]
# Validation DataLoader 0:  76%|███████████▎   | 472/625 [00:02<00:00, 207.14it/s]
# Validation DataLoader 0:  76%|███████████▎   | 473/625 [00:02<00:00, 207.21it/s]
# Validation DataLoader 0:  76%|███████████▍   | 474/625 [00:02<00:00, 207.30it/s]
# Validation DataLoader 0:  76%|███████████▍   | 475/625 [00:02<00:00, 207.40it/s]
# Validation DataLoader 0:  76%|███████████▍   | 476/625 [00:02<00:00, 207.43it/s]
# Validation DataLoader 0:  76%|███████████▍   | 477/625 [00:02<00:00, 207.51it/s]
# Validation DataLoader 0:  76%|███████████▍   | 478/625 [00:02<00:00, 207.58it/s]
# Validation DataLoader 0:  77%|███████████▍   | 479/625 [00:02<00:00, 207.64it/s]
# Validation DataLoader 0:  77%|███████████▌   | 480/625 [00:02<00:00, 207.67it/s]
# Validation DataLoader 0:  77%|███████████▌   | 481/625 [00:02<00:00, 207.73it/s]
# Validation DataLoader 0:  77%|███████████▌   | 482/625 [00:02<00:00, 207.80it/s]
# Validation DataLoader 0:  77%|███████████▌   | 483/625 [00:02<00:00, 207.83it/s]
# Validation DataLoader 0:  77%|███████████▌   | 484/625 [00:02<00:00, 207.90it/s]
# Validation DataLoader 0:  78%|███████████▋   | 485/625 [00:02<00:00, 207.96it/s]
# Validation DataLoader 0:  78%|███████████▋   | 486/625 [00:02<00:00, 208.06it/s]
# Validation DataLoader 0:  78%|███████████▋   | 487/625 [00:02<00:00, 208.16it/s]
# Validation DataLoader 0:  78%|███████████▋   | 488/625 [00:02<00:00, 208.24it/s]
# Validation DataLoader 0:  78%|███████████▋   | 489/625 [00:02<00:00, 208.27it/s]
# Validation DataLoader 0:  78%|███████████▊   | 490/625 [00:02<00:00, 208.30it/s]
# Validation DataLoader 0:  79%|███████████▊   | 491/625 [00:02<00:00, 208.38it/s]
# Validation DataLoader 0:  79%|███████████▊   | 492/625 [00:02<00:00, 208.45it/s]
# Validation DataLoader 0:  79%|███████████▊   | 493/625 [00:02<00:00, 208.50it/s]
# Validation DataLoader 0:  79%|███████████▊   | 494/625 [00:02<00:00, 208.53it/s]
# Validation DataLoader 0:  79%|███████████▉   | 495/625 [00:02<00:00, 208.65it/s]
# Validation DataLoader 0:  79%|███████████▉   | 496/625 [00:02<00:00, 208.73it/s]
# Validation DataLoader 0:  80%|███████████▉   | 497/625 [00:02<00:00, 208.77it/s]
# Validation DataLoader 0:  80%|███████████▉   | 498/625 [00:02<00:00, 208.83it/s]
# Validation DataLoader 0:  80%|███████████▉   | 499/625 [00:02<00:00, 208.90it/s]
# Validation DataLoader 0:  80%|████████████   | 500/625 [00:02<00:00, 208.97it/s]
# Validation DataLoader 0:  80%|████████████   | 501/625 [00:02<00:00, 209.04it/s]
# Validation DataLoader 0:  80%|████████████   | 502/625 [00:02<00:00, 209.12it/s]
# Validation DataLoader 0:  80%|████████████   | 503/625 [00:02<00:00, 209.14it/s]
# Validation DataLoader 0:  81%|████████████   | 504/625 [00:02<00:00, 209.23it/s]
# Validation DataLoader 0:  81%|████████████   | 505/625 [00:02<00:00, 209.26it/s]
# Validation DataLoader 0:  81%|████████████▏  | 506/625 [00:02<00:00, 209.28it/s]
# Validation DataLoader 0:  81%|████████████▏  | 507/625 [00:02<00:00, 209.33it/s]
# Validation DataLoader 0:  81%|████████████▏  | 508/625 [00:02<00:00, 209.40it/s]
# Validation DataLoader 0:  81%|████████████▏  | 509/625 [00:02<00:00, 209.43it/s]
# Validation DataLoader 0:  82%|████████████▏  | 510/625 [00:02<00:00, 209.44it/s]
# Validation DataLoader 0:  82%|████████████▎  | 511/625 [00:02<00:00, 209.49it/s]
# Validation DataLoader 0:  82%|████████████▎  | 512/625 [00:02<00:00, 209.56it/s]
# Validation DataLoader 0:  82%|████████████▎  | 513/625 [00:02<00:00, 209.61it/s]
# Validation DataLoader 0:  82%|████████████▎  | 514/625 [00:02<00:00, 209.66it/s]
# Validation DataLoader 0:  82%|████████████▎  | 515/625 [00:02<00:00, 209.72it/s]
# Validation DataLoader 0:  83%|████████████▍  | 516/625 [00:02<00:00, 209.81it/s]
# Validation DataLoader 0:  83%|████████████▍  | 517/625 [00:02<00:00, 209.87it/s]
# Validation DataLoader 0:  83%|████████████▍  | 518/625 [00:02<00:00, 209.88it/s]
# Validation DataLoader 0:  83%|████████████▍  | 519/625 [00:02<00:00, 209.92it/s]
# Validation DataLoader 0:  83%|████████████▍  | 520/625 [00:02<00:00, 210.00it/s]
# Validation DataLoader 0:  83%|████████████▌  | 521/625 [00:02<00:00, 210.02it/s]
# Validation DataLoader 0:  84%|████████████▌  | 522/625 [00:02<00:00, 210.08it/s]
# Validation DataLoader 0:  84%|████████████▌  | 523/625 [00:02<00:00, 210.15it/s]
# Validation DataLoader 0:  84%|████████████▌  | 524/625 [00:02<00:00, 210.20it/s]
# Validation DataLoader 0:  84%|████████████▌  | 525/625 [00:02<00:00, 210.21it/s]
# Validation DataLoader 0:  84%|████████████▌  | 526/625 [00:02<00:00, 210.27it/s]
# Validation DataLoader 0:  84%|████████████▋  | 527/625 [00:02<00:00, 210.33it/s]
# Validation DataLoader 0:  84%|████████████▋  | 528/625 [00:02<00:00, 210.40it/s]
# Validation DataLoader 0:  85%|████████████▋  | 529/625 [00:02<00:00, 210.46it/s]
# Validation DataLoader 0:  85%|████████████▋  | 530/625 [00:02<00:00, 210.49it/s]
# Validation DataLoader 0:  85%|████████████▋  | 531/625 [00:02<00:00, 210.58it/s]
# Validation DataLoader 0:  85%|████████████▊  | 532/625 [00:02<00:00, 210.64it/s]
# Validation DataLoader 0:  85%|████████████▊  | 533/625 [00:02<00:00, 210.71it/s]
# Validation DataLoader 0:  85%|████████████▊  | 534/625 [00:02<00:00, 210.79it/s]
# Validation DataLoader 0:  86%|████████████▊  | 535/625 [00:02<00:00, 210.79it/s]
# Validation DataLoader 0:  86%|████████████▊  | 536/625 [00:02<00:00, 210.87it/s]
# Validation DataLoader 0:  86%|████████████▉  | 537/625 [00:02<00:00, 210.96it/s]
# Validation DataLoader 0:  86%|████████████▉  | 538/625 [00:02<00:00, 211.02it/s]
# Validation DataLoader 0:  86%|████████████▉  | 539/625 [00:02<00:00, 211.06it/s]
# Validation DataLoader 0:  86%|████████████▉  | 540/625 [00:02<00:00, 211.13it/s]
# Validation DataLoader 0:  87%|████████████▉  | 541/625 [00:02<00:00, 211.21it/s]
# Validation DataLoader 0:  87%|█████████████  | 542/625 [00:02<00:00, 211.20it/s]
# Validation DataLoader 0:  87%|█████████████  | 543/625 [00:02<00:00, 211.25it/s]
# Validation DataLoader 0:  87%|█████████████  | 544/625 [00:02<00:00, 211.28it/s]
# Validation DataLoader 0:  87%|█████████████  | 545/625 [00:02<00:00, 211.34it/s]
# Validation DataLoader 0:  87%|█████████████  | 546/625 [00:02<00:00, 211.41it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 547/625 [00:02<00:00, 211.44it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 548/625 [00:02<00:00, 211.47it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 549/625 [00:02<00:00, 211.51it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 550/625 [00:02<00:00, 211.49it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 551/625 [00:02<00:00, 211.52it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 552/625 [00:02<00:00, 211.57it/s]
# Validation DataLoader 0:  88%|█████████████▎ | 553/625 [00:02<00:00, 211.57it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 554/625 [00:02<00:00, 211.64it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 555/625 [00:02<00:00, 211.69it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 556/625 [00:02<00:00, 211.73it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 557/625 [00:02<00:00, 211.75it/s]
# Validation DataLoader 0:  89%|█████████████▍ | 558/625 [00:02<00:00, 211.79it/s]
# Validation DataLoader 0:  89%|█████████████▍ | 559/625 [00:02<00:00, 211.82it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 560/625 [00:02<00:00, 211.89it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 561/625 [00:02<00:00, 211.92it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 562/625 [00:02<00:00, 211.97it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 563/625 [00:02<00:00, 211.99it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 564/625 [00:02<00:00, 212.06it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 565/625 [00:02<00:00, 212.06it/s]
# Validation DataLoader 0:  91%|█████████████▌ | 566/625 [00:02<00:00, 212.05it/s]
# Validation DataLoader 0:  91%|█████████████▌ | 567/625 [00:02<00:00, 212.08it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 568/625 [00:02<00:00, 212.10it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 569/625 [00:02<00:00, 212.17it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 570/625 [00:02<00:00, 212.20it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 571/625 [00:02<00:00, 212.24it/s]
# Validation DataLoader 0:  92%|█████████████▋ | 572/625 [00:02<00:00, 212.29it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 573/625 [00:02<00:00, 212.26it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 574/625 [00:02<00:00, 212.28it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 575/625 [00:02<00:00, 212.34it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 576/625 [00:02<00:00, 212.39it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 577/625 [00:02<00:00, 212.37it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 578/625 [00:02<00:00, 212.36it/s]
# ...
# Validation DataLoader 0:  69%|██████████▎    | 432/625 [00:02<00:00, 201.45it/s]
# Validation DataLoader 0:  69%|██████████▍    | 433/625 [00:02<00:00, 201.48it/s]
# Validation DataLoader 0:  69%|██████████▍    | 434/625 [00:02<00:00, 201.61it/s]
# Validation DataLoader 0:  70%|██████████▍    | 435/625 [00:02<00:00, 201.66it/s]
# Validation DataLoader 0:  80%|████████████   | 503/625 [00:02<00:00, 206.86it/s]
# Validation DataLoader 0:  81%|████████████   | 504/625 [00:02<00:00, 206.96it/s]
# Validation DataLoader 0:  81%|████████████   | 505/625 [00:02<00:00, 207.01it/s]
# Validation DataLoader 0:  81%|████████████▏  | 506/625 [00:02<00:00, 207.06it/s]
# Validation DataLoader 0:  81%|████████████▏  | 507/625 [00:02<00:00, 207.11it/s]
# Validation DataLoader 0:  81%|████████████▏  | 508/625 [00:02<00:00, 207.22it/s]
# Validation DataLoader 0:  81%|████████████▏  | 509/625 [00:02<00:00, 207.31it/s]
# Validation DataLoader 0:  82%|████████████▏  | 510/625 [00:02<00:00, 207.33it/s]
# Validation DataLoader 0:  82%|████████████▎  | 511/625 [00:02<00:00, 207.39it/s]
# Validation DataLoader 0:  82%|████████████▎  | 512/625 [00:02<00:00, 207.49it/s]
# Validation DataLoader 0:  82%|████████████▎  | 513/625 [00:02<00:00, 207.52it/s]
# Validation DataLoader 0:  82%|████████████▎  | 514/625 [00:02<00:00, 207.63it/s]
# Validation DataLoader 0:  82%|████████████▎  | 515/625 [00:02<00:00, 207.71it/s]
# Validation DataLoader 0:  83%|████████████▍  | 516/625 [00:02<00:00, 207.78it/s]
# Validation DataLoader 0:  83%|████████████▍  | 517/625 [00:02<00:00, 207.86it/s]
# Validation DataLoader 0:  83%|████████████▍  | 518/625 [00:02<00:00, 207.92it/s]
# Validation DataLoader 0:  83%|████████████▍  | 519/625 [00:02<00:00, 207.95it/s]
# Validation DataLoader 0:  83%|████████████▍  | 520/625 [00:02<00:00, 207.98it/s]
# Validation DataLoader 0:  83%|████████████▌  | 521/625 [00:02<00:00, 208.07it/s]
# Validation DataLoader 0:  84%|████████████▌  | 522/625 [00:02<00:00, 208.11it/s]
# Validation DataLoader 0:  84%|████████████▌  | 523/625 [00:02<00:00, 208.13it/s]
# Validation DataLoader 0:  84%|████████████▌  | 524/625 [00:02<00:00, 208.19it/s]
# Validation DataLoader 0:  84%|████████████▌  | 525/625 [00:02<00:00, 208.28it/s]
# Validation DataLoader 0:  84%|████████████▌  | 526/625 [00:02<00:00, 208.35it/s]
# Validation DataLoader 0:  84%|████████████▋  | 527/625 [00:02<00:00, 208.42it/s]
# Validation DataLoader 0:  84%|████████████▋  | 528/625 [00:02<00:00, 208.51it/s]
# Validation DataLoader 0:  85%|████████████▋  | 529/625 [00:02<00:00, 208.59it/s]
# Validation DataLoader 0:  85%|████████████▋  | 530/625 [00:02<00:00, 208.63it/s]
# Validation DataLoader 0:  85%|████████████▋  | 531/625 [00:02<00:00, 208.66it/s]
# Validation DataLoader 0:  85%|████████████▊  | 532/625 [00:02<00:00, 208.76it/s]
# Validation DataLoader 0:  85%|████████████▊  | 533/625 [00:02<00:00, 208.83it/s]
# Validation DataLoader 0:  85%|████████████▊  | 534/625 [00:02<00:00, 208.89it/s]
# Validation DataLoader 0:  86%|████████████▊  | 535/625 [00:02<00:00, 208.93it/s]
# Validation DataLoader 0:  86%|████████████▊  | 536/625 [00:02<00:00, 208.98it/s]
# Validation DataLoader 0:  86%|████████████▉  | 537/625 [00:02<00:00, 209.06it/s]
# Validation DataLoader 0:  86%|████████████▉  | 538/625 [00:02<00:00, 209.13it/s]
# Validation DataLoader 0:  86%|████████████▉  | 539/625 [00:02<00:00, 209.15it/s]
# Validation DataLoader 0:  86%|████████████▉  | 540/625 [00:02<00:00, 209.19it/s]
# Validation DataLoader 0:  87%|████████████▉  | 541/625 [00:02<00:00, 209.27it/s]
# Validation DataLoader 0:  87%|█████████████  | 542/625 [00:02<00:00, 209.35it/s]
# Validation DataLoader 0:  87%|█████████████  | 543/625 [00:02<00:00, 209.41it/s]
# Validation DataLoader 0:  87%|█████████████  | 544/625 [00:02<00:00, 209.48it/s]
# Validation DataLoader 0:  87%|█████████████  | 545/625 [00:02<00:00, 209.56it/s]
# Validation DataLoader 0:  87%|█████████████  | 546/625 [00:02<00:00, 209.64it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 547/625 [00:02<00:00, 209.69it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 548/625 [00:02<00:00, 209.73it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 549/625 [00:02<00:00, 209.78it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 550/625 [00:02<00:00, 209.87it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 551/625 [00:02<00:00, 209.86it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 552/625 [00:02<00:00, 209.93it/s]
# Validation DataLoader 0:  88%|█████████████▎ | 553/625 [00:02<00:00, 209.98it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 554/625 [00:02<00:00, 210.06it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 555/625 [00:02<00:00, 210.06it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 556/625 [00:02<00:00, 210.14it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 557/625 [00:02<00:00, 210.17it/s]
# Validation DataLoader 0:  89%|█████████████▍ | 558/625 [00:02<00:00, 210.24it/s]
# Validation DataLoader 0:  89%|█████████████▍ | 559/625 [00:02<00:00, 210.28it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 560/625 [00:02<00:00, 210.34it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 561/625 [00:02<00:00, 210.36it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 562/625 [00:02<00:00, 210.43it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 563/625 [00:02<00:00, 210.40it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 564/625 [00:02<00:00, 210.48it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 565/625 [00:02<00:00, 210.53it/s]
# Validation DataLoader 0:  91%|█████████████▌ | 566/625 [00:02<00:00, 210.58it/s]
# Validation DataLoader 0:  91%|█████████████▌ | 567/625 [00:02<00:00, 210.58it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 568/625 [00:02<00:00, 210.63it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 569/625 [00:02<00:00, 210.72it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 570/625 [00:02<00:00, 210.80it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 571/625 [00:02<00:00, 210.81it/s]
# Validation DataLoader 0:  92%|█████████████▋ | 572/625 [00:02<00:00, 210.83it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 573/625 [00:02<00:00, 210.89it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 574/625 [00:02<00:00, 210.97it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 575/625 [00:02<00:00, 211.02it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 576/625 [00:02<00:00, 211.04it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 577/625 [00:02<00:00, 211.09it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 578/625 [00:02<00:00, 211.16it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 579/625 [00:02<00:00, 211.18it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 580/625 [00:02<00:00, 211.25it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 581/625 [00:02<00:00, 211.26it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 582/625 [00:02<00:00, 211.33it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 583/625 [00:02<00:00, 211.35it/s]
# Validation DataLoader 0:  93%|██████████████ | 584/625 [00:02<00:00, 211.42it/s]
# Validation DataLoader 0:  94%|██████████████ | 585/625 [00:02<00:00, 211.44it/s]
# Validation DataLoader 0:  94%|██████████████ | 586/625 [00:02<00:00, 211.50it/s]
# Validation DataLoader 0:  94%|██████████████ | 587/625 [00:02<00:00, 211.53it/s]
# Validation DataLoader 0:  94%|██████████████ | 588/625 [00:02<00:00, 211.58it/s]
# Validation DataLoader 0: 100%|██████████████▉| 623/625 [00:02<00:00, 213.38it/s]
# Validation DataLoader 0: 100%|██████████████▉| 624/625 [00:02<00:00, 213.48it/s]
# Validation DataLoader 0: 100%|███████████████| 625/625 [00:02<00:00, 213.53it/s]
# Epoch 1: 100%|█| 3125/3125 [00:22<00:00, 137.83it/s, v_num=6, acc=0.812, val_los
# `Trainer.fit` stopped: `max_epochs=2` reached.
# Epoch 1: 100%|█| 3125/3125 [00:22<00:00, 137.79it/s, v_num=6, acc=0.812, val_los

# %% [markdown]
# Checkout the directory `lightning_logs`. For each run there is a new directory `version_xx` created. The rightmost argument in the progress bar, the `v_num` variable above shows the version of the current run. Each directory automatically contains a folder with checkpoints, logs and the hyperparameters for this run.
#
# As seen in the last notebook, you can have a look at the  logs of the runs in the TensorBoard
# Use the command as in the previous notebook in your terminal
# ```
# tensorboard --logdir lightning_logs
# ```
# Make sure to use the above command as the same directory as `homework_06`.

# %% [markdown]
# If you are using Google Colab, run the following cell to load the TensorBoard extension within the notebook. You may have to scroll to this block whenever you need to look at the TensorBoard interface.

# %%
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs

# %% [markdown]
# ## 4.3 Add images to tensorboard

# %% [markdown]
# The tensorboard logger is a submodule of the `LightningModule` and can be accessed via `self.logger`. We can  add images  to the logging module by calling
# ```python
# self.logger.experiment.add_image('tag', image)
# ```
# to add an image.
#
#
# We will log the first batch of validation images in a grid together with the predicted class labels and the ground truth labels.
#
# ```python
#         if batch_idx == 0:
#             self.visualize_predictions(images, out.detach(), targets)
# ```
#
# Let's have a look at the implementation of `visualize_predictions()` function in `exercise_code.lightning_models`.
#
#
#
# ```python
#     def visualize_predictions(self, images, preds, targets):
#         class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
#                        'dog', 'frog', 'horse', 'ship', 'truck']
#
#         # determine size of the grid based on given batch size
#         num_rows = torch.tensor(len(images)).float().sqrt().floor()
#
#         fig = plt.figure(figsize=(10, 10))
#         for i in range(len(images)):
#             plt.subplot(num_rows ,len(images) // num_rows + 1, i+1)
#             plt.imshow(images[i].permute(1, 2, 0))
#             plt.title(class_names[torch.argmax(preds, axis=-1)[i]] + f'\n[{class_names[targets[i]]}]')
#             plt.axis('off')
#
#         self.logger.experiment.add_figure('predictions', fig, global_step=self.global_step)
# ```
#
# You can view the logged images in your `IMAGES` tab of TensorBoard.

# %% [markdown]
# We have now looked at how to train a model using PyTorch Lightning. PyTorch Lightning is very active in developement and the features set are continously expanded and updated.

# %% [markdown]
# # 4. Other Features of PyTorch Lightning
#
#
# ### Checking  training timings
#
# The argument `profiler` of the `Trainer` class measures the time taken in different steps such as dataloading, forward and backward pass. You can select a variety of loggers [here](https://pytorch-lightning.readthedocs.io/en/stable/advanced/profiler.html).
#
# Run the cell below to see for yourself.

# %%
trainer = PL.Trainer(
    profiler='simple',
    max_epochs=1,
    # gpus=1 # Use GPU if available
   
)

trainer.fit(model, data)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name  | Type       | Params
# -------------------------------------
# 0 | model | Sequential | 407 K
# -------------------------------------
# 407 K     Trainable params
# 0         Non-trainable params
# 407 K     Total params
# 1.628     Total estimated model params size (MB)
# Epoch 0: 100%|█████████| 3125/3125 [00:17<00:00, 174.85it/s, v_num=7, acc=0.812]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/625 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/625 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                  | 1/625 [00:00<02:21,  4.42it/s]
# Validation DataLoader 0:   0%|                  | 2/625 [00:00<01:23,  7.49it/s]
# Validation DataLoader 0:   0%|                  | 3/625 [00:00<01:01, 10.15it/s]
# Validation DataLoader 0:   1%|                  | 4/625 [00:00<00:47, 13.12it/s]
# Validation DataLoader 0:   1%|▏                 | 5/625 [00:00<00:38, 16.01it/s]
# Validation DataLoader 0:   1%|▏                 | 6/625 [00:00<00:33, 18.73it/s]
# Validation DataLoader 0:   1%|▏                 | 7/625 [00:00<00:28, 21.43it/s]
# Validation DataLoader 0:   1%|▏                 | 8/625 [00:00<00:25, 24.06it/s]
# Validation DataLoader 0:   1%|▎                 | 9/625 [00:00<00:23, 26.53it/s]
# Validation DataLoader 0:   2%|▎                | 10/625 [00:00<00:21, 29.01it/s]
# Validation DataLoader 0:   2%|▎                | 11/625 [00:00<00:19, 31.44it/s]
# Validation DataLoader 0:   2%|▎                | 12/625 [00:00<00:18, 33.57it/s]
# Validation DataLoader 0:   2%|▎                | 13/625 [00:00<00:17, 35.97it/s]
# Validation DataLoader 0:   2%|▍                | 14/625 [00:00<00:15, 38.31it/s]
# Validation DataLoader 0:   2%|▍                | 15/625 [00:00<00:15, 40.58it/s]
# Validation DataLoader 0:   3%|▍                | 16/625 [00:00<00:14, 42.70it/s]
# Validation DataLoader 0:   3%|▍                | 17/625 [00:00<00:13, 44.93it/s]
# Validation DataLoader 0:   3%|▍                | 18/625 [00:00<00:12, 47.11it/s]
# Validation DataLoader 0:   3%|▌                | 19/625 [00:00<00:12, 49.05it/s]
# Validation DataLoader 0:   3%|▌                | 20/625 [00:00<00:11, 51.08it/s]
# Validation DataLoader 0:   3%|▌                | 21/625 [00:00<00:11, 53.05it/s]
# Validation DataLoader 0:   4%|▌                | 22/625 [00:00<00:10, 55.02it/s]
# Validation DataLoader 0:   4%|▋                | 23/625 [00:00<00:10, 56.79it/s]
# Validation DataLoader 0:   4%|▋                | 24/625 [00:00<00:10, 58.59it/s]
# Validation DataLoader 0:   4%|▋                | 25/625 [00:00<00:09, 60.46it/s]
# Validation DataLoader 0:   4%|▋                | 26/625 [00:00<00:09, 62.30it/s]
# Validation DataLoader 0:   4%|▋                | 27/625 [00:00<00:09, 63.76it/s]
# Validation DataLoader 0:   4%|▊                | 28/625 [00:00<00:09, 65.52it/s]
# Validation DataLoader 0:   5%|▊                | 29/625 [00:00<00:08, 67.25it/s]
# Validation DataLoader 0:   5%|▊                | 30/625 [00:00<00:08, 68.87it/s]
# Validation DataLoader 0:   5%|▊                | 31/625 [00:00<00:08, 70.26it/s]
# Validation DataLoader 0:   5%|▊                | 32/625 [00:00<00:08, 71.77it/s]
# Validation DataLoader 0:   5%|▉                | 33/625 [00:00<00:08, 73.37it/s]
# Validation DataLoader 0:   5%|▉                | 34/625 [00:00<00:07, 74.61it/s]
# Validation DataLoader 0:   6%|▉                | 35/625 [00:00<00:07, 75.96it/s]
# Validation DataLoader 0:   6%|▉                | 36/625 [00:00<00:07, 77.49it/s]
# Validation DataLoader 0:   6%|█                | 37/625 [00:00<00:07, 78.97it/s]
# Validation DataLoader 0:   6%|█                | 38/625 [00:00<00:07, 80.27it/s]
# Validation DataLoader 0:   6%|█                | 39/625 [00:00<00:07, 81.53it/s]
# Validation DataLoader 0:   6%|█                | 40/625 [00:00<00:07, 82.92it/s]
# Validation DataLoader 0:   7%|█                | 41/625 [00:00<00:06, 83.97it/s]
# Validation DataLoader 0:   7%|█▏               | 42/625 [00:00<00:06, 85.11it/s]
# Validation DataLoader 0:   7%|█▏               | 43/625 [00:00<00:06, 86.46it/s]
# Validation DataLoader 0:   7%|█▏               | 44/625 [00:00<00:06, 87.69it/s]
# Validation DataLoader 0:   7%|█▏               | 45/625 [00:00<00:06, 88.78it/s]
# Validation DataLoader 0:   7%|█▎               | 46/625 [00:00<00:06, 89.93it/s]
# Validation DataLoader 0:   8%|█▎               | 47/625 [00:00<00:06, 91.22it/s]
# Validation DataLoader 0:   8%|█▎               | 48/625 [00:00<00:06, 92.24it/s]
# Validation DataLoader 0:   8%|█▎               | 49/625 [00:00<00:06, 93.30it/s]
# Validation DataLoader 0:   8%|█▎               | 50/625 [00:00<00:06, 94.45it/s]
# Validation DataLoader 0:   8%|█▍               | 51/625 [00:00<00:06, 95.60it/s]
# Validation DataLoader 0:   8%|█▍               | 52/625 [00:00<00:05, 96.34it/s]
# Validation DataLoader 0:   8%|█▍               | 53/625 [00:00<00:05, 97.47it/s]
# Validation DataLoader 0:   9%|█▍               | 54/625 [00:00<00:05, 98.60it/s]
# Validation DataLoader 0:   9%|█▍               | 55/625 [00:00<00:05, 99.67it/s]
# Validation DataLoader 0:   9%|█▍              | 56/625 [00:00<00:05, 100.47it/s]
# Validation DataLoader 0:   9%|█▍              | 57/625 [00:00<00:05, 101.49it/s]
# Validation DataLoader 0:   9%|█▍              | 58/625 [00:00<00:05, 102.53it/s]
# Validation DataLoader 0:   9%|█▌              | 59/625 [00:00<00:05, 103.48it/s]
# Validation DataLoader 0:  10%|█▌              | 60/625 [00:00<00:05, 104.60it/s]
# Validation DataLoader 0:  10%|█▌              | 61/625 [00:00<00:05, 105.73it/s]
# Validation DataLoader 0:  10%|█▌              | 62/625 [00:00<00:05, 106.89it/s]
# Validation DataLoader 0:  10%|█▌              | 63/625 [00:00<00:05, 107.97it/s]
# Validation DataLoader 0:  10%|█▋              | 64/625 [00:00<00:05, 109.03it/s]
# Validation DataLoader 0:  10%|█▋              | 65/625 [00:00<00:05, 110.17it/s]
# Validation DataLoader 0:  11%|█▋              | 66/625 [00:00<00:05, 111.21it/s]
# Validation DataLoader 0:  11%|█▋              | 67/625 [00:00<00:04, 112.21it/s]
# Validation DataLoader 0:  11%|█▋              | 68/625 [00:00<00:04, 113.18it/s]
# Validation DataLoader 0:  11%|█▊              | 69/625 [00:00<00:04, 114.11it/s]
# Validation DataLoader 0:  11%|█▊              | 70/625 [00:00<00:04, 115.00it/s]
# Validation DataLoader 0:  11%|█▊              | 71/625 [00:00<00:04, 115.70it/s]
# Validation DataLoader 0:  12%|█▊              | 72/625 [00:00<00:04, 116.33it/s]
# Validation DataLoader 0:  12%|█▊              | 73/625 [00:00<00:04, 116.94it/s]
# Validation DataLoader 0:  12%|█▉              | 74/625 [00:00<00:04, 117.67it/s]
# Validation DataLoader 0:  12%|█▉              | 75/625 [00:00<00:04, 118.38it/s]
# Validation DataLoader 0:  12%|█▉              | 76/625 [00:00<00:04, 118.91it/s]
# Validation DataLoader 0:  12%|█▉              | 77/625 [00:00<00:04, 119.58it/s]
# Validation DataLoader 0:  12%|█▉              | 78/625 [00:00<00:04, 120.32it/s]
# Validation DataLoader 0:  13%|██              | 79/625 [00:00<00:04, 121.14it/s]
# Validation DataLoader 0:  13%|██              | 80/625 [00:00<00:04, 121.59it/s]
# Validation DataLoader 0:  13%|██              | 81/625 [00:00<00:04, 122.27it/s]
# Validation DataLoader 0:  13%|██              | 82/625 [00:00<00:04, 123.07it/s]
# Validation DataLoader 0:  13%|██              | 83/625 [00:00<00:04, 123.70it/s]
# Validation DataLoader 0:  13%|██▏             | 84/625 [00:00<00:04, 124.22it/s]
# Validation DataLoader 0:  14%|██▏             | 85/625 [00:00<00:04, 124.91it/s]
# Validation DataLoader 0:  14%|██▏             | 86/625 [00:00<00:04, 125.61it/s]
# Validation DataLoader 0:  14%|██▏             | 87/625 [00:00<00:04, 126.28it/s]
# Validation DataLoader 0:  14%|██▎             | 88/625 [00:00<00:04, 126.80it/s]
# Validation DataLoader 0:  14%|██▎             | 89/625 [00:00<00:04, 127.43it/s]
# Validation DataLoader 0:  14%|██▎             | 90/625 [00:00<00:04, 128.02it/s]
# Validation DataLoader 0:  15%|██▎             | 91/625 [00:00<00:04, 128.46it/s]
# Validation DataLoader 0:  15%|██▎             | 92/625 [00:00<00:04, 129.14it/s]
# Validation DataLoader 0:  15%|██▍             | 93/625 [00:00<00:04, 129.78it/s]
# Validation DataLoader 0:  15%|██▍             | 94/625 [00:00<00:04, 130.28it/s]
# Validation DataLoader 0:  15%|██▍             | 95/625 [00:00<00:04, 130.80it/s]
# Validation DataLoader 0:  15%|██▍             | 96/625 [00:00<00:04, 131.43it/s]
# Validation DataLoader 0:  16%|██▍             | 97/625 [00:00<00:03, 132.14it/s]
# Validation DataLoader 0:  16%|██▌             | 98/625 [00:00<00:03, 132.53it/s]
# Validation DataLoader 0:  16%|██▌             | 99/625 [00:00<00:03, 133.20it/s]
# Validation DataLoader 0:  16%|██▍            | 100/625 [00:00<00:03, 133.91it/s]
# Validation DataLoader 0:  16%|██▍            | 101/625 [00:00<00:03, 134.56it/s]
# Validation DataLoader 0:  16%|██▍            | 102/625 [00:00<00:03, 134.90it/s]
# Validation DataLoader 0:  16%|██▍            | 103/625 [00:00<00:03, 135.46it/s]
# Validation DataLoader 0:  55%|████████▎      | 346/625 [00:01<00:01, 190.91it/s]
# Validation DataLoader 0:  56%|████████▎      | 347/625 [00:01<00:01, 191.06it/s]
# Validation DataLoader 0:  56%|████████▎      | 348/625 [00:01<00:01, 191.16it/s]
# Validation DataLoader 0:  56%|████████▍      | 349/625 [00:01<00:01, 191.12it/s]
# Validation DataLoader 0:  56%|████████▍      | 350/625 [00:01<00:01, 191.26it/s]
# Validation DataLoader 0:  56%|████████▍      | 351/625 [00:01<00:01, 191.32it/s]
# Validation DataLoader 0:  56%|████████▍      | 352/625 [00:01<00:01, 191.34it/s]
# Validation DataLoader 0:  56%|████████▍      | 353/625 [00:01<00:01, 191.42it/s]
# Validation DataLoader 0:  57%|████████▍      | 354/625 [00:01<00:01, 191.55it/s]
# Validation DataLoader 0:  57%|████████▌      | 355/625 [00:01<00:01, 191.51it/s]
# Validation DataLoader 0:  57%|████████▌      | 356/625 [00:01<00:01, 191.60it/s]
# Validation DataLoader 0:  57%|████████▌      | 357/625 [00:01<00:01, 191.71it/s]
# Validation DataLoader 0:  57%|████████▌      | 358/625 [00:01<00:01, 191.88it/s]
# Validation DataLoader 0:  57%|████████▌      | 359/625 [00:01<00:01, 191.89it/s]
# Validation DataLoader 0:  58%|████████▋      | 360/625 [00:01<00:01, 191.95it/s]
# Validation DataLoader 0:  58%|████████▋      | 361/625 [00:01<00:01, 192.02it/s]
# Validation DataLoader 0:  58%|████████▋      | 362/625 [00:01<00:01, 192.11it/s]
# Validation DataLoader 0:  58%|████████▋      | 363/625 [00:01<00:01, 192.17it/s]
# Validation DataLoader 0:  58%|████████▋      | 364/625 [00:01<00:01, 192.28it/s]
# Validation DataLoader 0:  58%|████████▊      | 365/625 [00:01<00:01, 192.39it/s]
# Validation DataLoader 0:  59%|████████▊      | 366/625 [00:01<00:01, 192.53it/s]
# Validation DataLoader 0:  59%|████████▊      | 367/625 [00:01<00:01, 192.61it/s]
# Validation DataLoader 0:  59%|████████▊      | 368/625 [00:01<00:01, 192.70it/s]
# Validation DataLoader 0:  59%|████████▊      | 369/625 [00:01<00:01, 192.77it/s]
# Validation DataLoader 0:  59%|████████▉      | 370/625 [00:01<00:01, 192.88it/s]
# Validation DataLoader 0:  59%|████████▉      | 371/625 [00:01<00:01, 192.93it/s]
# Validation DataLoader 0:  60%|████████▉      | 372/625 [00:01<00:01, 193.01it/s]
# Validation DataLoader 0:  60%|████████▉      | 373/625 [00:01<00:01, 193.12it/s]
# Validation DataLoader 0:  60%|████████▉      | 374/625 [00:01<00:01, 193.25it/s]
# Validation DataLoader 0:  60%|█████████      | 375/625 [00:01<00:01, 193.27it/s]
# Validation DataLoader 0:  60%|█████████      | 376/625 [00:01<00:01, 193.35it/s]
# Validation DataLoader 0:  60%|█████████      | 377/625 [00:01<00:01, 193.47it/s]
# Validation DataLoader 0:  60%|█████████      | 378/625 [00:01<00:01, 193.59it/s]
# Validation DataLoader 0:  61%|█████████      | 379/625 [00:01<00:01, 193.64it/s]
# Validation DataLoader 0:  61%|█████████      | 380/625 [00:01<00:01, 193.76it/s]
# Validation DataLoader 0:  61%|█████████▏     | 381/625 [00:01<00:01, 193.89it/s]
# Validation DataLoader 0:  61%|█████████▏     | 382/625 [00:01<00:01, 193.93it/s]
# Validation DataLoader 0:  61%|█████████▏     | 383/625 [00:01<00:01, 194.03it/s]
# Validation DataLoader 0:  61%|█████████▏     | 384/625 [00:01<00:01, 194.12it/s]
# Validation DataLoader 0:  62%|█████████▏     | 385/625 [00:01<00:01, 194.26it/s]
# Validation DataLoader 0:  62%|█████████▎     | 386/625 [00:01<00:01, 194.36it/s]
# Validation DataLoader 0:  62%|█████████▎     | 387/625 [00:01<00:01, 194.48it/s]
# Validation DataLoader 0:  62%|█████████▎     | 388/625 [00:01<00:01, 194.54it/s]
# Validation DataLoader 0:  62%|█████████▎     | 389/625 [00:01<00:01, 194.69it/s]
# Validation DataLoader 0:  62%|█████████▎     | 390/625 [00:02<00:01, 194.74it/s]
# Validation DataLoader 0:  63%|█████████▍     | 391/625 [00:02<00:01, 194.86it/s]
# Validation DataLoader 0:  63%|█████████▍     | 392/625 [00:02<00:01, 194.94it/s]
# Validation DataLoader 0:  63%|█████████▍     | 393/625 [00:02<00:01, 195.07it/s]
# Validation DataLoader 0:  63%|█████████▍     | 394/625 [00:02<00:01, 195.11it/s]
# Validation DataLoader 0:  63%|█████████▍     | 395/625 [00:02<00:01, 195.17it/s]
# Validation DataLoader 0:  63%|█████████▌     | 396/625 [00:02<00:01, 195.28it/s]
# Validation DataLoader 0:  64%|█████████▌     | 397/625 [00:02<00:01, 195.41it/s]
# Validation DataLoader 0:  64%|█████████▌     | 398/625 [00:02<00:01, 195.52it/s]
# Validation DataLoader 0:  64%|█████████▌     | 399/625 [00:02<00:01, 195.58it/s]
# Validation DataLoader 0:  64%|█████████▌     | 400/625 [00:02<00:01, 195.61it/s]
# Validation DataLoader 0:  64%|█████████▌     | 401/625 [00:02<00:01, 195.75it/s]
# Validation DataLoader 0:  64%|█████████▋     | 402/625 [00:02<00:01, 195.83it/s]
# Validation DataLoader 0:  64%|█████████▋     | 403/625 [00:02<00:01, 195.92it/s]
# Validation DataLoader 0:  65%|█████████▋     | 404/625 [00:02<00:01, 196.00it/s]
# Validation DataLoader 0:  65%|█████████▋     | 405/625 [00:02<00:01, 196.16it/s]
# Validation DataLoader 0:  65%|█████████▋     | 406/625 [00:02<00:01, 196.24it/s]
# Validation DataLoader 0:  65%|█████████▊     | 407/625 [00:02<00:01, 196.33it/s]
# Validation DataLoader 0:  65%|█████████▊     | 408/625 [00:02<00:01, 196.35it/s]
# Validation DataLoader 0:  65%|█████████▊     | 409/625 [00:02<00:01, 196.47it/s]
# Validation DataLoader 0:  66%|█████████▊     | 410/625 [00:02<00:01, 196.51it/s]
# Validation DataLoader 0:  66%|█████████▊     | 411/625 [00:02<00:01, 196.59it/s]
# Validation DataLoader 0:  66%|█████████▉     | 412/625 [00:02<00:01, 196.67it/s]
# Validation DataLoader 0:  77%|███████████▌   | 480/625 [00:02<00:00, 198.56it/s]
# Validation DataLoader 0:  77%|███████████▌   | 481/625 [00:02<00:00, 198.59it/s]
# Validation DataLoader 0:  77%|███████████▌   | 482/625 [00:02<00:00, 198.64it/s]
# Validation DataLoader 0:  77%|███████████▌   | 483/625 [00:02<00:00, 198.70it/s]
# Validation DataLoader 0:  77%|███████████▌   | 484/625 [00:02<00:00, 198.77it/s]
# Validation DataLoader 0:  78%|███████████▋   | 485/625 [00:02<00:00, 198.80it/s]
# Validation DataLoader 0:  78%|███████████▋   | 486/625 [00:02<00:00, 198.90it/s]
# Validation DataLoader 0:  78%|███████████▋   | 487/625 [00:02<00:00, 198.99it/s]
# Validation DataLoader 0:  78%|███████████▋   | 488/625 [00:02<00:00, 199.06it/s]
# Validation DataLoader 0:  78%|███████████▋   | 489/625 [00:02<00:00, 199.09it/s]
# Validation DataLoader 0:  78%|███████████▊   | 490/625 [00:02<00:00, 199.13it/s]
# Validation DataLoader 0:  79%|███████████▊   | 491/625 [00:02<00:00, 199.18it/s]
# Validation DataLoader 0:  79%|███████████▊   | 492/625 [00:02<00:00, 199.16it/s]
# Validation DataLoader 0:  79%|███████████▊   | 493/625 [00:02<00:00, 199.16it/s]
# Validation DataLoader 0:  79%|███████████▊   | 494/625 [00:02<00:00, 199.17it/s]
# Validation DataLoader 0:  79%|███████████▉   | 495/625 [00:02<00:00, 199.25it/s]
# Validation DataLoader 0:  79%|███████████▉   | 496/625 [00:02<00:00, 199.23it/s]
# Validation DataLoader 0:  80%|███████████▉   | 497/625 [00:02<00:00, 199.23it/s]
# Validation DataLoader 0:  80%|███████████▉   | 498/625 [00:02<00:00, 199.28it/s]
# Validation DataLoader 0:  80%|███████████▉   | 499/625 [00:02<00:00, 199.25it/s]
# Validation DataLoader 0:  80%|████████████   | 500/625 [00:02<00:00, 199.20it/s]
# Validation DataLoader 0:  80%|████████████   | 501/625 [00:02<00:00, 199.22it/s]
# Validation DataLoader 0:  80%|████████████   | 502/625 [00:02<00:00, 199.18it/s]
# Validation DataLoader 0:  80%|████████████   | 503/625 [00:02<00:00, 199.13it/s]
# Validation DataLoader 0:  81%|████████████   | 504/625 [00:02<00:00, 199.17it/s]
# Validation DataLoader 0:  81%|████████████   | 505/625 [00:02<00:00, 199.25it/s]
# Validation DataLoader 0:  81%|████████████▏  | 506/625 [00:02<00:00, 199.20it/s]
# Validation DataLoader 0:  81%|████████████▏  | 507/625 [00:02<00:00, 199.16it/s]
# Validation DataLoader 0:  81%|████████████▏  | 508/625 [00:02<00:00, 199.24it/s]
# Validation DataLoader 0:  81%|████████████▏  | 509/625 [00:02<00:00, 199.20it/s]
# Validation DataLoader 0:  82%|████████████▏  | 510/625 [00:02<00:00, 199.27it/s]
# Validation DataLoader 0:  82%|████████████▎  | 511/625 [00:02<00:00, 199.31it/s]
# Validation DataLoader 0:  82%|████████████▎  | 512/625 [00:02<00:00, 199.41it/s]
# Validation DataLoader 0:  82%|████████████▎  | 513/625 [00:02<00:00, 199.39it/s]
# Validation DataLoader 0:  82%|████████████▎  | 514/625 [00:02<00:00, 199.39it/s]
# Validation DataLoader 0:  82%|████████████▎  | 515/625 [00:02<00:00, 199.44it/s]
# Validation DataLoader 0:  83%|████████████▍  | 516/625 [00:02<00:00, 199.36it/s]
# Validation DataLoader 0:  83%|████████████▍  | 517/625 [00:02<00:00, 199.42it/s]
# Validation DataLoader 0:  83%|████████████▍  | 518/625 [00:02<00:00, 199.48it/s]
# Validation DataLoader 0:  83%|████████████▍  | 519/625 [00:02<00:00, 199.54it/s]
# Validation DataLoader 0:  83%|████████████▍  | 520/625 [00:02<00:00, 199.56it/s]
# Validation DataLoader 0:  83%|████████████▌  | 521/625 [00:02<00:00, 199.65it/s]
# Validation DataLoader 0:  84%|████████████▌  | 522/625 [00:02<00:00, 199.74it/s]
# Validation DataLoader 0:  84%|████████████▌  | 523/625 [00:02<00:00, 199.83it/s]
# Validation DataLoader 0:  84%|████████████▌  | 524/625 [00:02<00:00, 199.84it/s]
# Validation DataLoader 0:  84%|████████████▌  | 525/625 [00:02<00:00, 199.85it/s]
# Validation DataLoader 0:  84%|████████████▌  | 526/625 [00:02<00:00, 199.92it/s]
# Validation DataLoader 0:  84%|████████████▋  | 527/625 [00:02<00:00, 200.01it/s]
# Validation DataLoader 0:  84%|████████████▋  | 528/625 [00:02<00:00, 200.02it/s]
# Validation DataLoader 0:  85%|████████████▋  | 529/625 [00:02<00:00, 200.01it/s]
# Validation DataLoader 0:  85%|████████████▋  | 530/625 [00:02<00:00, 200.09it/s]
# Validation DataLoader 0:  85%|████████████▋  | 531/625 [00:02<00:00, 200.11it/s]
# Validation DataLoader 0:  85%|████████████▊  | 532/625 [00:02<00:00, 200.17it/s]
# Validation DataLoader 0:  85%|████████████▊  | 533/625 [00:02<00:00, 200.24it/s]
# Validation DataLoader 0:  85%|████████████▊  | 534/625 [00:02<00:00, 200.31it/s]
# Validation DataLoader 0:  86%|████████████▊  | 535/625 [00:02<00:00, 200.31it/s]
# Validation DataLoader 0:  86%|████████████▊  | 536/625 [00:02<00:00, 200.40it/s]
# Validation DataLoader 0:  86%|████████████▉  | 537/625 [00:02<00:00, 200.47it/s]
# Validation DataLoader 0:  86%|████████████▉  | 538/625 [00:02<00:00, 200.55it/s]
# Validation DataLoader 0:  86%|████████████▉  | 539/625 [00:02<00:00, 200.57it/s]
# Validation DataLoader 0:  86%|████████████▉  | 540/625 [00:02<00:00, 200.64it/s]
# Validation DataLoader 0:  87%|████████████▉  | 541/625 [00:02<00:00, 200.70it/s]
# Validation DataLoader 0:  87%|█████████████  | 542/625 [00:02<00:00, 200.77it/s]
# Validation DataLoader 0:  87%|█████████████  | 543/625 [00:02<00:00, 200.82it/s]
# Validation DataLoader 0:  87%|█████████████  | 544/625 [00:02<00:00, 200.89it/s]
# Validation DataLoader 0:  87%|█████████████  | 545/625 [00:02<00:00, 200.97it/s]
# Validation DataLoader 0:  87%|█████████████  | 546/625 [00:02<00:00, 201.07it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 547/625 [00:02<00:00, 201.06it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 548/625 [00:02<00:00, 201.11it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 549/625 [00:02<00:00, 201.16it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 550/625 [00:02<00:00, 201.26it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 551/625 [00:02<00:00, 201.26it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 552/625 [00:02<00:00, 201.31it/s]
# Validation DataLoader 0:  88%|█████████████▎ | 553/625 [00:02<00:00, 201.38it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 554/625 [00:02<00:00, 201.50it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 555/625 [00:02<00:00, 201.57it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 556/625 [00:02<00:00, 201.54it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 557/625 [00:02<00:00, 201.58it/s]
# Validation DataLoader 0:  89%|█████████████▍ | 558/625 [00:02<00:00, 201.65it/s]
# Validation DataLoader 0:  89%|█████████████▍ | 559/625 [00:02<00:00, 201.73it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 560/625 [00:02<00:00, 201.75it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 561/625 [00:02<00:00, 201.83it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 562/625 [00:02<00:00, 201.90it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 563/625 [00:02<00:00, 201.90it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 564/625 [00:02<00:00, 201.94it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 565/625 [00:02<00:00, 201.99it/s]
# Validation DataLoader 0:  91%|█████████████▌ | 566/625 [00:02<00:00, 202.07it/s]
# Validation DataLoader 0:  91%|█████████████▌ | 567/625 [00:02<00:00, 202.08it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 568/625 [00:02<00:00, 202.10it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 569/625 [00:02<00:00, 202.14it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 570/625 [00:02<00:00, 202.20it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 571/625 [00:02<00:00, 202.23it/s]
# Validation DataLoader 0:  92%|█████████████▋ | 572/625 [00:02<00:00, 202.27it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 573/625 [00:02<00:00, 202.39it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 574/625 [00:02<00:00, 202.48it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 575/625 [00:02<00:00, 202.46it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 576/625 [00:02<00:00, 202.51it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 577/625 [00:02<00:00, 202.56it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 578/625 [00:02<00:00, 202.57it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 579/625 [00:02<00:00, 202.61it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 580/625 [00:02<00:00, 202.69it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 581/625 [00:02<00:00, 202.69it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 582/625 [00:02<00:00, 202.70it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 583/625 [00:02<00:00, 202.74it/s]
# ...
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                   	|  0.00027983     	|  1              	|  0.00027983     	|  0.001173       	|
# |  [LightningDataModule]FashionMNISTDataModule.train_dataloader                                                                                                   	|  0.00016729     	|  1              	|  0.00016729     	|  0.00070125     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup                    	|  0.00013575     	|  1              	|  0.00013575     	|  0.00056904     	|
# |  [LightningDataModule]FashionMNISTDataModule.val_dataloader                                                                                                     	|  0.00012696     	|  1              	|  0.00012696     	|  0.00053218     	|
# |  [LightningModule]TwoLayerNet.on_validation_model_eval                                                                                                          	|  5.7354e-05     	|  2              	|  0.00011471     	|  0.00048083     	|
# |  [LightningModule]TwoLayerNet.configure_optimizers                                                                                                              	|  9.925e-05      	|  1              	|  9.925e-05      	|  0.00041604     	|
# |  [LightningModule]TwoLayerNet.on_validation_model_train                                                                                                         	|  3.0938e-05     	|  2              	|  6.1876e-05     	|  0.00025937     	|
# |  [LightningModule]TwoLayerNet.on_validation_model_zero_grad                                                                                                     	|  2.9167e-05     	|  1              	|  2.9167e-05     	|  0.00012226     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_end        	|  1.4521e-05     	|  2              	|  2.9042e-05     	|  0.00012174     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                  	|  5.708e-06      	|  1              	|  5.708e-06      	|  2.3927e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_start           	|  4.625e-06      	|  1              	|  4.625e-06      	|  1.9387e-05     	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                     	|  2.2705e-06     	|  2              	|  4.541e-06      	|  1.9035e-05     	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                       	|  2.146e-06      	|  2              	|  4.292e-06      	|  1.7991e-05     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                	|  3.875e-06      	|  1              	|  3.875e-06      	|  1.6243e-05     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                           	|  3.5e-06        	|  1              	|  3.5e-06        	|  1.4671e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                             	|  1.541e-06      	|  2              	|  3.082e-06      	|  1.2919e-05     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                  	|  2.666e-06      	|  1              	|  2.666e-06      	|  1.1175e-05     	|
# |  [LightningModule]TwoLayerNet.on_train_start                                                                                                                    	|  2.625e-06      	|  1              	|  2.625e-06      	|  1.1003e-05     	|
# |  [LightningDataModule]FashionMNISTDataModule.setup                                                                                                              	|  2.292e-06      	|  1              	|  2.292e-06      	|  9.6076e-06     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                              	|  1.0625e-06     	|  2              	|  2.125e-06      	|  8.9076e-06     	|
# |  [LightningModule]TwoLayerNet.configure_callbacks                                                                                                               	|  2.083e-06      	|  1              	|  2.083e-06      	|  8.7315e-06     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                   	|  1.75e-06       	|  1              	|  1.75e-06       	|  7.3356e-06     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                            	|  8.13e-07       	|  2              	|  1.626e-06      	|  6.8158e-06     	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                          	|  1.583e-06      	|  1              	|  1.583e-06      	|  6.6356e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                   	|  1.541e-06      	|  1              	|  1.541e-06      	|  6.4596e-06     	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                            	|  1.541e-06      	|  1              	|  1.541e-06      	|  6.4595e-06     	|
# |  [LightningModule]TwoLayerNet.on_validation_end                                                                                                                 	|  7.29e-07       	|  2              	|  1.458e-06      	|  6.1116e-06     	|
# |  [Callback]ModelSummary.setup                                                                                                                                   	|  1.417e-06      	|  1              	|  1.417e-06      	|  5.9398e-06     	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                      	|  1.375e-06      	|  1              	|  1.375e-06      	|  5.7637e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_start      	|  6.67e-07       	|  2              	|  1.334e-06      	|  5.5919e-06     	|
# |  [LightningModule]TwoLayerNet.prepare_data                                                                                                                      	|  1.333e-06      	|  1              	|  1.333e-06      	|  5.5877e-06     	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                    	|  1.333e-06      	|  1              	|  1.333e-06      	|  5.5877e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                               	|  6.665e-07      	|  2              	|  1.333e-06      	|  5.5876e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                         	|  1.292e-06      	|  1              	|  1.292e-06      	|  5.4158e-06     	|
# |  [LightningDataModule]FashionMNISTDataModule.state_dict                                                                                                         	|  1.25e-06       	|  1              	|  1.25e-06       	|  5.2398e-06     	|
# |  [LightningModule]TwoLayerNet.on_validation_start                                                                                                               	|  6.25e-07       	|  2              	|  1.25e-06       	|  5.2397e-06     	|
# |  [LightningModule]TwoLayerNet.on_validation_epoch_end                                                                                                           	|  5.83e-07       	|  2              	|  1.166e-06      	|  4.8876e-06     	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                 	|  5.625e-07      	|  2              	|  1.125e-06      	|  4.7158e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_start             	|  1.083e-06      	|  1              	|  1.083e-06      	|  4.5397e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_start	|  5.415e-07      	|  2              	|  1.083e-06      	|  4.5397e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_end  	|  5.415e-07      	|  2              	|  1.083e-06      	|  4.5397e-06     	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                               	|  5e-07          	|  2              	|  1e-06          	|  4.1918e-06     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                             	|  1e-06          	|  1              	|  1e-06          	|  4.1918e-06     	|
# |  [LightningDataModule]FashionMNISTDataModule.teardown                                                                                                           	|  9.58e-07       	|  1              	|  9.58e-07       	|  4.0158e-06     	|
# |  [LightningModule]TwoLayerNet.on_validation_epoch_start                                                                                                         	|  4.375e-07      	|  2              	|  8.7501e-07     	|  3.6678e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                     	|  8.33e-07       	|  1              	|  8.33e-07       	|  3.4918e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_save_checkpoint       	|  8.33e-07       	|  1              	|  8.33e-07       	|  3.4918e-06     	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                              	|  7.09e-07       	|  1              	|  7.09e-07       	|  2.972e-06      	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                      	|  7.08e-07       	|  1              	|  7.08e-07       	|  2.9678e-06     	|
# |  [LightningModule]TwoLayerNet.on_train_end                                                                                                                      	|  7.0799e-07     	|  1              	|  7.0799e-07     	|  2.9678e-06     	|
# |  [LightningModule]TwoLayerNet.on_train_epoch_start                                                                                                              	|  6.66e-07       	|  1              	|  6.66e-07       	|  2.7918e-06     	|
# |  [LightningModule]TwoLayerNet.on_fit_end                                                                                                                        	|  6.66e-07       	|  1              	|  6.66e-07       	|  2.7917e-06     	|
# |  [LightningModule]TwoLayerNet.setup                                                                                                                             	|  5.84e-07       	|  1              	|  5.84e-07       	|  2.448e-06      	|
# |  [LightningModule]TwoLayerNet.on_fit_start                                                                                                                      	|  5.84e-07       	|  1              	|  5.84e-07       	|  2.448e-06      	|
# |  [LightningModule]TwoLayerNet.on_train_epoch_end                                                                                                                	|  5.84e-07       	|  1              	|  5.84e-07       	|  2.448e-06      	|
# |  [Callback]ModelSummary.teardown                                                                                                                                	|  5.84e-07       	|  1              	|  5.84e-07       	|  2.448e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_start    	|  5.83e-07       	|  1              	|  5.83e-07       	|  2.4438e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_start     	|  5.83e-07       	|  1              	|  5.83e-07       	|  2.4438e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown                 	|  5.83e-07       	|  1              	|  5.83e-07       	|  2.4438e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                    	|  5.41e-07       	|  1              	|  5.41e-07       	|  2.2678e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_end             	|  5e-07          	|  1              	|  5e-07          	|  2.0959e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_end               	|  5e-07          	|  1              	|  5e-07          	|  2.0959e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_end      	|  5e-07          	|  1              	|  5e-07          	|  2.0959e-06     	|
# |  [LightningModule]TwoLayerNet.on_save_checkpoint                                                                                                                	|  3.75e-07       	|  1              	|  3.75e-07       	|  1.5719e-06     	|
# |  [LightningModule]TwoLayerNet.teardown                                                                                                                          	|  3.75e-07       	|  1              	|  3.75e-07       	|  1.5719e-06     	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# We can see an overview of the time taken for different steps.
# This  enables us to detect bottlenecks in the model more easily. A bottleneck can be, for example, long times in dataloading. It becomes very important later, especially, when you start to implement custom layers or loss functions.

# %% [markdown]
# ### Some more debugging Options
#
# * [`fast_dev_run`](https://pytorch-lightning.readthedocs.io/en/latest/trainer.html#fast-dev-run): Runs of batch of each train, validation and test pass (if validation and test datalaoders are passed as arguments).This is a fast way to check if everything works (dataloading, validation metric, model saving/ loading) without having to wait for a full epoch.
#
# * [`track_grad_norm`](https://pytorch-lightning.readthedocs.io/en/latest/trainer.html#track-grad-norm): Logs the  norm of the gradients (set to `1` for the $L1$ norm or `2` for the $L2$ norm) for each layer. You can check whether the network is actually doing something. If the gradients are too small or too high, you won't have a good training (due to vanishing/ exploding gradients).
#
#
# ### Other Features
#
# Finally, we want to mention some other useful options in the Trainer class:
#
# * [`resume_from_checkpoint`](https://pytorch-lightning.readthedocs.io/en/latest/trainer.html#resume-from-checkpoint): Start the training from a checkpoint saved earlier. Argument is the path to the saved model file.
# * [`Callbacks`](https://pytorch-lightning.readthedocs.io/en/latest/callbacks.html#callback): Callbacks are extremely useful system during training that automate non essential code such as  storing model checkpoints , saving weights values among others.
#
# Let's have the look at the [`EarlyStopping`](https://pytorch-lightning.readthedocs.io/en/latest/early_stopping.html#early-stopping-based-on-metric-using-the-earlystopping-callback)  callback.
#
# It interrupts the training if the `monitor` metric variable does not  improve for `patience` number of epochs.
#
# Below is a code example on how to apply it.
#
# ```python
# from lightning.callbacks.early_stopping import EarlyStopping
#
# early_stop_callback = EarlyStopping(
#    monitor='val_accuracy',
#    patience=3,
#    verbose=False,
#    mode='max'
# )
#
# trainer = Trainer(max_epochs=10,callbacks=[early_stop_callback])
# ```
#
# Pytorch lightning will force you to check out a bunch of callbacks to return the desired functions without having to write the respective code yourself.

# %% [markdown]
# ## References
#
# 1. PyTorch Lightining [`Source Code`](https://github.com/PyTorchLightning/pytorch-lightning) with a nice introduction
# 2. PyTorch Lightining [`Documentation`](https://pytorch-lightning.readthedocs.io/en/latest/#)  Explore it, the features are very well explained.
# 3. The creator's [`Blogpost`](https://towardsdatascience.com/from-pytorch-to-pytorch-lightning-a-gentle-introduction-b371b7caaf09) It is a gentle introduction From PyTorch to PyTorch Lightning.
