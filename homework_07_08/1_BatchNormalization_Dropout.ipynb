# %% [markdown]
# # Batch Normalization & Dropout
#
# In this Notebook we will implement Batch Normalization and Dropout and discuss how both these methods help in Neural Network training.
#
# By completing this exercise you will:
# 1. Know the implementation details of Batch Norm and Dropout
# 2. Notice the difference in behaviour during train and test time
# 3. Use Batch Norm and Dropout in a Fully Connected Layer to see how it affects training
#
# Let us start with Batch Normalization:

# %% [markdown]
# # 1. Batch Normalization
#
# ## 1.1 What is Batch Normalization
# One way to make deep networks easier to train is to use more sophisticated optimization procedures such as SGD+momentum, RMSProp, or Adam. Another strategy is to change the architecture of the network to make it easier to train. One idea along these lines is batch normalization which was proposed by [1].
#
# The idea is relatively straightforward. Machine learning methods tend to work better when their input data consists of uncorrelated features with zero mean and unit variance. When training a neural network, we can preprocess the data before feeding it to the network to explicitly decorrelate its features; this will ensure that the first layer of the network sees data that follows a nice distribution. However even if we preprocess the input data, the activations at deeper layers of the network will likely no longer be decorrelated and will no longer have zero mean or unit variance since they are output from earlier layers in the network. Even worse, during the training process the distribution of features at each layer of the network will shift as the weights of each layer are updated.
#
# The authors of [1] hypothesize that the shifting distribution of features inside deep neural networks may make training deep networks more difficult. To overcome this problem, [1] proposes to insert batch normalization layers into the network. At training time, a batch normalization layer uses a minibatch of data to estimate the mean and standard deviation of each feature. These estimated means and standard deviations are then used to center and normalize the features of the minibatch. A running average of these means and standard deviations is kept during training, and at test time these running averages are used to center and normalize features.
#
# It is possible that this normalization strategy could reduce the representational power of the network, since it may sometimes be optimal for certain layers to have features that are not zero-mean or unit variance. To this end, the batch normalization layer includes learnable shift and scale parameters for each feature dimension.
#
# [1] Sergey Ioffe and Christian Szegedy, "Batch Normalization: Accelerating Deep Network Training by Reducing
# Internal Covariate Shift", ICML 2015.

# %% [markdown]
# ### Before We Start
#
# It is important that we take a look at the Mathematical formula behind Batch Norm. Please make sure to understand the formula below since this will definitely help you with the implementation later.

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1TJ4_jbyQRPinXmYDqN1mRK9_Vtjt68WI)

# %% [markdown]
# ### A quick explanation of the formula
# Let's summarize the mathematics here: In the left column, we are given the input data, which consists (as always) of $N$ samples of dimension $D$. Furthermore, we need the learnable shift and scale parameters which we call $\beta$ and $\gamma$. The intermediates are describing the mean $\mu$ and variance $\sigma$ that we need to compute from the input data and then $\hat{x}$ which is the normalized input data. The output is given by $y$ which is the combination of the normalized data with the learnable parameters.
#
# The right column contains the mathematical formulations and can be summarized as follows:
# 1. For the given input x, we calculate the mean $\mu$ across all input samples.
# 2. Based on the mean $\mu$, we compute the variances $\sigma$ of each value in the sample.
# 3. We then normalize the input data based on the computed mean and variance.
# 4. Finally, we combine the normalized data with the learnable parameters $\gamma$ and $\beta$.
#
# Please remember that Batch Normalization behaves differently at training and test time. In the figure above, we see the behaviour at training time.

# %% [markdown]
# ## (Optional) Mount folder in Colab
#
# Uncomment thefollowing cell to mount your gdrive if you are using the notebook in google colab:

# %%
# Use the following lines if you want to use Google Colab
# Don't forget to change to GPU. Runtime --> Change runtime type --> GPU
# NOTE: terminate all other colab sessions that use GPU!
# NOTE 2: Make sure the correct exercise folder (e.g homework_07) is given.
# NOTE 3: For simplicity, create a folder "DL_homeworks" within your main drive folder, and put the exercise there.

"""
import os
import pickle

import os
from google.colab import drive

def mount_gdrive(gdrive_path='/content/gdrive/MyDrive/DL_homeworks/homework_07'):
    # This will mount your google drive under 'MyDrive'
    drive.mount('/content/gdrive', force_remount=True)
    # In order to access the files in this notebook we have to navigate to the correct folder
    os.chdir(gdrive_path)
    # Let's test the setup by simply checking if all paths are present
    present = True
    necessary_paths= ['exercise_code']
    files = os.listdir()
    for path in necessary_paths:
        if path not in files:
            present = False
    if not present:
        print("Can't find all required folders. You either installed the notebook in the wrong path or didn't upload the full exercise folder. You can check your paths in the file overview on the left.")
    else:
        print('Google colab setup complete! Mounted folders:')
        print(files)

# Specify your gdrive path here. If you simply created a 'DL_homeworks' folder in the main directory that is the correct path
mount_gdrive('/content/gdrive/MyDrive/DL_homeworks/homework_07')

# Relevant packages. NOTE: Be patient, it will take a few minutes.
# !python -m pip install  tensorboard==2.8.0 pytorch-lightning==1.6.0 torchtext
"""

# %% [markdown]
# ## 1.2 Batch Normalization: Implementation

# %%
# As usual, a bit of setup

import time
import numpy as np
import matplotlib.pyplot as plt
from exercise_code.layers import *
from exercise_code.tests import *
import torch.nn as nn
import torch
import torchvision
import torchvision.transforms as transforms
import pytorch_lightning as pl
import os
import shutil
from pytorch_lightning.loggers import TensorBoardLogger

from exercise_code.networks.BatchNormModel import SimpleNetwork, BatchNormNetwork, DropoutNetwork

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# supress cluttering warnings in solutions
import warnings
warnings.filterwarnings('ignore')

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# ### Batch normalization: Forward Pass
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>In the file <code>exercise_code/layers.py </code>, we have implemented the <code>batchnorm_forward</code> function. Read this implementation and make sure you understand what batch normalization is doing. Then execute the following cells to test the implementation.
#  </p>
# </div>

# %%
# Check the training-time forward pass by checking means and variances
# of features both before and after batch normalization

# Simulate the forward pass for a two-layer network
N, D1, D2, D3 = 200, 50, 60, 3
X = np.random.randn(N, D1)
W1 = np.random.randn(D1, D2)
W2 = np.random.randn(D2, D3)
a = np.maximum(0, X.dot(W1)).dot(W2)

print('Before batch normalization:')
print('  means: ', a.mean(axis=0))
print('  stds: ', a.std(axis=0), '\n')

# Means should be close to zero and stds close to one
print('After batch normalization with (gamma=1, beta=0)')
a_norm, _ = batchnorm_forward(a, np.ones(D3), np.zeros(D3), {'mode': 'train'})
print('  mean: ', a_norm.mean(axis=0))
print('  std: ', a_norm.std(axis=0) , '\n')

# Now means should be close to beta and stds close to gamma
gamma = np.asarray([1.0, 2.0, 3.0])
beta = np.asarray([11.0, 12.0, 13.0])
a_norm, _ = batchnorm_forward(a, gamma, beta, {'mode': 'train'})
print('After batch normalization with (nontrivial gamma, beta)')
print('  means: ', a_norm.mean(axis=0))
print('  stds: ', a_norm.std(axis=0) )
# Out:
# Before batch normalization:
#   means:  [ 8.59292588 27.92306639 -8.51749491]
#   stds:  [35.68115257 26.10258544 35.24304226]
#
# After batch normalization with (gamma=1, beta=0)
#   mean:  [ 2.39253062e-16 -9.69224700e-16  4.01068068e-17]
#   std:  [1.         0.99999999 1.        ]
#
# After batch normalization with (nontrivial gamma, beta)
#   means:  [11. 12. 13.]
#   stds:  [1.         1.99999999 2.99999999]

# %% [markdown]
# Since the mean and variances in batch norm are computed in training time,
# before invoking the test-time forward pass run the training-time
# forward pass (previous cell) many times to warm up the running averages. Then
# checking the means and variances of activations for a test-time
# forward pass.

# %%
# Check the test-time forward pass by checking means and variances 
# of features after batch normalization

N, D1, D2, D3 = 200, 50, 60, 3
W1 = np.random.randn(D1, D2)
W2 = np.random.randn(D2, D3)

bn_param = {'mode': 'train'}
gamma = np.ones(D3)
beta = np.zeros(D3)
for t in range(50):
    X = np.random.randn(N, D1)
    a = np.maximum(0, X.dot(W1)).dot(W2)
    batchnorm_forward(a, gamma, beta, bn_param)
bn_param['mode'] = 'test'
X = np.random.randn(N, D1)
a = np.maximum(0, X.dot(W1)).dot(W2)
a_norm, _ = batchnorm_forward(a, gamma, beta, bn_param)

# Means should be close to zero and stds close to one, but will be
# noisier than training-time forward passes.
print('After batch normalization (test-time):')
print('  means: ', a_norm.mean(axis=0))
print('  stds: ', a_norm.std(axis=0))
# Out:
# After batch normalization (test-time):
#   means:  [-0.00860989  0.12967537 -0.0052237 ]
#   stds:  [1.01008661 0.99859765 0.97590471]

# %% [markdown]
# ### Batch Normalization: Backward Pass
# Since batch normalization is realized by a more complex function of learnable parameters, it is a good exercise to train your backprop skills through this computational graph.
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p>Open <code>exercise_code/layer.py</code> and implement the backward pass for Batch Normalization in the function <code> batchnorm_backward() </code>.
#     </p>
#     <p> To derive the backward pass you should write out the computation graph for batch normalization and backprop through each of the intermediate nodes. Some intermediates may have multiple outgoing branches; make sure to sum gradients across these branches in the backward pass. You can stay close to the forward pass implementation we have provided for you, i.e. go line by line backward.
#     </p>
#     <p> Once you have finished, run the following to numerically check your backward pass.
#     </p>
# </div>

# %%
# Gradient check batchnorm backward pass

N, D = 4, 5
x = 5 * np.random.randn(N, D) + 12
gamma = np.random.randn(D)
beta = np.random.randn(D)
dout = np.random.randn(N, D)

bn_param = {'mode': 'train'}

fx = lambda x: batchnorm_forward(x, gamma, beta, bn_param)[0]
fg = lambda a: batchnorm_forward(x, gamma, beta, bn_param)[0]
fb = lambda b: batchnorm_forward(x, gamma, beta, bn_param)[0]

dx_num = eval_numerical_gradient_array(fx, x, dout)
da_num = eval_numerical_gradient_array(fg, gamma, dout)
db_num = eval_numerical_gradient_array(fb, beta, dout)

_, cache = batchnorm_forward(x, gamma, beta, bn_param)
dx, dgamma, dbeta = batchnorm_backward(dout, cache)

print('dx error: ', rel_error(dx_num, dx))
print('dgamma error: ', rel_error(da_num, dgamma))
print('dbeta error: ', rel_error(db_num, dbeta))
# Out:
# dx error:  1.0593391199640983e-09
# dgamma error:  1.421916445020242e-10
# dbeta error:  5.475049990632359e-12

# %% [markdown]
# ## 1.3 Using Batch Normalization with PyTorch Lightning
#
# Now that we have seen the implementation of Batch Normalization, it is interesting to see how it would affect the overall Model Performance. Since you have already worked with PyTorch Lightning in the last exercise, you have seen how easy it makes our lives. As an experiment, we will use a simple Fully Connected Network in PyTorch Lightning here.

# %% [markdown]
# ### Setup TensorBoard
# In homework_06 you've already learned how to use TensorBoard. Let's use it again to make the debugging of our network and training process more convenient. Throughout this notebook, feel free to add further logs or visualizations to your TensorBoard.

# %%
# Few Hyperparameters before we start things off
hidden_dim = 200
batch_size = 50

logdir = './batch_norm_logs'
if os.path.exists(logdir):
    # We delete the logs on the first run
    shutil.rmtree(logdir)
os.mkdir(logdir)

epochs = 5
learning_rate = 0.00005

# %%
# %load_ext tensorboard
# !/Users/tigrangaplanyan/anaconda3/envs/Homeworks/bin/tensorboard --logdir batch_norm_logs
# Out:
# TensorFlow installation not found - running with reduced feature set.
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.9.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# ### Train a model without Batch Normalization.
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>Let us first start with a simple network which does not make use of Batch Normalization. We have already implemented the a simple network <code>SimpleNetwork</code> in <code>exercise_code/BatchNormModel.py</code>. Feel free to check it out and play around with the parameters. The cell below is setting up a short trainings process for this network.
#  </p>
# </div>

# %%
# train
model = SimpleNetwork(hidden_dim=hidden_dim, batch_size=batch_size, learning_rate=learning_rate)
# Creating a logging object
simple_network_logger = TensorBoardLogger(
    save_dir=logdir,
    name='simple_network'
)
trainer = pl.Trainer(max_epochs=epochs, logger=simple_network_logger)

trainer.fit(model)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: ./batch_norm_logs/simple_network
#
#   | Name  | Type       | Params
# -------------------------------------
# 0 | model | Sequential | 159 K
# -------------------------------------
# 159 K     Trainable params
# 0         Non-trainable params
# 159 K     Total params
# 0.636     Total estimated model params size (MB)
# Sanity Checking DataLoader 0: 100%|███████████████| 2/2 [00:00<00:00, 46.84it/s]Val-Acc=0.0010000000474974513
# Epoch 0: 100%|██████████████████████| 960/960 [00:08<00:00, 115.57it/s, v_num=0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/240 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/240 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                 | 1/240 [00:00<00
/s]
# Validation DataLoader 0:  48%|███████▏       | 115/240 [00:00<00:00, 164.92it/s]
# Validation DataLoader 0:  48%|███████▎       | 116/240 [00:00<00:00, 164.98it/s]
# Validation DataLoader 0:  49%|███████▎       | 117/240 [00:00<00:00, 164.89it/s]
# Validation DataLoader 0:  49%|███████▍       | 118/240 [00:00<00:00, 165.02it/s]
# Validation DataLoader 0:  50%|███████▍       | 119/240 [00:00<00:00, 164.86it/s]
# Validation DataLoader 0:  50%|███████▌       | 120/240 [00:00<00:00, 164.81it/s]
# Validation DataLoader 0:  50%|███████▌       | 121/240 [00:00<00:00, 164.77it/s]
# Validation DataLoader 0:  51%|███████▋       | 122/240 [00:00<00:00, 164.80it/s]
# Validation DataLoader 0:  51%|███████▋       | 123/240 [00:00<00:00, 164.91it/s]
# Validation DataLoader 0:  52%|███████▊       | 124/240 [00:00<00:00, 164.85it/s]
# Validation DataLoader 0:  52%|███████▊       | 125/240 [00:00<00:00, 164.88it/s]
# Validation DataLoader 0:  52%|███████▉       | 126/240 [00:00<00:00, 164.90it/s]
# Validation DataLoader 0:  53%|███████▉       | 127/240 [00:00<00:00, 164.98it/s]
# Validation DataLoader 0:  53%|████████       | 128/240 [00:00<00:00, 164.85it/s]
# Validation DataLoader 0:  54%|████████       | 129/240 [00:00<00:00, 164.95it/s]
# Validation DataLoader 0:  54%|████████▏      | 130/240 [00:00<00:00, 164.97it/s]
# Validation DataLoader 0:  55%|████████▏      | 131/240 [00:00<00:00, 164.90it/s]
# Validation DataLoader 0:  55%|████████▎      | 132/240 [00:00<00:00, 164.95it/s]
# Validation DataLoader 0:  55%|████████▎      | 133/240 [00:00<00:00, 164.88it/s]
# Validation DataLoader 0:  56%|████████▍      | 134/240 [00:00<00:00, 164.91it/s]
# Validation DataLoader 0:  56%|████████▍      | 135/240 [00:00<00:00, 164.97it/s]
# Validation DataLoader 0:  57%|████████▌      | 136/240 [00:00<00:00, 165.06it/s]
# Validation DataLoader 0:  57%|████████▌      | 137/240 [00:00<00:00, 165.05it/s]
# Validation DataLoader 0:  57%|████████▋      | 138/240 [00:00<00:00, 165.07it/s]
# Validation DataLoader 0:  58%|████████▋      | 139/240 [00:00<00:00, 164.99it/s]
# Validation DataLoader 0:  58%|████████▊      | 140/240 [00:00<00:00, 165.06it/s]
# Validation DataLoader 0:  59%|████████▊      | 141/240 [00:00<00:00, 165.01it/s]
# Validation DataLoader 0:  59%|████████▉      | 142/240 [00:00<00:00, 164.97it/s]
# Validation DataLoader 0:  60%|████████▉      | 143/240 [00:00<00:00, 164.97it/s]
# Validation DataLoader 0:  60%|█████████      | 144/240 [00:00<00:00, 164.94it/s]
# Validation DataLoader 0:  60%|█████████      | 145/240 [00:00<00:00, 164.88it/s]
# Validation DataLoader 0:  61%|█████████▏     | 146/240 [00:00<00:00, 164.87it/s]
# Validation DataLoader 0:  61%|█████████▏     | 147/240 [00:00<00:00, 164.99it/s]
# Validation DataLoader 0:  62%|█████████▎     | 148/240 [00:00<00:00, 165.09it/s]
# Validation DataLoader 0:  62%|█████████▎     | 149/240 [00:00<00:00, 165.10it/s]
# Validation DataLoader 0:  62%|█████████▍     | 150/240 [00:00<00:00, 165.14it/s]
# Validation DataLoader 0:  63%|█████████▍     | 151/240 [00:00<00:00, 165.14it/s]
# Validation DataLoader 0:  63%|█████████▌     | 152/240 [00:00<00:00, 164.98it/s]
# Validation DataLoader 0:  64%|█████████▌     | 153/240 [00:00<00:00, 165.00it/s]
# Validation DataLoader 0:  64%|█████████▋     | 154/240 [00:00<00:00, 165.03it/s]
# Validation DataLoader 0:  65%|█████████▋     | 155/240 [00:00<00:00, 164.96it/s]
# Validation DataLoader 0:  65%|█████████▊     | 156/240 [00:00<00:00, 164.87it/s]
# Validation DataLoader 0:  65%|█████████▊     | 157/240 [00:00<00:00, 164.97it/s]
# Validation DataLoader 0:  66%|█████████▉     | 158/240 [00:00<00:00, 164.96it/s]
# Validation DataLoader 0:  66%|█████████▉     | 159/240 [00:00<00:00, 164.94it/s]
# Validation DataLoader 0:  67%|██████████     | 160/240 [00:00<00:00, 165.04it/s]
# Validation DataLoader 0:  67%|██████████     | 161/240 [00:00<00:00, 165.07it/s]
# Validation DataLoader 0:  68%|██████████▏    | 162/240 [00:00<00:00, 165.10it/s]
# Validation DataLoader 0:  68%|██████████▏    | 163/240 [00:00<00:00, 165.18it/s]
# Validation DataLoader 0:  68%|██████████▎    | 164/240 [00:00<00:00, 165.08it/s]
# Validation DataLoader 0:  69%|██████████▎    | 165/240 [00:00<00:00, 165.07it/s]
# Validation DataLoader 0:  69%|██████████▍    | 166/240 [00:01<00:00, 164.99it/s]
# Validation DataLoader 0:  70%|██████████▍    | 167/240 [00:01<00:00, 164.97it/s]
# Validation DataLoader 0:  70%|██████████▌    | 168/240 [00:01<00:00, 165.02it/s]
# Validation DataLoader 0:  70%|██████████▌    | 169/240 [00:01<00:00, 164.97it/s]
# Validation DataLoader 0:  71%|██████████▋    | 170/240 [00:01<00:00, 165.00it/s]
# Validation DataLoader 0:  71%|██████████▋    | 171/240 [00:01<00:00, 165.06it/s]
# Validation DataLoader 0:  72%|██████████▊    | 172/240 [00:01<00:00, 165.09it/s]
# Validation DataLoader 0:  72%|██████████▊    | 173/240 [00:01<00:00, 165.08it/s]
# Validation DataLoader 0:  72%|██████████▉    | 174/240 [00:01<00:00, 165.16it/s]
# Validation DataLoader 0:  73%|██████████▉    | 175/240 [00:01<00:00, 165.16it/s]
# Validation DataLoader 0:  73%|███████████    | 176/240 [00:01<00:00, 165.17it/s]
# Validation DataLoader 0:  74%|███████████    | 177/240 [00:01<00:00, 165.19it/s]
# Validation DataLoader 0:  74%|███████████▏   | 178/240 [00:01<00:00, 165.13it/s]
# Validation DataLoader 0:  75%|███████████▏   | 179/240 [00:01<00:00, 165.14it/s]
# Validation DataLoader 0:  75%|███████████▎   | 180/240 [00:01<00:00, 165.17it/s]
# Validation DataLoader 0:  75%|███████████▎   | 181/240 [00:01<00:00, 165.06it/s]
# Validation DataLoader 0:  76%|███████████▍   | 182/240 [00:01<00:00, 165.09it/s]
# Validation DataLoader 0:  76%|███████████▍   | 183/240 [00:01<00:00, 165.09it/s]
# Validation DataLoader 0:  77%|███████████▌   | 184/240 [00:01<00:00, 165.08it/s]
# Validation DataLoader 0:  77%|███████████▌   | 185/240 [00:01<00:00, 165.00it/s]
# Validation DataLoader 0:  78%|███████████▋   | 186/240 [00:01<00:00, 165.06it/s]
# Validation DataLoader 0:  78%|███████████▋   | 187/240 [00:01<00:00, 165.03it/s]
# Validation DataLoader 0:  78%|███████████▊   | 188/240 [00:01<00:00, 164.96it/s]
# Validation DataLoader 0:  79%|███████████▊   | 189/240 [00:01<00:00, 164.91it/s]
# Validation DataLoader 0:  79%|███████████▉   | 190/240 [00:01<00:00, 164.90it/s]
# Validation DataLoader 0:  80%|███████████▉   | 191/240 [00:01<00:00, 164.94it/s]
# Validation DataLoader 0:  80%|████████████   | 192/240 [00:01<00:00, 164.91it/s]
# Validation DataLoader 0:  80%|████████████   | 193/240 [00:01<00:00, 164.90it/s]
# Validation DataLoader 0:  81%|████████████▏  | 194/240 [00:01<00:00, 164.97it/s]
# Validation DataLoader 0:  81%|████████████▏  | 195/240 [00:01<00:00, 165.06it/s]
# Validation DataLoader 0:  82%|████████████▎  | 196/240 [00:01<00:00, 165.12it/s]
# Validation DataLoader 0:  82%|████████████▎  | 197/240 [00:01<00:00, 165.20it/s]
# Validation DataLoader 0:  82%|████████████▍  | 198/240 [00:01<00:00, 165.19it/s]
# Validation DataLoader 0:  83%|████████████▍  | 199/240 [00:01<00:00, 165.17it/s]
# Validation DataLoader 0:  83%|████████████▌  | 200/240 [00:01<00:00, 165.17it/s]
# Validation DataLoader 0:  84%|████████████▌  | 201/240 [00:01<00:00, 165.21it/s]
# Validation DataLoader 0:  84%|████████████▋  | 202/240 [00:01<00:00, 165.30it/s]
# Validation DataLoader 0:  85%|████████████▋  | 203/240 [00:01<00:00, 165.35it/s]
# Validation DataLoader 0:  85%|████████████▊  | 204/240 [00:01<00:00, 165.39it/s]
# Validation DataLoader 0:  85%|████████████▊  | 205/240 [00:01<00:00, 165.49it/s]
# Validation DataLoader 0:  86%|████████████▉  | 206/240 [00:01<00:00, 165.60it/s]
# Validation DataLoader 0:  86%|████████████▉  | 207/240 [00:01<00:00, 165.54it/s]
# Validation DataLoader 0:  87%|█████████████  | 208/240 [00:01<00:00, 165.42it/s]
# Validation DataLoader 0:  87%|█████████████  | 209/240 [00:01<00:00, 165.38it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 210/240 [00:01<00:00, 165.39it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 211/240 [00:01<00:00, 165.42it/s]
# Validation DataLoader 0:  88%|█████████████▎ | 212/240 [00:01<00:00, 165.43it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 213/240 [00:01<00:00, 165.45it/s]
# Validation DataLoader 0:  89%|█████████████▍ | 214/240 [00:01<00:00, 165.46it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 215/240 [00:01<00:00, 165.40it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 216/240 [00:01<00:00, 165.35it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 217/240 [00:01<00:00, 165.29it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 218/240 [00:01<00:00, 165.30it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 219/240 [00:01<00:00, 165.34it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 220/240 [00:01<00:00, 165.27it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 221/240 [00:01<00:00, 165.23it/s]
# Validation DataLoader 0:  92%|█████████████▉ | 222/240 [00:01<00:00, 165.22it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 223/240 [00:01<00:00, 165.18it/s]
# Validation DataLoader 0:  93%|██████████████ | 224/240 [00:01<00:00, 165.18it/s]
# Validation DataLoader 0:  94%|██████████████ | 225/240 [00:01<00:00, 165.09it/s]
# Validation DataLoader 0:  94%|██████████████▏| 226/240 [00:01<00:00, 165.15it/s]
# Validation DataLoader 0:  95%|██████████████▏| 227/240 [00:01<00:00, 165.10it/s]
# Validation DataLoader 0:  95%|██████████████▎| 228/240 [00:01<00:00, 165.11it/s]
# Validation DataLoader 0:  95%|██████████████▎| 229/240 [00:01<00:00, 165.14it/s]
# Validation DataLoader 0:  96%|██████████████▍| 230/240 [00:01<00:00, 165.16it/s]
# Validation DataLoader 0:  96%|██████████████▍| 231/240 [00:01<00:00, 165.10it/s]
# Validation DataLoader 0:  97%|██████████████▌| 232/240 [00:01<00:00, 165.14it/s]
# Validation DataLoader 0:  97%|██████████████▌| 233/240 [00:01<00:00, 165.09it/s]
# Validation DataLoader 0:  98%|██████████████▋| 234/240 [00:01<00:00, 165.09it/s]
# Validation DataLoader 0:  98%|██████████████▋| 235/240 [00:01<00:00, 165.03it/s]
# Validation DataLoader 0:  98%|██████████████▊| 236/240 [00:01<00:00, 165.01it/s]
# Validation DataLoader 0:  99%|██████████████▊| 237/240 [00:01<00:00, 165.04it/s]
# Validation DataLoader 0:  99%|██████████████▉| 238/240 [00:01<00:00, 164.99it/s]
# Validation DataLoader 0: 100%|██████████████▉| 239/240 [00:01<00:00, 165.03it/s]
# Validation DataLoader 0: 100%|███████████████| 240/240 [00:01<00:00, 165.04it/s]Val-Acc=4.038166522979736
#
# Epoch 4: 100%|█| 960/960 [00:09<00:00, 98.06it/s, v_num=0, val/loss=0.565, val/a
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|█| 960/960 [00:09<00:00, 97.98it/s, v_num=0, val/loss=0.565, val/a

# %% [markdown]
# ### Train a model incl. Batch Normalization
#
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p> Now that we have already seen how our simple network should work, let us look at a model that is actually using Batch Normalization. Again, we provide you with such a model <code>BatchNormNetwork</code> in <code>exercise_code/BatchNormModel.py</code>. Same as before: Feel free to check it out and play around with the parameters. The cell below is setting up a short trainings process for this model.
#  </p>
# </div>

# %%
model = BatchNormNetwork(hidden_dim=hidden_dim, batch_size=batch_size, learning_rate=learning_rate)
batch_norm_network_logger = TensorBoardLogger(
    save_dir=logdir,
    name='batch_norm_network'
)
trainer = pl.Trainer(max_epochs=epochs, logger=batch_norm_network_logger)
trainer.fit(model)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: ./batch_norm_logs/batch_norm_network
#
#   | Name  | Type       | Params
# -------------------------------------
# 0 | model | Sequential | 159 K
# -------------------------------------
# 159 K     Trainable params
# 0         Non-trainable params
# 159 K     Total params
# 0.638     Total estimated model params size (MB)
# Sanity Checking DataLoader 0: 100%|██████████████| 2/2 [00:00<00:00, 143.40it/s]Val-Acc=4.038750171661377
# Epoch 0: 100%|██████████████████████| 960/960 [00:09<00:00, 104.13it/s, v_num=0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/240 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/240 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                 | 1/240 [00:00<00
/s]
# Validation DataLoader 0:  51%|███████▋       | 122/240 [00:00<00:00, 156.51it/s]
# Validation DataLoader 0:  51%|███████▋       | 123/240 [00:00<00:00, 156.48it/s]
# Validation DataLoader 0:  52%|███████▊       | 124/240 [00:00<00:00, 156.20it/s]
# Validation DataLoader 0:  52%|███████▊       | 125/240 [00:00<00:00, 156.19it/s]
# Validation DataLoader 0:  52%|███████▉       | 126/240 [00:00<00:00, 156.10it/s]
# Validation DataLoader 0:  53%|███████▉       | 127/240 [00:00<00:00, 156.10it/s]
# Validation DataLoader 0:  53%|████████       | 128/240 [00:00<00:00, 156.06it/s]
# Validation DataLoader 0:  54%|████████       | 129/240 [00:00<00:00, 155.99it/s]
# Validation DataLoader 0:  54%|████████▏      | 130/240 [00:00<00:00, 156.09it/s]
# Validation DataLoader 0:  55%|████████▏      | 131/240 [00:00<00:00, 156.18it/s]
# Validation DataLoader 0:  55%|████████▎      | 132/240 [00:00<00:00, 155.91it/s]
# Validation DataLoader 0:  55%|████████▎      | 133/240 [00:00<00:00, 155.81it/s]
# Validation DataLoader 0:  56%|████████▍      | 134/240 [00:00<00:00, 155.61it/s]
# Validation DataLoader 0:  56%|████████▍      | 135/240 [00:00<00:00, 155.63it/s]
# Validation DataLoader 0:  57%|████████▌      | 136/240 [00:00<00:00, 155.72it/s]
# Validation DataLoader 0:  57%|████████▌      | 137/240 [00:00<00:00, 155.64it/s]
# Validation DataLoader 0:  57%|████████▋      | 138/240 [00:00<00:00, 155.56it/s]
# Validation DataLoader 0:  58%|████████▋      | 139/240 [00:00<00:00, 155.49it/s]
# Validation DataLoader 0:  58%|████████▊      | 140/240 [00:00<00:00, 155.43it/s]
# Validation DataLoader 0:  59%|████████▊      | 141/240 [00:00<00:00, 155.45it/s]
# Validation DataLoader 0:  59%|████████▉      | 142/240 [00:00<00:00, 155.48it/s]
# Validation DataLoader 0:  60%|████████▉      | 143/240 [00:00<00:00, 155.45it/s]
# Validation DataLoader 0:  60%|█████████      | 144/240 [00:00<00:00, 155.44it/s]
# Validation DataLoader 0:  60%|█████████      | 145/240 [00:00<00:00, 155.45it/s]
# Validation DataLoader 0:  61%|█████████▏     | 146/240 [00:00<00:00, 155.40it/s]
# Validation DataLoader 0:  61%|█████████▏     | 147/240 [00:00<00:00, 155.27it/s]
# Validation DataLoader 0:  62%|█████████▎     | 148/240 [00:00<00:00, 155.31it/s]
# Validation DataLoader 0:  62%|█████████▎     | 149/240 [00:00<00:00, 155.37it/s]
# Validation DataLoader 0:  62%|█████████▍     | 150/240 [00:00<00:00, 155.41it/s]
# Validation DataLoader 0:  63%|█████████▍     | 151/240 [00:00<00:00, 155.54it/s]
# Validation DataLoader 0:  63%|█████████▌     | 152/240 [00:00<00:00, 155.59it/s]
# Validation DataLoader 0:  64%|█████████▌     | 153/240 [00:00<00:00, 155.60it/s]
# Validation DataLoader 0:  64%|█████████▋     | 154/240 [00:00<00:00, 155.53it/s]
# Validation DataLoader 0:  65%|█████████▋     | 155/240 [00:00<00:00, 155.61it/s]
# Validation DataLoader 0:  65%|█████████▊     | 156/240 [00:01<00:00, 155.63it/s]
# Validation DataLoader 0:  65%|█████████▊     | 157/240 [00:01<00:00, 155.61it/s]
# Validation DataLoader 0:  66%|█████████▉     | 158/240 [00:01<00:00, 155.63it/s]
# Validation DataLoader 0:  66%|█████████▉     | 159/240 [00:01<00:00, 155.65it/s]
# Validation DataLoader 0:  67%|██████████     | 160/240 [00:01<00:00, 155.70it/s]
# Validation DataLoader 0:  67%|██████████     | 161/240 [00:01<00:00, 155.74it/s]
# Validation DataLoader 0:  68%|██████████▏    | 162/240 [00:01<00:00, 155.76it/s]
# Validation DataLoader 0:  68%|██████████▏    | 163/240 [00:01<00:00, 155.78it/s]
# Validation DataLoader 0:  68%|██████████▎    | 164/240 [00:01<00:00, 155.89it/s]
# Validation DataLoader 0:  69%|██████████▎    | 165/240 [00:01<00:00, 155.87it/s]
# Validation DataLoader 0:  69%|██████████▍    | 166/240 [00:01<00:00, 155.78it/s]
# Validation DataLoader 0:  70%|██████████▍    | 167/240 [00:01<00:00, 155.75it/s]
# Validation DataLoader 0:  70%|██████████▌    | 168/240 [00:01<00:00, 155.70it/s]
# Validation DataLoader 0:  70%|██████████▌    | 169/240 [00:01<00:00, 155.79it/s]
# Validation DataLoader 0:  71%|██████████▋    | 170/240 [00:01<00:00, 155.84it/s]
# Validation DataLoader 0:  71%|██████████▋    | 171/240 [00:01<00:00, 155.92it/s]
# Validation DataLoader 0:  72%|██████████▊    | 172/240 [00:01<00:00, 156.03it/s]
# Validation DataLoader 0:  72%|██████████▊    | 173/240 [00:01<00:00, 156.04it/s]
# Validation DataLoader 0:  72%|██████████▉    | 174/240 [00:01<00:00, 156.12it/s]
# Validation DataLoader 0:  73%|██████████▉    | 175/240 [00:01<00:00, 156.23it/s]
# Validation DataLoader 0:  73%|███████████    | 176/240 [00:01<00:00, 156.29it/s]
# Validation DataLoader 0:  74%|███████████    | 177/240 [00:01<00:00, 156.31it/s]
# Validation DataLoader 0:  74%|███████████▏   | 178/240 [00:01<00:00, 156.37it/s]
# Validation DataLoader 0:  75%|███████████▏   | 179/240 [00:01<00:00, 156.40it/s]
# Validation DataLoader 0:  75%|███████████▎   | 180/240 [00:01<00:00, 156.39it/s]
# Validation DataLoader 0:  75%|███████████▎   | 181/240 [00:01<00:00, 156.43it/s]
# Validation DataLoader 0:  76%|███████████▍   | 182/240 [00:01<00:00, 156.49it/s]
# Validation DataLoader 0:  76%|███████████▍   | 183/240 [00:01<00:00, 156.52it/s]
# Validation DataLoader 0:  77%|███████████▌   | 184/240 [00:01<00:00, 156.55it/s]
# Validation DataLoader 0:  77%|███████████▌   | 185/240 [00:01<00:00, 156.56it/s]
# Validation DataLoader 0:  78%|███████████▋   | 186/240 [00:01<00:00, 156.47it/s]
# Validation DataLoader 0:  78%|███████████▋   | 187/240 [00:01<00:00, 156.51it/s]
# Validation DataLoader 0:  78%|███████████▊   | 188/240 [00:01<00:00, 156.57it/s]
# Validation DataLoader 0:  79%|███████████▊   | 189/240 [00:01<00:00, 156.63it/s]
# Validation DataLoader 0:  79%|███████████▉   | 190/240 [00:01<00:00, 156.62it/s]
# Validation DataLoader 0:  80%|███████████▉   | 191/240 [00:01<00:00, 156.69it/s]
# Validation DataLoader 0:  80%|████████████   | 192/240 [00:01<00:00, 156.68it/s]
# Validation DataLoader 0:  80%|████████████   | 193/240 [00:01<00:00, 156.69it/s]
# Validation DataLoader 0:  81%|████████████▏  | 194/240 [00:01<00:00, 156.73it/s]
# Validation DataLoader 0:  81%|████████████▏  | 195/240 [00:01<00:00, 156.76it/s]
# Validation DataLoader 0:  82%|████████████▎  | 196/240 [00:01<00:00, 156.79it/s]
# Validation DataLoader 0:  82%|████████████▎  | 197/240 [00:01<00:00, 156.84it/s]
# Validation DataLoader 0:  82%|████████████▍  | 198/240 [00:01<00:00, 156.84it/s]
# Validation DataLoader 0:  83%|████████████▍  | 199/240 [00:01<00:00, 156.88it/s]
# Validation DataLoader 0:  83%|████████████▌  | 200/240 [00:01<00:00, 156.87it/s]
# Validation DataLoader 0:  84%|████████████▌  | 201/240 [00:01<00:00, 156.89it/s]
# Validation DataLoader 0:  84%|████████████▋  | 202/240 [00:01<00:00, 156.93it/s]
# Validation DataLoader 0:  85%|████████████▋  | 203/240 [00:01<00:00, 156.97it/s]
# Validation DataLoader 0:  85%|████████████▊  | 204/240 [00:01<00:00, 157.07it/s]
# Validation DataLoader 0:  85%|████████████▊  | 205/240 [00:01<00:00, 157.12it/s]
# Validation DataLoader 0:  86%|████████████▉  | 206/240 [00:01<00:00, 157.09it/s]
# Validation DataLoader 0:  86%|████████████▉  | 207/240 [00:01<00:00, 157.15it/s]
# Validation DataLoader 0:  87%|█████████████  | 208/240 [00:01<00:00, 157.14it/s]
# Validation DataLoader 0:  87%|█████████████  | 209/240 [00:01<00:00, 157.20it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 210/240 [00:01<00:00, 157.23it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 211/240 [00:01<00:00, 157.23it/s]
# Validation DataLoader 0:  88%|█████████████▎ | 212/240 [00:01<00:00, 157.23it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 213/240 [00:01<00:00, 157.32it/s]
# Validation DataLoader 0:  89%|█████████████▍ | 214/240 [00:01<00:00, 157.28it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 215/240 [00:01<00:00, 157.31it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 216/240 [00:01<00:00, 157.34it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 217/240 [00:01<00:00, 157.34it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 218/240 [00:01<00:00, 157.36it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 219/240 [00:01<00:00, 157.37it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 220/240 [00:01<00:00, 157.35it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 221/240 [00:01<00:00, 157.40it/s]
# Validation DataLoader 0:  92%|█████████████▉ | 222/240 [00:01<00:00, 157.35it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 223/240 [00:01<00:00, 157.43it/s]
# Validation DataLoader 0:  93%|██████████████ | 224/240 [00:01<00:00, 157.44it/s]
# Validation DataLoader 0:  94%|██████████████ | 225/240 [00:01<00:00, 157.44it/s]
# Validation DataLoader 0:  94%|██████████████▏| 226/240 [00:01<00:00, 157.54it/s]
# Validation DataLoader 0:  95%|██████████████▏| 227/240 [00:01<00:00, 157.55it/s]
# Validation DataLoader 0:  95%|██████████████▎| 228/240 [00:01<00:00, 157.53it/s]
# Validation DataLoader 0:  95%|██████████████▎| 229/240 [00:01<00:00, 157.60it/s]
# Validation DataLoader 0:  96%|██████████████▍| 230/240 [00:01<00:00, 157.60it/s]
# Validation DataLoader 0:  96%|██████████████▍| 231/240 [00:01<00:00, 157.67it/s]
# Validation DataLoader 0:  97%|██████████████▌| 232/240 [00:01<00:00, 157.77it/s]
# Validation DataLoader 0:  97%|██████████████▌| 233/240 [00:01<00:00, 157.74it/s]
# Validation DataLoader 0:  98%|██████████████▋| 234/240 [00:01<00:00, 157.77it/s]
# Validation DataLoader 0:  98%|██████████████▋| 235/240 [00:01<00:00, 157.78it/s]
# Validation DataLoader 0:  98%|██████████████▊| 236/240 [00:01<00:00, 157.81it/s]
# Validation DataLoader 0:  99%|██████████████▊| 237/240 [00:01<00:00, 157.88it/s]
# Validation DataLoader 0:  99%|██████████████▉| 238/240 [00:01<00:00, 157.90it/s]
# Validation DataLoader 0: 100%|██████████████▉| 239/240 [00:01<00:00, 157.94it/s]
# Validation DataLoader 0: 100%|███████████████| 240/240 [00:01<00:00, 157.98it/s]Val-Acc=8.289833068847656
#
# Epoch 4: 100%|█| 960/960 [00:10<00:00, 88.35it/s, v_num=0, val/loss=0.502, val/a
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|█| 960/960 [00:10<00:00, 88.27it/s, v_num=0, val/loss=0.502, val/a

# %% [markdown]
# ### Observations
# Take a look at TensorBoard to compare the performance of both networks:

# %%
# %load_ext tensorboard
# !/Users/tigrangaplanyan/anaconda3/envs/Homeworks/bin/tensorboard --logdir batch_norm_logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# TensorFlow installation not found - running with reduced feature set.
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.9.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# As you can see, using Batch Normalization resulted in better performance. You can easily observe lower validation loss and higher validation accuracy from the graphs. Batch Norm in general is helpful since it would lead to faster model training.
#
# Batch Normalization has other related benefits, for instance, it provides a bit of regularization. However, we also look for other methods of regularization such as Dropout. So in the second part of this notebook, let's have a more detailed look at the effect of Dropout.

# %% [markdown]
# # 2. Dropout

# %% [markdown]
# ## 2.1 What is Dropout
#
# Dropout [1] is a technique for regularizing neural networks by randomly setting some features to zero during the forward pass. While training, traditional dropout is implemented by only keeping a neuron active with some probability p
# (a hyperparameter), or setting it to zero otherwise. However, a modification of dropout called "inverted dropout" drops neurons with a given probability. You can read about the difference [here](https://machinelearning.wtf/terms/inverted-dropout/). The Dropout technique would help your Neural Network to perform better on Test data.
#
# We want to repeat the approach that we saw above for Batch Normalization, but this time for Dropout. Let us thus first have a look at the implementation and then compare two networks with each other where one is using Dropout and one is not.
#
# [1] Srivastava et al, "Dropout: A Simple Way to Prevent Neural Networks from Overfitting", 2014

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1dQEuk9DwZm3Pe8nBNrJo9FpV17jUMew5)

# %% [markdown]
# ## 2.2 Inverted Dropout Implementation

# %% [markdown]
# ### Inverted Dropout: Forward Pass
#
# The dropout method is a little less complex to implement than the Batch Normalization, hence we ask you to implement both, the forward and the backward pass. Let us start with the forward pass:
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p> In the file <code>exercise_code/layers.py</code>, implement the forward pass for Dropout in <code>dropout_forward()</code>. Since Dropout behaves differently during training and testing, make sure to implement the operation for both modes.
#     </p>
#     <p> Once you have done so, run the cell below to test your implementation.
#     </p>
# </div>

# %%
x = np.random.randn(500, 500) + 10
# Let us use different dropout values(p) for our dropout layer and see their effects
for p in [0.3, 0.6, 0.75]:
    out, _ = dropout_forward(x, {'mode': 'train', 'p': p})
    out_test, _ = dropout_forward(x, {'mode': 'test', 'p': p})

    print('Running tests with p = ', p)
    print('Mean of input: ', x.mean())
    print('Mean of train-time output: ', out.mean())
    print('Mean of test-time output: ', out_test.mean())
    print('Fraction of train-time output set to zero: ', (out == 0).mean())
    print('Fraction of test-time output set to zero: ', (out_test == 0).mean())
    print()
# Out:
# Running tests with p =  0.3
# Mean of input:  10.003729902741311
# Mean of train-time output:  10.011381833687244
# Mean of test-time output:  10.003729902741311
# Fraction of train-time output set to zero:  0.699812
# Fraction of test-time output set to zero:  0.0
#
# Running tests with p =  0.6
# Mean of input:  10.003729902741311
# Mean of train-time output:  9.992309269734971
# Mean of test-time output:  10.003729902741311
# Fraction of train-time output set to zero:  0.4007
# Fraction of test-time output set to zero:  0.0
#
# Running tests with p =  0.75
# Mean of input:  10.003729902741311
# Mean of train-time output:  9.996677979616209
# Mean of test-time output:  10.003729902741311
# Fraction of train-time output set to zero:  0.250468
# Fraction of test-time output set to zero:  0.0

# %% [markdown]
# ### Inverted Dropout: Backward Pass
#
# <div class="alert alert-info">
#     <h3>Task: Implement</h3>
#     <p> In the file <code>exercise_code/layers.py</code>, implement the backward pass for dropout in <code>dropout_backward()</code>. After doing so, run the following cell to numerically gradient-check your implementation.
#     </p>
# </div>

# %%
x = np.random.randn(10, 10) + 10
dout = np.random.randn(*x.shape)

dropout_param = {'mode': 'train', 'p': 0.8, 'seed': 123}
out, cache = dropout_forward(x, dropout_param)
dx = dropout_backward(dout, cache)
dx_num = eval_numerical_gradient_array(lambda xx: dropout_forward(xx, dropout_param)[0], x, dout)

print('dx relative error: ', rel_error(dx, dx_num))
# Out:
# dx relative error:  5.445608632586474e-11

# %% [markdown]
# ## 2.3 Using Dropout with PyTorch Lightning
#
# Same experiment as for Batch Normalization: We will train a pair of two-layer networks on a training dataset where one network will use no Dropout and one will use a Dropout probability of 0.75. We will then visualize the training and validation accuracies of the two networks over time.

# %% [markdown]
# ### Setup TensorBoard
#
# In homework_06 you've already learned how to use TensorBoard. Let's use it again to make the debugging of our network and training process more convenient. Throughout this notebook, feel free to add further logs or visualizations to your TensorBoard.

# %%
# Few Hyperparameters before we start things off
hidden_dim = 200
batch_size = 50

epochs = 5
learning_rate = 0.00005

logdir = './dropout_logs'
if os.path.exists(logdir):
    # We delete the logs on the first run
    shutil.rmtree(logdir)
os.mkdir(logdir)

# %%
# %load_ext tensorboard
# !/Users/tigrangaplanyan/anaconda3/envs/Homeworks/bin/tensorboard --logdir dropout_logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# TensorFlow installation not found - running with reduced feature set.
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.9.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p> As before, we have already implemented those two networks for you. You may check them out in <code>exercise_code/BatchNormModel.py</code>. As always, feel free to play around with the parameters here. Run the following two cells to setup both models and train them for a few epochs in order to compare the performance with and without Dropout.
#  </p>
# </div>
#
# ### Train a model without Dropout
#
# Let us first start with a simple network `SimpleNetwork` which does not make use of Dropout.

# %%
# train a model without Dropout
model = SimpleNetwork(hidden_dim=hidden_dim, batch_size=batch_size, learning_rate=learning_rate)
simple_network_logger = TensorBoardLogger(
    save_dir=logdir,
    name='simple_network'
)
trainer = pl.Trainer(max_epochs=epochs, logger=simple_network_logger)

trainer.fit(model)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: ./dropout_logs/simple_network
#
#   | Name  | Type       | Params
# -------------------------------------
# 0 | model | Sequential | 159 K
# -------------------------------------
# 159 K     Trainable params
# 0         Non-trainable params
# 159 K     Total params
# 0.636     Total estimated model params size (MB)
# Sanity Checking DataLoader 0: 100%|██████████████| 2/2 [00:00<00:00, 221.00it/s]Val-Acc=8.290416717529297
# Epoch 0: 100%|██████████████████████| 960/960 [00:07<00:00, 120.41it/s, v_num=0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/240 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/240 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                 | 1/240 [00:00<00:00, 255.02it/s]
# Validation DataLoader 0:   1%|▏                | 2/240 [00:00<00:01, 197.68it/s]
# Validation DataLoader 0:   1%|▏                | 3/240 [00:00<00:01, 188.98it/s]
# Validation DataLoader 0:   2%|▎                | 4/240 [00:00<00:01, 183.48it/s]
# Validation DataLoader 0:   2%|▎                | 5/240 [00:00<00:01, 176.79it/s]
# Validation DataLoader 0:   2%|▍                | 6/240 [00:00<00:01, 175.61it/s]
# Validation DataLoader 0:   3%|▍                | 7/240 [00:00<00:01, 171.45it/s]
# Validation DataLoader 0:   3%|▌                | 8/240 [00:00<00:01, 169.39it/s]
# Validation DataLoader 0:   4%|▋                | 9/240 [00:00<00:01, 169.43it/s]
# Validation DataLoader 0:   4%|▋               | 10/240 [00:00<00:01, 168.05it/s]
# Validation DataLoader 0:   5%|▋               | 11/240 [00:00<00:01, 168.73it/s]
# Validation DataLoader 0:   5%|▊               | 12/240 [00:00<00:01, 168.75it/s]
# Validation DataLoader 0:   5%|▊               | 13/240 [00:00<00:01, 168.78it/s]
# Validation DataLoader 0:   6%|▉               | 14/240 [00:00<00:01, 169.05it/s]
# Validation DataLoader 0:   6%|█               | 15/240 [00:00<00:01, 167.62it/s]
# Validation DataLoader 0:   7%|█               | 16/240 [00:00<00:01, 167.27it/s]
# Validation DataLoader 0:   7%|█▏              | 17/240 [00:00<00:01, 167.53it/s]
# Validation DataLoader 0:   8%|█▏              | 18/240 [00:00<00:01, 166.84it/s]
# Validation DataLoader 0:   8%|█▎              | 19/240 [00:00<00:01, 167.33it/s]
# Validation DataLoader 0:   8%|█▎              | 20/240 [00:00<00:01, 167.05it/s]
# Validation DataLoader 0:   9%|█▍              | 21/240 [00:00<00:01, 166.04it/s]
# Validation DataLoader 0:   9%|█▍              | 22/240 [00:00<00:01, 166.54it/s]
# Validation DataLoader 0:  10%|█▌              | 23/240 [00:00<00:01, 165.36it/s]
# Validation DataLoader 0:  10%|█▌              | 24/240 [00:00<00:01, 165.33it/s]
# Validation DataLoader 0:  10%|█▋              | 25/240 [00:00<00:01, 165.29it/s]
# Validation DataLoader 0:  11%|█▋              | 26/240 [00:00<00:01, 164.65it/s]
# Validation DataLoader 0:  11%|█▊              | 27/240 [00:00<00:01, 165.43it/s]
# Validation DataLoader 0:  12%|█▊              | 28/240 [00:00<00:01, 165.56it/s]
# Validation DataLoader 0:  12%|█▉              | 29/240 [00:00<00:01, 164.67it/s]
# Validation DataLoader 0:  12%|██              | 30/240 [00:00<00:01, 165.27it/s]
# Validation DataLoader 0:  13%|██              | 31/240 [00:00<00:01, 164.48it/s]
# Validation DataLoader 0:  13%|██▏             | 32/240 [00:00<00:01, 164.18it/s]
# Validation DataLoader 0:  14%|██▏             | 33/240 [00:00<00:01, 164.44it/s]
# Validation DataLoader 0:  14%|██▎             | 34/240 [00:00<00:01, 163.91it/s]
# Validation DataLoader 0:  15%|██▎             | 35/240 [00:00<00:01, 164.33it/s]
# Validation DataLoader 0:  15%|██▍             | 36/240 [00:00<00:01, 164.58it/s]
# Validation DataLoader 0:  15%|██▍             | 37/240 [00:00<00:01, 164.11it/s]
# Validation DataLoader 0:  16%|██▌             | 38/240 [00:00<00:01, 164.05it/s]
# Validation DataLoader 0:  16%|██▌             | 39/240 [00:00<00:01, 163.23it/s]
# Validation DataLoader 0:  17%|██▋             | 40/240 [00:00<00:01, 163.01it/s]
# Validation DataLoader 0:  17%|██▋             | 41/240 [00:00<00:01, 163.16it/s]
# Validation DataLoader 0:  18%|██▊             | 42/240 [00:00<00:01, 162.89it/s]
# Validation DataLoader 0:  18%|██▊             | 43/240 [00:00<00:01, 162.89it/s]
# Validation DataLoader 0:  18%|██▉             | 44/240 [00:00<00:01, 162.74it/s]
# Validation DataLoader 0:  19%|███             | 45/240 [00:00<00:01, 162.45it/s]
# Validation DataLoader 0:  19%|███             | 46/240 [00:00<00:01, 162.42it/s]
# Validation DataLoader 0:  20%|███▏            | 47/240 [00:00<00:01, 162.41it/s]
# Validation DataLoader 0:  20%|███▏            | 48/240 [00:00<00:01, 162.09it/s]
# Validation DataLoader 0:  20%|███▎            | 49/240 [00:00<00:01, 161.97it/s]
# Validation DataLoader 0:  21%|███▎            | 50/240 [00:00<00:01, 161.64it/s]
# Validation DataLoader 0:  21%|███▍            | 51/240 [00:00<00:01, 161.75it/s]
# Validation DataLoader 0:  22%|███▍            | 52/240 [00:00<00:01, 161.40it/s]
# Validation DataLoader 0:  22%|███▌            | 53/240 [00:00<00:01, 161.21it/s]
# Validation DataLoader 0:  22%|███▌            | 54/240 [00:00<00:01, 161.35it/s]
# Validation DataLoader 0:  23%|███▋            | 55/240 [00:00<00:01, 161.03it/s]
# Validation DataLoader 0:  23%|███▋            | 56/240 [00:00<00:01, 160.90it/s]
# Validation DataLoader 0:  24%|███▊            | 57/240 [00:00<00:01, 161.14it/s]
# Validation DataLoader 0:  24%|███▊            | 58/240 [00:00<00:01, 160.77it/s]
# Validation DataLoader 0:  25%|███▉            | 59/240 [00:00<00:01, 160.71it/s]
# Validation DataLoader 0:  25%|████            | 60/240 [00:00<00:01, 160.50it/s]
# Validation DataLoader 0:  25%|████            | 61/240 [00:00<00:01, 160.66it/s]
# Validation DataLoader 0:  26%|████▏           | 62/240 [00:00<00:01, 160.95it/s]
# Validation DataLoader 0:  26%|████▏           | 63/240 [00:00<00:01, 160.63it/s]
# Validation DataLoader 0:  27%|████▎           | 64/240 [00:00<00:01, 160.61it/s]
# Validation DataLoader 0:  27%|████▎           | 65/240 [00:00<00:01, 160.21it/s]
# Validation DataLoader 0:  28%|████▍           | 66/240 [00:00<00:01, 160.23it/s]
# Validation DataLoader 0:  28%|████▍           | 67/240 [00:00<00:01, 160.36it/s]
# Validation DataLoader 0:  28%|████▌           | 68/240 [00:00<00:01, 160.26it/s]
# Validation DataLoader 0:  29%|████▌           | 69/240 [00:00<00:01, 160.30it/s]
# Validation DataLoader 0:  29%|████▋           | 70/240 [00:00<00:01, 160.29it/s]
# Validation DataLoader 0:  30%|████▋           | 71/240 [00:00<00:01, 160.12it/s]
# Validation DataLoader 0:  30%|████▊           | 72/240 [00:00<00:01, 160.11it/s]
# Validation DataLoader 0:  30%|████▊           | 73/240 [00:00<00:01, 160.05it/s]
# Validation DataLoader 0:  31%|████▉           | 74/240 [00:00<00:01, 160.12it/s]
# Validation DataLoader 0:  31%|█████           | 75/240 [00:00<00:01, 160.27it/s]
# Validation DataLoader 0:  32%|█████           | 76/240 [00:00<00:01, 159.94it/s]
# Validation DataLoader 0:  32%|█████▏          | 77/240 [00:00<00:01, 160.04it/s]
# Validation DataLoader 0:  32%|█████▏          | 78/240 [00:00<00:01, 160.07it/s]
# Validation DataLoader 0:  33%|█████▎          | 79/240 [00:00<00:01, 159.83it/s]
# Validation DataLoader 0:  33%|█████▎          | 80/240 [00:00<00:01, 159.85it/s]
# Validation DataLoader 0:  34%|█████▍          | 81/240 [00:00<00:00, 159.90it/s]
# Validation DataLoader 0:  34%|█████▍          | 82/240 [00:00<00:00, 159.95it/s]
# Validation DataLoader 0:  35%|█████▌          | 83/240 [00:00<00:00, 159.91it/s]
# Validation DataLoader 0:  35%|█████▌          | 84/240 [00:00<00:00, 159.68it/s]
# Validation DataLoader 0:  35%|█████▋          | 85/240 [00:00<00:00, 159.71it/s]
# Validation DataLoader 0:  36%|█████▋          | 86/240 [00:00<00:00, 159.40it/s]
# Validation DataLoader 0:  36%|█████▊          | 87/240 [00:00<00:00, 159.27it/s]
# Validation DataLoader 0:  37%|█████▊          | 88/240 [00:00<00:00, 159.36it/s]
# Validation DataLoader 0:  37%|█████▉          | 89/240 [00:00<00:00, 159.63it/s]
# Validation DataLoader 0:  38%|██████          | 90/240 [00:00<00:00, 159.48it/s]
# Validation DataLoader 0:  38%|██████          | 91/240 [00:00<00:00, 159.50it/s]
# Validation DataLoader 0:  38%|██████▏         | 92/240 [00:00<00:00, 159.52it/s]
# Validation DataLoader 0:  39%|██████▏         | 93/240 [00:00<00:00, 159.65it/s]
# Validation DataLoader 0:  39%|██████▎         | 94/240 [00:00<00:00, 159.48it/s]
# Validation DataLoader 0:  40%|██████▎         | 95/240 [00:00<00:00, 159.32it/s]
# Validation DataLoader 0:  40%|██████▍         | 96/240 [00:00<00:00, 159.28it/s]
# Validation DataLoader 0:  40%|██████▍         | 97/240 [00:00<00:00, 159.24it/s]
# Validation DataLoader 0:  41%|██████▌         | 98/240 [00:00<00:00, 159.22it/s]
# Validation DataLoader 0:  41%|██████▌         | 99/240 [00:00<00:00, 159.30it/s]
# Validation DataLoader 0:  42%|██████▎        | 100/240 [00:00<00:00, 159.24it/s]
# Validation DataLoader 0:  42%|██████▎        | 101/240 [00:00<00:00, 159.39it/s]
# Validation DataLoader 0:  42%|██████▍        | 102/240 [00:00<00:00, 159.28it/s]
# Validation DataLoader 0:  43%|██████▍        | 103/240 [00:00<00:00, 159.28it/s]
# Validation DataLoader 0:  43%|██████▌        | 104/240 [00:00<00:00, 159.38it/s]
# Validation DataLoader 0:  44%|██████▌        | 105/240 [00:00<00:00, 159.32it/s]
# Validation DataLoader 0:  44%|██████▋        | 106/240 [00:00<00:00, 159.37it/s]
# Validation DataLoader 0:  45%|██████▋        | 107/240 [00:00<00:00, 159.35it/s]
# Validation DataLoader 0:  45%|██████▊        | 108/240 [00:00<00:00, 159.39it/s]
# Validation DataLoader 0:  45%|██████▊        | 109/240 [00:00<00:00, 159.51it/s]
# Validation DataLoader 0:  46%|██████▉        | 110/240 [00:00<00:00, 159.42it/s]
# Validation DataLoader 0:  46%|██████▉        | 111/240 [00:00<00:00, 159.41it/s]
# Validation DataLoader 0:  47%|███████        | 112/240 [00:00<00:00, 159.53it/s]
# Validation DataLoader 0:  47%|███████        | 113/240 [00:00<00:00, 159.54it/s]
# Validation DataLoader 0:  48%|███████▏       | 114/240 [00:00<00:00, 159.52it/s]
# Validation DataLoader 0:  48%|███████▏       | 115/240 [00:00<00:00, 159.84it/s]
# Validation DataLoader 0:  48%|███████▎       | 116/240 [00:00<00:00, 159.65it/s]
# Validation DataLoader 0:  49%|███████▎       | 117/240 [00:00<00:00, 159.87it/s]
# Validation DataLoader 0:  49%|███████▍       | 118/240 [00:00<00:00, 160.00it/s]
# Validation DataLoader 0:  50%|███████▍       | 119/240 [00:00<00:00, 159.96it/s]
# Validation DataLoader 0:  50%|███████▌       | 120/240 [00:00<00:00, 160.04it/s]
# Validation DataLoader 0:  50%|███████▌       | 121/240 [00:00<00:00, 160.09it/s]
# Validation DataLoader 0:  51%|███████▋       | 122/240 [00:00<00:00, 160.03it/s]
# Validation DataLoader 0:  51%|███████▋       | 123/240 [00:00<00:00, 160.08it/s]
# Validation DataLoader 0:  52%|███████▊       | 124/240 [00:00<00:00, 160.05it/s]
# Validation DataLoader 0:  52%|███████▊       | 125/240 [00:00<00:00, 160.12it/s]
# Validation DataLoader 0:  52%|███████▉       | 126/240 [00:00<00:00, 160.18it/s]
# Validation DataLoader 0:  53%|███████▉       | 127/240 [00:00<00:00, 160.11it/s]
# Validation DataLoader 0:  53%|████████       | 128/240 [00:00<00:00, 160.19it/s]
# Validation DataLoader 0:  54%|████████       | 129/240 [00:00<00:00, 160.23it/s]
# Validation DataLoader 0:  54%|████████▏      | 130/240 [00:00<00:00, 160.13it/s]
# Validation DataLoader 0:  55%|████████▏      | 131/240 [00:00<00:00, 160.22it/s]
# Validation DataLoader 0:  55%|████████▎      | 132/240 [00:00<00:00, 160.29it/s]
# Validation DataLoader 0:  55%|████████▎      | 133/240 [00:00<00:00, 160.34it/s]
# Validation DataLoader 0:  56%|████████▍      | 134/240 [00:00<00:00, 160.50it/s]
# Validation DataLoader 0:  56%|████████▍      | 135/240 [00:00<00:00, 160.51it/s]
# Validation DataLoader 0:  57%|████████▌      | 136/240 [00:00<00:00, 160.60it/s]
# Validation DataLoader 0:  57%|████████▌      | 137/240 [00:00<00:00, 160.71it/s]
# Validation DataLoader 0:  57%|████████▋      | 138/240 [00:00<00:00, 160.66it/s]
# Validation DataLoader 0:  58%|████████▋      | 139/240 [00:00<00:00, 160.76it/s]
# Validation DataLoader 0:  58%|████████▊      | 140/240 [00:00<00:00, 160.86it/s]
# Validation DataLoader 0:  59%|████████▊      | 141/240 [00:00<00:00, 160.80it/s]
# Validation DataLoader 0:  59%|████████▉      | 142/240 [00:00<00:00, 160.86it/s]
# Validation DataLoader 0:  60%|████████▉      | 143/240 [00:00<00:00, 160.89it/s]
# Validation DataLoader 0:  60%|█████████      | 144/240 [00:00<00:00, 160.87it/s]
# Validation DataLoader 0:  60%|█████████      | 145/240 [00:00<00:00, 161.00it/s]
# Validation DataLoader 0:  61%|█████████▏     | 146/240 [00:00<00:00, 161.07it/s]
# Validation DataLoader 0:  61%|█████████▏     | 147/240 [00:00<00:00, 161.12it/s]
# Validation DataLoader 0:  62%|█████████▎     | 148/240 [00:00<00:00, 161.19it/s]
# Validation DataLoader 0:  62%|█████████▎     | 149/240 [00:00<00:00, 161.14it/s]
# Validation DataLoader 0:  62%|█████████▍     | 150/240 [00:00<00:00, 161.27it/s]
# Validation DataLoader 0:  63%|█████████▍     | 151/240 [00:00<00:00, 161.32it/s]
# Validation DataLoader 0:  63%|█████████▌     | 152/240 [00:00<00:00, 161.34it/s]
# Validation DataLoader 0:  64%|█████████▌     | 153/240 [00:00<00:00, 161.35it/s]
# Validation DataLoader 0:  64%|█████████▋     | 154/240 [00:00<00:00, 161.40it/s]
# Validation DataLoader 0:  65%|█████████▋     | 155/240 [00:00<00:00, 161.38it/s]
# Validation DataLoader 0:  65%|█████████▊     | 156/240 [00:00<00:00, 161.45it/s]
# Validation DataLoader 0:  65%|█████████▊     | 157/240 [00:00<00:00, 161.51it/s]
# Validation DataLoader 0:  66%|█████████▉     | 158/240 [00:00<00:00, 161.37it/s]
# Validation DataLoader 0:  66%|█████████▉     | 159/240 [00
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|█| 960/960 [00:10<00:00, 94.26it/s, v_num=0, val/loss=0.524, val/a

# %% [markdown]
# ### Train a model incl. Dropout
#
# Now that we have already seen how our simple network should work, let us look at the model `DropoutNetwork` that is actually using Dropout.

# %%
# train a model with Dropout
model = DropoutNetwork(hidden_dim=hidden_dim, batch_size=batch_size, learning_rate=learning_rate,dropout_p=0.75)
dropout_network_logger = TensorBoardLogger(
    save_dir=logdir,
    name='dropout_network'
)
trainer = pl.Trainer(max_epochs=epochs, logger=dropout_network_logger)

trainer.fit(model)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: ./dropout_logs/dropout_network
#
#   | Name  | Type       | Params
# -------------------------------------
# 0 | model | Sequential | 159 K
# -------------------------------------
# 159 K     Trainable params
# 0         Non-trainable params
# 159 K     Total params
# 0.638     Total estimated model params size (MB)
# Sanity Checking DataLoader 0: 100%|██████████████| 2/2 [00:00<00:00, 149.56it/s]Val-Acc=12.317083358764648
# Epoch 0: 100%|███████████████████████| 960/960 [00:09<00:00, 96.55it/s, v_num=0]
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/240 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/240 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                 | 1/240 [00:00<00:00, 269.19it/s]
# Validation DataLoader 0:   1%|▏                | 2/240 [00:00<00:01, 192.36it/s]
# Validation DataLoader 0:   1%|▏                | 3/240 [00:00<00:01, 178.18it/s]
# Validation DataLoader 0:   2%|▎                | 4/240 [00:00<00:01, 165.84it/s]
# Validation DataLoader 0:   2%|▎                | 5/240 [00:00<00:01, 163.42it/s]
# Validation DataLoader 0:   2%|▍                | 6/240 [00:00<00:01, 165.15it/s]
# Validation DataLoader 0:   3%|▍                | 7/240 [00:00<00:01, 163.80it/s]
# Validation DataLoader 0:   3%|▌                | 8/240 [00:00<00:01, 162.62it/s]
# Validation DataLoader 0:   4%|▋                | 9/240 [00:00<00:01, 163.17it/s]
# Validation DataLoader 0:   4%|▋               | 10/240 [00:00<00:01, 161.50it/s]
# Validation DataLoader 0:   5%|▋               | 11/240 [00:00<00:01, 162.19it/s]
# Validation DataLoader 0:   5%|▊               | 12/240 [00:00<00:01, 161.54it/s]
# Validation DataLoader 0:   5%|▊               | 13/240 [00:00<00:01, 159.58it/s]
# Validation DataLoader 0:   6%|▉               | 14/240 [00:00<00:01, 160.08it/s]
# Validation DataLoader 0:   6%|█               | 15/240 [00:00<00:01, 159.88it/s]
# Validation DataLoader 0:   7%|█               | 16/240 [00:00<00:01, 160.09it/s]
# Validation DataLoader 0:   7%|█▏              | 17/240 [00:00<00:01, 160.10it/s]
# Validation DataLoader 0:   8%|█▏              | 18/240 [00:00<00:01, 159.39it/s]
# Validation DataLoader 0:   8%|█▎              | 19/240 [00:00<00:01, 160.08it/s]
# Validation DataLoader 0:   8%|█▎              | 20/240 [00:00<00:01, 159.20it/s]
# Validation DataLoader 0:   9%|█▍              | 21/240 [00:00<00:01, 158.63it/s]
# Validation DataLoader 0:   9%|█▍              | 22/240 [00:00<00:01, 159.48it/s]
# Validation DataLoader 0:  10%|█▌              | 23/240 [00:00<00:01, 158.65it/s]
# Validation DataLoader 0:  10%|█▌              | 24/240 [00:00<00:01, 158.51it/s]
# Validation DataLoader 0:  10%|█▋              | 25/240 [00:00<00:01, 157.99it/s]
# Validation DataLoader 0:  11%|█▋              | 26/240 [00:00<00:01, 157.27it/s]
# Validation DataLoader 0:  11%|█▊              | 27/240 [00:00<00:01, 157.62it/s]
# Validation DataLoader 0:  12%|█▊              | 28/240 [00:00<00:01, 157.10it/s]
# Validation DataLoader 0:  12%|█▉              | 29/240 [00:00<00:01, 157.06it/s]
# Validation DataLoader 0:  12%|██              | 30/240 [00:00<00:01, 156.98it/s]
# Validation DataLoader 0:  13%|██              | 31/240 [00:00<00:01, 156.11it/s]
# Validation DataLoader 0:  13%|██▏             | 32/240 [00:00<00:01, 156.05it/s]
# Validation DataLoader 0:  14%|██▏             | 33/240 [00:00<00:01, 155.81it/s]
# Validation DataLoader 0:  14%|██▎             | 34/240 [00:00<00:01, 155.83it/s]
# Validation DataLoader 0:  15%|██▎             | 35/240 [00:00<00:01, 155.78it/s]
# Validation DataLoader 0:  15%|██▍             | 36/240 [00:00<00:01, 155.05it/s]
# Validation DataLoader 0:  15%|██▍             | 37/240 [00:00<00:01, 155.18it/s]
# Validation DataLoader 0:  16%|██▌             | 38/240 [00:00<00:01, 154.80it/s]
# Validation DataLoader 0:  16%|██▌             | 39/240 [00:00<00:01, 155.08it/s]
# Validation DataLoader 0:  17%|██▋             | 40/240 [00:00<00:01, 155.20it/s]
# Validation DataLoader 0:  17%|██▋             | 41/240 [00:00<00:01, 154.39it/s]
# Validation DataLoader 0:  18%|██▊             | 42/240 [00:00<00:01, 154.60it/s]
# Validation DataLoader 0:  18%|██▊             | 43/240 [00:00<00:01, 154.28it/s]
# Validation DataLoader 0:  18%|██▉             | 44/240 [00:00<00:01, 154.46it/s]
# Validation DataLoader 0:  19%|███             | 45/240 [00:00<00:01, 154.36it/s]
# Validation DataLoader 0:  19%|███             | 46/240 [00:00<00:01, 153.90it/s]
# Validation DataLoader 0:  20%|███▏            | 47/240 [00:00<00:01, 154.11it/s]
# Validation DataLoader 0:  20%|███▏            | 48/240 [00:00<00:01, 154.10it/s]
# Validation DataLoader 0:  20%|███▎            | 49/240 [00:00<00:01, 154.31it/s]
# Validation DataLoader 0:  21%|███▎            | 50/240 [00:00<00:01, 154.64it/s]
# Validation DataLoader 0:  21%|███▍            | 51/240 [00:00<00:01, 154.53it/s]
# Validation DataLoader 0:  22%|███▍            | 52/240 [00:00<00:01, 154.75it/s]
# Validation DataLoader 0:  22%|███▌            | 53/240 [00:00<00:01, 154.78it/s]
# Validation DataLoader 0:  22%|███▌            | 54/240 [00:00<00:01, 154.79it/s]
# Validation DataLoader 0:  23%|███▋            | 55/240 [00:00<00:01, 154.92it/s]
# Validation DataLoader 0:  23%|███▋            | 56/240 [00:00<00:01, 154.70it/s]
# Validation DataLoader 0:  24%|███▊            | 57/240 [00:00<00:01, 154.73it/s]
# Validation DataLoader 0:  24%|███▊            | 58/240 [00:00<00:01, 155.11it/s]
# Validation DataLoader 0:  25%|███▉            | 59/240 [00:00<00:01, 155.37it/s]
# Validation DataLoader 0:  25%|████            | 60/240 [00:00<00:01, 155.51it/s]
# Validation DataLoader 0:  25%|████            | 61/240 [00:00<00:01, 155.80it/s]
# Validation DataLoader 0:  26%|████▏           | 62/240 [00:00<00:01, 155.66it/s]
# Validation DataLoader 0:  26%|████▏           | 63/240 [00:00<00:01, 155.88it/s]
# Validation DataLoader 0:  27%|████▎           | 64/240 [00:00<00:01, 156.10it/s]
# Validation DataLoader 0:  27%|████▎           | 65/240 [00:00<00:01, 156.21it/s]
# Validation DataLoader 0:  28%|████▍           | 66/240 [00:00<00:01, 156.02it/s]
# Validation DataLoader 0:  28%|████▍           | 67/240 [00:00<00:01, 155.93it/s]
# Validation DataLoader 0:  28%|████▌           | 68/240 [00:00<00:01, 156.00it/s]
# Validation DataLoader 0:  29%|████▌           | 69/240 [00:00<00:01, 155.92it/s]
# Validation DataLoader 0:  29%|████▋           | 70/240 [00:00<00:01, 156.00it/s]
# Validation DataLoader 0:  30%|████▋           | 71/240 [00:00<00:01, 156.15it/s]
# Validation DataLoader 0:  30%|████▊           | 72/240 [00:00<00:01, 156.18it/s]
# Validation DataLoader 0:  30%|████▊           | 73/240 [00:00<00:01, 156.31it/s]
# Validation DataLoader 0:  31%|████▉           | 74/240 [00:00<00:01, 156.57it/s]
# Validation DataLoader 0:  31%|█████           | 75/240 [00:00<00:01, 156.38it/s]
# Validation DataLoader 0:  32%|█████           | 76/240 [00:00<00:01, 156.55it/s]
# Validation DataLoader 0:  32%|█████▏          | 77/240 [00:00<00:01, 156.56it/s]
# Validation DataLoader 0:  32%|█████▏          | 78/240 [00:00<00:01, 156.37it/s]
# Validation DataLoader 0:  33%|█████▎          | 79/240 [00:00<00:01, 156.58it/s]
# Validation DataLoader 0:  33%|█████▎          | 80/240 [00:00<00:01, 156.73it/s]
# Validation DataLoader 0:  34%|█████▍          | 81/240 [00:00<00:01, 156.90it/s]
# Validation DataLoader 0:  34%|█████▍          | 82/240 [00:00<00:01, 157.06it/s]
# Validation DataLoader 0:  35%|█████▌          | 83/240 [00:00<00:01, 156.92it/s]
# Validation DataLoader 0:  35%|█████▌          | 84/240 [00:00<00:00, 156.93it/s]
# Validation DataLoader 0:  35%|█████▋          | 85/240 [00:00<00:00, 156.92it/s]
# Validation DataLoader 0:  36%|█████▋          | 86/240 [00:00<00:00, 156.61it/s]
# Validation DataLoader 0:  36%|█████▊          | 87/240 [00:00<00:00, 156.75it/s]
# Validation DataLoader 0:  37%|█████▊          | 88/240 [00:00<00:00, 156.75it/s]
# Validation DataLoader 0:  37%|█████▉          | 89/240 [00:00<00:00, 156.77it/s]
# Validation DataLoader 0:  38%|██████          | 90/240 [00:00<00:00, 156.81it/s]
# Validation DataLoader 0:  38%|██████          | 91/240 [00:00<00:00, 156.92it/s]
# Validation DataLoader 0:  38%|██████▏         | 92/240 [00:00<00:00, 157.05it/s]
# Validation DataLoader 0:  39%|██████▏         | 93/240 [00:00<00:00, 157.12it/s]
# Validation DataLoader 0:  39%|██████▎         | 94/240 [00:00<00:00, 157.28it/s]
# Validation DataLoader 0:  40%|██████▎         | 95/240 [00:00<00:00, 157.44it/s]
# Validation DataLoader 0:  40%|██████▍         | 96/240 [00:00<00:00, 157.52it/s]
# Validation DataLoader 0:  40%|██████▍         | 97/240 [00:00<00:00, 157.69it/s]
# Validation DataLoader 0:  41%|██████▌         | 98/240 [00:00<00:00, 157.75it/s]
# Validation DataLoader 0:  41%|██████▌         | 99/240 [00:00<00:00, 157.81it/s]
# Validation DataLoader 0:  42%|██████▎        | 100/240 [00:00<00:00, 157.90it/s]
# Validation DataLoader 0:  42%|██████▎        | 101/240 [00:00<00:00, 157.95it/s]
# Validation DataLoader 0:  42%|██████▍        | 102/240 [00:00<00:00, 157.98it/s]
# Validation DataLoader 0:  43%|██████▍        | 103/240 [00:00<00:00, 158.07it/s]
# Validation DataLoader 0:  43%|██████▌        | 104/240 [00:00<00:00, 158.15it/s]
# Validation DataLoader 0:  44%|██████▌        | 105/240 [00:00<00:00, 158.21it/s]
# Validation DataLoader 0:  44%|██████▋        | 106/240 [00:00<00:00, 158.38it/s]
# Validation DataLoader 0:  45%|██████▋        | 107/240 [00:00<00:00, 158.48it/s]
# Validation DataLoader 0:  45%|██████▊        | 108/240 [00:00<00:00, 158.67it/s]
# Validation DataLoader 0:  45%|██████▊        | 109/240 [00:00<00:00, 158.82it/s]
# Validation DataLoader 0:  46%|██████▉        | 110/240 [00:00<00:00, 158.83it/s]
# Validation DataLoader 0:  46%|██████▉        | 111/240 [00:00<00:00, 158.94it/s]
# Validation DataLoader 0:  47%|███████        | 112/240 [00:00<00:00, 159.07it/s]
# Validation DataLoader 0:  47%|███████        | 113/240 [00:00<00:00, 159.07it/s]
# Validation DataLoader 0:  48%|███████▏       | 114/240 [00:00<00:00, 159.17it/s]
# Validation DataLoader 0:  48%|███████▏       | 115/240 [00:00<00:00, 159.18it/s]
# Validation DataLoader 0:  48%|███████▎       | 116/240 [00:00<00:00, 159.25it/s]
# Validation DataLoader 0:  49%|███████▎       | 117/240 [00:00<00:00, 159.42it/s]
# Validation DataLoader 0:  49%|███████▍       | 118/240 [00:00<00:00, 159.51it/s]
# Validation DataLoader 0:  50%|███████▍       | 119/240 [00:00<00:00, 159.51it/s]
# Validation DataLoader 0:  50%|███████▌       | 120/240 [00:00<00:00, 159.52it/s]
# Validation DataLoader 0:  50%|███████▌       | 121/240 [00:00<00:00, 159.47it/s]
# Validation DataLoader 0:  51%|███████▋       | 122/240 [00:00<00:00, 159.55it/s]
# Validation DataLoader 0:  51%|███████▋       | 123/240 [00:00<00:00, 159.62it/s]
# Validation DataLoader 0:  52%|███████▊       | 124/240 [00:00<00:00, 159.57it/s]
# Validation DataLoader 0:  52%|███████▊       | 125/240 [00:00<00:00, 159.59it/s]
# Validation DataLoader 0:  52%|███████▉       | 126/240 [00:00<00:00, 159.58it/s]
# Validation DataLoader 0:  53%|███████▉       | 127/240 [00:00<00:00, 159.58it/s]
# Validation DataLoader 0:  53%|████████       | 128/240 [00:00<00:00, 159.64it/s]
# Validation DataLoader 0:  54%|████████       | 129/240 [00:00<00:00, 159.69it/s]
# Validation DataLoader 0:  54%|████████▏      | 130/240 [00:00<00:00, 159.64it/s]
# Validation DataLoader 0:  55%|████████▏      | 131/240 [00:00<00:00, 159.78it/s]
# Validation DataLoader 0:  55%|████████▎      | 132/240 [00:00<00:00, 159.82it/s]
# Validation DataLoader 0:  55%|████████▎      | 133/240 [00:00<00:00, 159.89it/s]
# Validation DataLoader 0:  56%|████████▍      | 134/240 [00:00<00:00, 159.95it/s]
# Validation DataLoader 0:  56%|████████▍      | 135/240 [00:00<00:00, 159.96it/s]
# Validation DataLoader 0:  57%|████████▌      | 136/240 [00:00<00:00, 159.96it/s]
# Validation DataLoader 0:  57%|████████▌      | 137/240 [00:00<00:00, 160.05it/s]
# Validation DataLoader 0:  57%|████████▋      | 138/240 [00:00<00:00, 159.97it/s]
# Validation DataLoader 0:  58%|████████▋      | 139/240 [00:00<00:00, 160.03it/s]
# Validation DataLoader 0:  58%|████████▊      | 140/240 [00:00<00:00, 160.10it/s]
# Validation DataLoader 0:  59%|████████▊      | 141/240 [00:00<00:00, 160.11it/s]
# Validation DataLoader 0:  59%|████████▉      | 142/240 [00:00<00:00, 160.13it/s]
# Validation DataLoader 0:  60%|████████▉      | 143/240 [00:00<00:00, 160.25it/s]
# Validation DataLoader 0:  60%|█████████      | 144/240 [00:00<00:00, 160.36it/s]
# Validation DataLoader 0:  60%|█████████      | 145/240 [00:00<00:00, 160.39it/s]
# Validation DataLoader 0:  61%|█████████▏     | 146/240 [00:00<00:00, 160.30it/s]
# Validation DataLoader 0:  61%|█████████▏     | 147/240 [00:00<00:00, 160.26it/s]
# Validation DataLoader 0:  62%|█████████▎     | 148/240 [00:00<00:00, 160.33it/s]
# Validation DataLoader 0:  62%|█████████▎     | 149/240 [00:00<00:00, 160.30it/s]
# Validation DataLoader 0:  62%|█████████▍     | 150/240 [00:00<00:00, 160.29it/s]
# Validation DataLoader 0:  63%|█████████▍     | 151/240 [00:00<00:00, 160.31it/s]
# Validation DataLoader 0:  63%|█████████▌     | 152/240 [00:00<00:00, 160.33it/s]
# Validation DataLoader 0:  64%|█████████▌     | 153/240 [00:00<00:00, 160.41it/s]
# Validation DataLoader 0:  64%|█████████▋     | 154/240 [00:00<00:00, 160.39it/s]
# Validation DataLoader 0:  65%|█████████▋     | 155/240 [00:00<00:00, 160.47it/s]
# Validation DataLoader 0:  65%|█████████▊     | 156/240 [00:00<00:00, 160.45it/s]
# Validation DataLoader 0:  65%|█████████▊     | 157/240 [00:00<00:00, 160.45it/s]
# Validation DataLoader 0:  66%|█████████▉     | 158/240 [00:00<00:00, 160.47it/s]
# Validation DataLoader 0:  66%|█████████▉     | 159/240 [00:00<00:00, 160.49it/s]
# Validation DataLoader 0:  67%|██████████     | 160/240 [00:00<00:00, 160.47it/s]
# Validation DataLoader 0:  67%|██████████     | 161/240 [00:01<00:00, 160.46it/s]
# Validation DataLoader 0:  68%|██████████▏    | 162/240 [00:01<00:00, 160.38it/s]
# Validation DataLoader 0:  68%|██████████▏    | 163/240 [00:01<00:00, 160.43it/s]
# Validation DataLoader 0:  68%|██████████▎    | 164/240 [00:01<00:00, 160.50it/s]
# Validation DataLoader 0:  69%|██████████▎    | 165/240 [00:01<00:00, 160.58it/s]
# Validation DataLoader 0:  69%|██████████▍    | 166/240 [00:01<00:00, 160.71it/s]
# Validation DataLoader 0:  70%|██████████▍    | 167/240 [00:01<00:00, 160.70it/s]
# Validation DataLoader 0:  70%|██████████▌    | 168/240 [00:01<00:00, 160.69it/s]
# Validation DataLoader 0:  70%|██████████▌    | 169/240 [00
/s]
# Validation DataLoader 0:  62%|█████████▍     | 150/240 [00:00<00:00, 155.47it/s]
# Validation DataLoader 0:  63%|█████████▍     | 151/240 [00:00<00:00, 155.48it/s]
# Validation DataLoader 0:  63%|█████████▌     | 152/240 [00:00<00:00, 155.53it/s]
# Validation DataLoader 0:  64%|█████████▌     | 153/240 [00:00<00:00, 155.47it/s]
# Validation DataLoader 0:  64%|█████████▋     | 154/240 [00:00<00:00, 155.45it/s]
# Validation DataLoader 0:  65%|█████████▋     | 155/240 [00:00<00:00, 155.42it/s]
# Validation DataLoader 0:  65%|█████████▊     | 156/240 [00:01<00:00, 155.47it/s]
# Validation DataLoader 0:  65%|█████████▊     | 157/240 [00:01<00:00, 155.35it/s]
# Validation DataLoader 0:  66%|█████████▉     | 158/240 [00:01<00:00, 155.36it/s]
# Validation DataLoader 0:  66%|█████████▉     | 159/240 [00:01<00:00, 155.32it/s]
# Validation DataLoader 0:  67%|██████████     | 160/240 [00:01<00:00, 155.11it/s]
# Validation DataLoader 0:  67%|██████████     | 161/240 [00:01<00:00, 155.12it/s]
# Validation DataLoader 0:  68%|██████████▏    | 162/240 [00:01<00:00, 155.06it/s]
# Validation DataLoader 0:  68%|██████████▏    | 163/240 [00:01<00:00, 155.01it/s]
# Validation DataLoader 0:  68%|██████████▎    | 164/240 [00:01<00:00, 155.07it/s]
# Validation DataLoader 0:  69%|██████████▎    | 165/240 [00:01<00:00, 154.94it/s]
# Validation DataLoader 0:  69%|██████████▍    | 166/240 [00:01<00:00, 154.97it/s]
# Validation DataLoader 0:  70%|██████████▍    | 167/240 [00:01<00:00, 154.95it/s]
# Validation DataLoader 0:  70%|██████████▌    | 168/240 [00:01<00:00, 154.96it/s]
# Validation DataLoader 0:  70%|██████████▌    | 169/240 [00:01<00:00, 154.91it/s]
# Validation DataLoader 0:  71%|██████████▋    | 170/240 [00:01<00:00, 154.83it/s]
# Validation DataLoader 0:  71%|██████████▋    | 171/240 [00:01<00:00, 154.77it/s]
# Validation DataLoader 0:  72%|██████████▊    | 172/240 [00:01<00:00, 154.80it/s]
# Validation DataLoader 0:  72%|██████████▊    | 173/240 [00:01<00:00, 154.76it/s]
# Validation DataLoader 0:  72%|██████████▉    | 174/240 [00:01<00:00, 154.76it/s]
# Validation DataLoader 0:  73%|██████████▉    | 175/240 [00:01<00:00, 154.66it/s]
# Validation DataLoader 0:  73%|███████████    | 176/240 [00:01<00:00, 154.66it/s]
# Validation DataLoader 0:  74%|███████████    | 177/240 [00:01<00:00, 154.69it/s]
# Validation DataLoader 0:  74%|███████████▏   | 178/240 [00:01<00:00, 154.67it/s]
# Validation DataLoader 0:  75%|███████████▏   | 179/240 [00:01<00:00, 154.65it/s]
# Validation DataLoader 0:  75%|███████████▎   | 180/240 [00:01<00:00, 154.51it/s]
# Validation DataLoader 0:  75%|███████████▎   | 181/240 [00:01<00:00, 154.54it/s]
# Validation DataLoader 0:  76%|███████████▍   | 182/240 [00:01<00:00, 154.59it/s]
# Validation DataLoader 0:  76%|███████████▍   | 183/240 [00:01<00:00, 154.57it/s]
# Validation DataLoader 0:  77%|███████████▌   | 184/240 [00:01<00:00, 154.58it/s]
# Validation DataLoader 0:  77%|███████████▌   | 185/240 [00:01<00:00, 154.49it/s]
# Validation DataLoader 0:  78%|███████████▋   | 186/240 [00:01<00:00, 154.54it/s]
# Validation DataLoader 0:  78%|███████████▋   | 187/240 [00:01<00:00, 154.50it/s]
# Validation DataLoader 0:  78%|███████████▊   | 188/240 [00:01<00:00, 154.52it/s]
# Validation DataLoader 0:  79%|███████████▊   | 189/240 [00:01<00:00, 154.51it/s]
# Validation DataLoader 0:  79%|███████████▉   | 190/240 [00:01<00:00, 154.59it/s]
# Validation DataLoader 0:  80%|███████████▉   | 191/240 [00:01<00:00, 154.57it/s]
# Validation DataLoader 0:  80%|████████████   | 192/240 [00:01<00:00, 154.55it/s]
# Validation DataLoader 0:  80%|████████████   | 193/240 [00:01<00:00, 154.54it/s]
# Validation DataLoader 0:  81%|████████████▏  | 194/240 [00:01<00:00, 154.57it/s]
# Validation DataLoader 0:  81%|████████████▏  | 195/240 [00:01<00:00, 154.51it/s]
# Validation DataLoader 0:  82%|████████████▎  | 196/240 [00:01<00:00, 154.59it/s]
# Validation DataLoader 0:  82%|████████████▎  | 197/240 [00:01<00:00, 154.61it/s]
# Validation DataLoader 0:  82%|████████████▍  | 198/240 [00:01<00:00, 154.56it/s]
# Validation DataLoader 0:  83%|████████████▍  | 199/240 [00:01<00:00, 154.64it/s]
# Validation DataLoader 0:  83%|████████████▌  | 200/240 [00:01<00:00, 154.69it/s]
# Validation DataLoader 0:  84%|████████████▌  | 201/240 [00:01<00:00, 154.68it/s]
# Validation DataLoader 0:  84%|████████████▋  | 202/240 [00:01<00:00, 154.77it/s]
# Validation DataLoader 0:  85%|████████████▋  | 203/240 [00:01<00:00, 154.77it/s]
# Validation DataLoader 0:  85%|████████████▊  | 204/240 [00:01<00:00, 154.81it/s]
# Validation DataLoader 0:  85%|████████████▊  | 205/240 [00:01<00:00, 154.79it/s]
# Validation DataLoader 0:  86%|████████████▉  | 206/240 [00:01<00:00, 154.72it/s]
# Validation DataLoader 0:  86%|████████████▉  | 207/240 [00:01<00:00, 154.71it/s]
# Validation DataLoader 0:  87%|█████████████  | 208/240 [00:01<00:00, 154.68it/s]
# Validation DataLoader 0:  87%|█████████████  | 209/240 [00:01<00:00, 154.69it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 210/240 [00:01<00:00, 154.70it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 211/240 [00:01<00:00, 154.58it/s]
# Validation DataLoader 0:  88%|█████████████▎ | 212/240 [00:01<00:00, 154.59it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 213/240 [00:01<00:00, 154.50it/s]
# Validation DataLoader 0:  89%|█████████████▍ | 214/240 [00:01<00:00, 154.56it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 215/240 [00:01<00:00, 154.65it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 216/240 [00:01<00:00, 154.56it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 217/240 [00:01<00:00, 154.58it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 218/240 [00:01<00:00, 154.56it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 219/240 [00:01<00:00, 154.61it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 220/240 [00:01<00:00, 154.63it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 221/240 [00:01<00:00, 154.55it/s]
# Validation DataLoader 0:  92%|█████████████▉ | 222/240 [00:01<00:00, 154.60it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 223/240 [00:01<00:00, 154.62it/s]
# Validation DataLoader 0:  93%|██████████████ | 224/240 [00:01<00:00, 154.62it/s]
# Validation DataLoader 0:  94%|██████████████ | 225/240 [00:01<00:00, 154.63it/s]
# Validation DataLoader 0:  94%|██████████████▏| 226/240 [00:01<00:00, 154.53it/s]
# Validation DataLoader 0:  95%|██████████████▏| 227/240 [00:01<00:00, 154.61it/s]
# Validation DataLoader 0:  95%|██████████████▎| 228/240 [00:01<00:00, 154.59it/s]
# Validation DataLoader 0:  95%|██████████████▎| 229/240 [00:01<00:00, 154.56it/s]
# Validation DataLoader 0:  96%|██████████████▍| 230/240 [00:01<00:00, 154.61it/s]
# Validation DataLoader 0:  96%|██████████████▍| 231/240 [00:01<00:00, 154.56it/s]
# Validation DataLoader 0:  97%|██████████████▌| 232/240 [00:01<00:00, 154.57it/s]
# Validation DataLoader 0:  97%|██████████████▌| 233/240 [00:01<00:00, 154.66it/s]
# Validation DataLoader 0:  98%|██████████████▋| 234/240 [00:01<00:00, 154.68it/s]
# Validation DataLoader 0:  98%|██████████████▋| 235/240 [00:01<00:00, 154.69it/s]
# Validation DataLoader 0:  98%|██████████████▊| 236/240 [00:01<00:00, 154.60it/s]
# Validation DataLoader 0:  99%|██████████████▊| 237/240 [00:01<00:00, 154.67it/s]
# Validation DataLoader 0:  99%|██████████████▉| 238/240 [00:01<00:00, 154.68it/s]
# Validation DataLoader 0: 100%|██████████████▉| 239/240 [00:01<00:00, 154.60it/s]
# Validation DataLoader 0: 100%|███████████████| 240/240 [00:01<00:00, 154.61it/s]Val-Acc=13.925749778747559
#
# Epoch 2: 100%|█| 960/960 [00:09<00:00, 97.99it/s, v_num=0, val/loss=0.535, val/a
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                       | 0/240 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                          | 0/240 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                 | 1/240 [00:00<00:01, 192.61it/s]
# Validation DataLoader 0:   1%|▏                | 2/240 [00:00<00:01, 174.84it/s]
# Validation DataLoader 0:   1%|▏                | 3/240 [00:00<00:01, 167.88it/s]
# Validation DataLoader 0:   2%|▎                | 4/240 [00:00<00:01, 163.89it/s]
# Validation DataLoader 0:   2%|▎                | 5/240 [00:00<00:01, 158.20it/s]
# Validation DataLoader 0:   2%|▍                | 6/240 [00:00<00:01, 156.89it/s]
# Validation DataLoader 0:   3%|▍                | 7/240 [00:00<00:01, 156.20it/s]
# Validation DataLoader 0:   3%|▌                | 8/240 [00:00<00:01, 158.28it/s]
# Validation DataLoader 0:   4%|▋                | 9/240 [00:00<00:01, 155.04it/s]
# Validation DataLoader 0:   4%|▋               | 10/240 [00:00<00:01, 155.36it/s]
# Validation DataLoader 0:   5%|▋               | 11/240 [00:00<00:01, 154.31it/s]
# Validation DataLoader 0:   5%|▊               | 12/240 [00:00<00:01, 153.00it/s]
# Validation DataLoader 0:   5%|▊               | 13/240 [00:00<00:01, 153.38it/s]
# Validation DataLoader 0:   6%|▉               | 14/240 [00:00<00:01, 154.03it/s]
# Validation DataLoader 0:   6%|█               | 15/240 [00:00<00:01, 153.77it/s]
# Validation DataLoader 0:   7%|█               | 16/240 [00:00<00:01, 153.42it/s]
# Validation DataLoader 0:   7%|█▏              | 17/240 [00:00<00:01, 153.08it/s]
# Validation DataLoader 0:   8%|█▏              | 18/240 [00:00<00:01, 153.57it/s]
# Validation DataLoader 0:   8%|█▎              | 19/240 [00:00<00:01, 154.27it/s]
# Validation DataLoader 0:   8%|█▎              | 20/240 [00:00<00:01, 153.66it/s]
# Validation DataLoader 0:   9%|█▍              | 21/240 [00:00<00:01, 153.62it/s]
# Validation DataLoader 0:   9%|█▍              | 22/240 [00:00<00:01, 153.38it/s]
# Validation DataLoader 0:  10%|█▌              | 23/240 [00:00<00:01, 153.81it/s]
# Validation DataLoader 0:  10%|█▌              | 24/240 [00:00<00:01, 153.11it/s]
# Validation DataLoader 0:  10%|█▋              | 25/240 [00:00<00:01, 152.84it/s]
# Validation DataLoader 0:  11%|█▋              | 26/240 [00:00<00:01, 153.28it/s]
# Validation DataLoader 0:  11%|█▊              | 27/240 [00:00<00:01, 153.32it/s]
# Validation DataLoader 0:  12%|█▊              | 28/240 [00:00<00:01, 153.27it/s]
# Validation DataLoader 0:  12%|█▉              | 29/240 [00:00<00:01, 153.09it/s]
# Validation DataLoader 0:  12%|██              | 30/240 [00:00<00:01, 152.35it/s]
# Validation DataLoader 0:  13%|██              | 31/240 [00:00<00:01, 152.76it/s]
# Validation DataLoader 0:  13%|██▏             | 32/240 [00:00<00:01, 153.17it/s]
# Validation DataLoader 0:  14%|██▏             | 33/240 [00:00<00:01, 152.84it/s]
# Validation DataLoader 0:  14%|██▎             | 34/240 [00:00<00:01, 152.36it/s]
# Validation DataLoader 0:  15%|██▎             | 35/240 [00:00<00:01, 152.24it/s]
# Validation DataLoader 0:  15%|██▍             | 36/240 [00:00<00:01, 152.26it/s]
# Validation DataLoader 0:  15%|██▍             | 37/240 [00:00<00:01, 152.12it/s]
# Validation DataLoader 0:  16%|██▌             | 38/240 [00:00<00:01, 152.02it/s]
# Validation DataLoader 0:  16%|██▌             | 39/240 [00:00<00:01, 151.94it/s]
# Validation DataLoader 0:  17%|██▋             | 40/240 [00:00<00:01, 151.94it/s]
# Validation DataLoader 0:  17%|██▋             | 41/240 [00:00<00:01, 152.00it/s]
# Validation DataLoader 0:  18%|██▊             | 42/240 [00:00<00:01, 152.10it/s]
# Validation DataLoader 0:  18%|██▊             | 43/240 [00:00<00:01, 152.09it/s]
# Validation DataLoader 0:  18%|██▉             | 44/240 [00:00<00:01, 152.18it/s]
# Validation DataLoader 0:  19%|███             | 45/240 [00:00<00:01, 152.03it/s]
# Validation DataLoader 0:  19%|███             | 46/240 [00:00<00:01, 152.04it/s]
# Validation DataLoader 0:  20%|███▏            | 47/240 [00:00<00:01, 151.67it/s]
# Validation DataLoader 0:  20%|███▏            | 48/240 [00:00<00:01, 151.80it/s]
# Validation DataLoader 0:  20%|███▎            | 49/240 [00:00<00:01, 151.67it/s]
# Validation DataLoader 0:  21%|███▎            | 50/240 [00:00<00:01, 151.63it/s]
# Validation DataLoader 0:  21%|███▍            | 51/240 [00:00<00:01, 151.68it/s]
# Validation DataLoader 0:  22%|███▍            | 52/240 [00:00<00:01, 151.97it/s]
# Validation DataLoader 0:  22%|███▌            | 53/240 [00:00<00:01, 151.95it/s]
# Validation DataLoader 0:  22%|███▌            | 54/240 [00:00<00:01, 152.04it/s]
# Validation DataLoader 0:  23%|███▋            | 55/240 [00:00<00:01, 152.06it/s]
# Validation DataLoader 0:  23%|███▋            | 56/240 [00:00<00:01, 151.85it/s]
# Validation DataLoader 0:  24%|███▊            | 57/240 [00:00<00:01, 151.69it/s]
# Validation DataLoader 0:  24%|███▊            | 58/240 [00:00<00:01, 151.68it/s]
# Validation DataLoader 0:  25%|███▉            | 59/240 [00:00<00:01, 151.59it/s]
# Validation DataLoader 0:  25%|████            | 60/240 [00:00<00:01, 151.69it/s]
# Validation DataLoader 0:  25%|████            | 61/240 [00:00<00:01, 151.98it/s]
# Validation DataLoader 0:  26%|████▏           | 62/240 [00:00<00:01, 152.09it/s]
# Validation DataLoader 0:  26%|████▏           | 63/240 [00:00<00:01, 152.12it/s]
# Validation DataLoader 0:  27%|████▎           | 64/240 [00:00<00:01, 152.37it/s]
# Validation DataLoader 0:  27%|████▎           | 65/240 [00:00<00:01, 152.47it/s]
# Validation DataLoader 0:  28%|████▍           | 66/240 [00:00<00:01, 152.57it/s]
# Validation DataLoader 0:  28%|████▍           | 67/240 [00:00<00:01, 152.38it/s]
# Validation DataLoader 0:  28%|████▌           | 68/240 [00:00<00:01, 152.56it/s]
# Validation DataLoader 0:  29%|████▌           | 69/240 [00:00<00:01, 152.80it/s]
# Validation DataLoader 0:  29%|████▋           | 70/240 [00:00<00:01, 152.95it/s]
# Validation DataLoader 0:  30%|████▋           | 71/240 [00:00<00:01, 153.25it/s]
# Validation DataLoader 0:  30%|████▊           | 72/240 [00:00<00:01, 153.34it/s]
# Validation DataLoader 0:  30%|████▊           | 73/240 [00:00<00:01, 153.36it/s]
# Validation DataLoader 0:  31%|████▉           | 74/240 [00:00<00:01, 153.53it/s]
# Validation DataLoader 0:  31%|█████           | 75/240 [00:00<00:01, 153.71it/s]
# Validation DataLoader 0:  32%|█████           | 76/240 [00:00<00:01, 154.02it/s]
# Validation DataLoader 0:  32%|█████▏          | 77/240 [00:00<00:01, 154.21it/s]
# Validation DataLoader 0:  32%|█████▏          | 78/240 [00:00<00:01, 154.33it/s]
# Validation DataLoader 0:  33%|█████▎          | 79/240 [00:00<00:01, 154.61it/s]
# Validation DataLoader 0:  33%|█████▎          | 80/240 [00:00<00:01, 154.77it/s]
# Validation DataLoader 0:  34%|█████▍          | 81/240 [00:00<00:01, 154.87it/s]
# Validation DataLoader 0:  34%|█████▍          | 82/240 [00:00<00:01, 154.82it/s]
# Validation DataLoader 0:  35%|█████▌          | 83/240 [00:00<00:01, 154.81it/s]
# Validation DataLoader 0:  35%|█████▌          | 84/240 [00:00<00:01, 154.22it/s]
# Validation DataLoader 0:  35%|█████▋          | 85/240 [00:00<00:01, 154.26it/s]
# Validation DataLoader 0:  36%|█████▋          | 86/240 [00:00<00:00, 154.43it/s]
# Validation DataLoader 0:  36%|█████▊          | 87/240 [00:00<00:00, 154.62it/s]
# Validation DataLoader 0:  37%|█████▊          | 88/240 [00:00<00:00, 154.69it/s]
# Validation DataLoader 0:  37%|█████▉          | 89/240 [00:00<00:00, 154.56it/s]
# Validation DataLoader 0:  38%|██████          | 90/240 [00:00<00:00, 154.56it/s]
# Validation DataLoader 0:  38%|██████          | 91/240 [00:00<00:00, 154.62it/s]
# Validation DataLoader 0:  38%|██████▏         | 92/240 [00:00<00:00, 154.38it/s]
# ...
# Validation DataLoader 0:  20%|███▏            | 47/240 [00:00<00:01, 167.22it/s]
# Validation DataLoader 0:  20%|███▏            | 48/240 [00:00<00:01, 167.12it/s]
# Validation DataLoader 0:  20%|███▎            | 49/240 [00:00<00:01, 167.07it/s]
# Validation DataLoader 0:  21%|███▎            | 50/240 [00:00<00:01, 167.04it/s]
# Validation DataLoader 0:  21%|███▍            | 51/240 [00:00<00:01, 167.12it/s]
# Validation DataLoader 0:  22%|███▍            | 52/240 [00:00<00:01, 166.95it/s]
# Validation DataLoader 0:  22%|███▌            | 53/240 [00:00<00:01, 166.99it/s]
# Validation DataLoader 0:  22%|███▌            | 54/240 [00:00<00:01, 167.12it/s]
# Validation DataLoader 0:  23%|███▋            | 55/240 [00:00<00:01, 166.84it/s]
# Validation DataLoader 0:  23%|███▋            | 56/240 [00:00<00:01, 166.82it/s]
# Validation DataLoader 0:  24%|███▊            | 57/240 [00:00<00:01, 166.74it/s]
# Validation DataLoader 0:  24%|███▊            | 58/240 [00:00<00:01, 166.53it/s]
# Validation DataLoader 0:  25%|███▉            | 59/240 [00:00<00:01, 166.69it/s]
# Validation DataLoader 0:  25%|████            | 60/240 [00:00<00:01, 166.58it/s]
# Validation DataLoader 0:  25%|████            | 61/240 [00:00<00:01, 166.77it/s]
# Validation DataLoader 0:  26%|████▏           | 62/240 [00:00<00:01, 166.85it/s]
# Validation DataLoader 0:  26%|████▏           | 63/240 [00:00<00:01, 166.70it/s]
# Validation DataLoader 0:  27%|████▎           | 64/240 [00:00<00:01, 166.87it/s]
# Validation DataLoader 0:  27%|████▎           | 65/240 [00:00<00:01, 166.70it/s]
# Validation DataLoader 0:  28%|████▍           | 66/240 [00:00<00:01, 166.58it/s]
# Validation DataLoader 0:  28%|████▍           | 67/240 [00:00<00:01, 166.78it/s]
# Validation DataLoader 0:  28%|████▌           | 68/240 [00:00<00:01, 166.77it/s]
# Validation DataLoader 0:  29%|████▌           | 69/240 [00:00<00:01, 166.68it/s]
# Validation DataLoader 0:  29%|████▋           | 70/240 [00:00<00:01, 166.68it/s]
# Validation DataLoader 0:  30%|████▋           | 71/240 [00:00<00:01, 166.63it/s]
# Validation DataLoader 0:  30%|████▊           | 72/240 [00:00<00:01, 166.39it/s]
# Validation DataLoader 0:  30%|████▊           | 73/240 [00:00<00:01, 166.52it/s]
# Validation DataLoader 0:  31%|████▉           | 74/240 [00:00<00:00, 166.21it/s]
# Validation DataLoader 0:  31%|█████           | 75/240 [00:00<00:00, 166.32it/s]
# Validation DataLoader 0:  32%|█████           | 76/240 [00:00<00:00, 166.20it/s]
# Validation DataLoader 0:  32%|█████▏          | 77/240 [00:00<00:00, 166.07it/s]
# Validation DataLoader 0:  32%|█████▏          | 78/240 [00:00<00:00, 166.28it/s]
# Validation DataLoader 0:  33%|█████▎          | 79/240 [00:00<00:00, 166.24it/s]
# Validation DataLoader 0:  48%|███████▏       | 114/240 [00:00<00:00, 166.48it/s]
# Validation DataLoader 0:  48%|███████▏       | 115/240 [00:00<00:00, 166.41it/s]
# Validation DataLoader 0:  48%|███████▎       | 116/240 [00:00<00:00, 166.33it/s]
# Validation DataLoader 0:  49%|███████▎       | 117/240 [00:00<00:00, 166.41it/s]
# Validation DataLoader 0:  49%|███████▍       | 118/240 [00:00<00:00, 166.35it/s]
# Validation DataLoader 0:  50%|███████▍       | 119/240 [00:00<00:00, 166.33it/s]
# Validation DataLoader 0:  50%|███████▌       | 120/240 [00:00<00:00, 166.32it/s]
# Validation DataLoader 0:  50%|███████▌       | 121/240 [00:00<00:00, 166.20it/s]
# Validation DataLoader 0:  51%|███████▋       | 122/240 [00:00<00:00, 166.31it/s]
# Validation DataLoader 0:  51%|███████▋       | 123/240 [00:00<00:00, 166.26it/s]
# Validation DataLoader 0:  52%|███████▊       | 124/240 [00:00<00:00, 166.16it/s]
# Validation DataLoader 0:  52%|███████▊       | 125/240 [00:00<00:00, 166.15it/s]
# Validation DataLoader 0:  52%|███████▉       | 126/240 [00:00<00:00, 166.26it/s]
# Validation DataLoader 0:  53%|███████▉       | 127/240 [00:00<00:00, 166.26it/s]
# Validation DataLoader 0:  53%|████████       | 128/240 [00:00<00:00, 166.28it/s]
# Validation DataLoader 0:  54%|████████       | 129/240 [00:00<00:00, 166.26it/s]
# Validation DataLoader 0:  54%|████████▏      | 130/240 [00:00<00:00, 166.38it/s]
# Validation DataLoader 0:  55%|████████▏      | 131/240 [00:00<00:00, 166.45it/s]
# Validation DataLoader 0:  55%|████████▎      | 132/240 [00:00<00:00, 166.41it/s]
# Validation DataLoader 0:  55%|████████▎      | 133/240 [00:00<00:00, 166.31it/s]
# Validation DataLoader 0:  56%|████████▍      | 134/240 [00:00<00:00, 166.38it/s]
# Validation DataLoader 0:  56%|████████▍      | 135/240 [00:00<00:00, 166.28it/s]
# Validation DataLoader 0:  57%|████████▌      | 136/240 [00:00<00:00, 166.39it/s]
# Validation DataLoader 0:  57%|████████▌      | 137/240 [00:00<00:00, 166.43it/s]
# Validation DataLoader 0:  57%|████████▋      | 138/240 [00:00<00:00, 166.39it/s]
# Validation DataLoader 0:  58%|████████▋      | 139/240 [00:00<00:00, 166.44it/s]
# Validation DataLoader 0:  58%|████████▊      | 140/240 [00:00<00:00, 166.35it/s]
# Validation DataLoader 0:  59%|████████▊      | 141/240 [00:00<00:00, 166.28it/s]
# Validation DataLoader 0:  59%|████████▉      | 142/240 [00:00<00:00, 166.33it/s]
# Validation DataLoader 0:  60%|████████▉      | 143/240 [00:00<00:00, 166.27it/s]
# Validation DataLoader 0:  60%|█████████      | 144/240 [00:00<00:00, 166.22it/s]
# Validation DataLoader 0:  60%|█████████      | 145/240 [00:00<00:00, 166.32it/s]
# Validation DataLoader 0:  61%|█████████▏     | 146/240 [00:00<00:00, 166.33it/s]
# Validation DataLoader 0:  75%|███████████▎   | 180/240 [00:01<00:00, 166.49it/s]
# Validation DataLoader 0:  75%|███████████▎   | 181/240 [00:01<00:00, 166.48it/s]
# Validation DataLoader 0:  76%|███████████▍   | 182/240 [00:01<00:00, 166.42it/s]
# Validation DataLoader 0:  76%|███████████▍   | 183/240 [00:01<00:00, 166.40it/s]
# Validation DataLoader 0:  77%|███████████▌   | 184/240 [00:01<00:00, 166.33it/s]
# Validation DataLoader 0:  77%|███████████▌   | 185/240 [00:01<00:00, 166.28it/s]
# Validation DataLoader 0:  78%|███████████▋   | 186/240 [00:01<00:00, 166.28it/s]
# Validation DataLoader 0:  78%|███████████▋   | 187/240 [00:01<00:00, 166.24it/s]
# Validation DataLoader 0:  78%|███████████▊   | 188/240 [00:01<00:00, 166.25it/s]
# Validation DataLoader 0:  79%|███████████▊   | 189/240 [00:01<00:00, 166.29it/s]
# Validation DataLoader 0:  79%|███████████▉   | 190/240 [00:01<00:00, 166.26it/s]
# Validation DataLoader 0:  80%|███████████▉   | 191/240 [00:01<00:00, 166.29it/s]
# Validation DataLoader 0:  80%|████████████   | 192/240 [00:01<00:00, 166.33it/s]
# Validation DataLoader 0:  80%|████████████   | 193/240 [00:01<00:00, 166.21it/s]
# Validation DataLoader 0:  81%|████████████▏  | 194/240 [00:01<00:00, 166.24it/s]
# Validation DataLoader 0:  81%|████████████▏  | 195/240 [00:01<00:00, 166.26it/s]
# Validation DataLoader 0:  82%|████████████▎  | 196/240 [00:01<00:00, 166.25it/s]
# Validation DataLoader 0:  82%|████████████▎  | 197/240 [00:01<00:00, 166.27it/s]
# Validation DataLoader 0:  82%|████████████▍  | 198/240 [00:01<00:00, 166.20it/s]
# Validation DataLoader 0:  83%|████████████▍  | 199/240 [00:01<00:00, 166.30it/s]
# Validation DataLoader 0:  83%|████████████▌  | 200/240 [00:01<00:00, 166.36it/s]
# Validation DataLoader 0:  84%|████████████▌  | 201/240 [00:01<00:00, 166.36it/s]
# Validation DataLoader 0:  84%|████████████▋  | 202/240 [00:01<00:00, 166.42it/s]
# Validation DataLoader 0:  85%|████████████▋  | 203/240 [00:01<00:00, 166.42it/s]
# Validation DataLoader 0:  85%|████████████▊  | 204/240 [00:01<00:00, 166.40it/s]
# Validation DataLoader 0:  85%|████████████▊  | 205/240 [00:01<00:00, 166.34it/s]
# Validation DataLoader 0:  86%|████████████▉  | 206/240 [00:01<00:00, 166.35it/s]
# Validation DataLoader 0:  86%|████████████▉  | 207/240 [00:01<00:00, 166.28it/s]
# Validation DataLoader 0:  87%|█████████████  | 208/240 [00:01<00:00, 166.30it/s]
# Validation DataLoader 0:  87%|█████████████  | 209/240 [00:01<00:00, 166.33it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 210/240 [00:01<00:00, 166.29it/s]
# Validation DataLoader 0:  88%|█████████████▏ | 211/240 [00:01<00:00, 166.30it/s]
# Validation DataLoader 0:  88%|█████████████▎ | 212/240 [00:01<00:00, 166.26it/s]
# Validation DataLoader 0:  89%|█████████████▎ | 213/240 [00:01<00:00, 166.27it/s]
# Validation DataLoader 0:  89%|█████████████▍ | 214/240 [00:01<00:00, 166.27it/s]
# Validation DataLoader 0:  90%|█████████████▍ | 215/240 [00:01<00:00, 166.21it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 216/240 [00:01<00:00, 166.22it/s]
# Validation DataLoader 0:  90%|█████████████▌ | 217/240 [00:01<00:00, 166.31it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 218/240 [00:01<00:00, 166.28it/s]
# Validation DataLoader 0:  91%|█████████████▋ | 219/240 [00:01<00:00, 166.37it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 220/240 [00:01<00:00, 166.38it/s]
# Validation DataLoader 0:  92%|█████████████▊ | 221/240 [00:01<00:00, 166.26it/s]
# Validation DataLoader 0:  92%|█████████████▉ | 222/240 [00:01<00:00, 166.27it/s]
# Validation DataLoader 0:  93%|█████████████▉ | 223/240 [00:01<00:00, 166.24it/s]
# Validation DataLoader 0:  93%|██████████████ | 224/240 [00:01<00:00, 166.19it/s]
# Validation DataLoader 0:  94%|██████████████ | 225/240 [00:01<00:00, 166.24it/s]
# Validation DataLoader 0:  94%|██████████████▏| 226/240 [00:01<00:00, 166.20it/s]
# Validation DataLoader 0:  95%|██████████████▏| 227/240 [00:01<00:00, 166.17it/s]
# Validation DataLoader 0:  95%|██████████████▎| 228/240 [00:01<00:00, 166.20it/s]
# Validation DataLoader 0:  95%|██████████████▎| 229/240 [00:01<00:00, 166.20it/s]
# Validation DataLoader 0:  96%|██████████████▍| 230/240 [00:01<00:00, 166.28it/s]
# Validation DataLoader 0:  96%|██████████████▍| 231/240 [00:01<00:00, 166.35it/s]
# Validation DataLoader 0:  97%|██████████████▌| 232/240 [00:01<00:00, 166.30it/s]
# Validation DataLoader 0:  97%|██████████████▌| 233/240 [00:01<00:00, 166.39it/s]
# Validation DataLoader 0:  98%|██████████████▋| 234/240 [00:01<00:00, 166.37it/s]
# Validation DataLoader 0:  98%|██████████████▋| 235/240 [00:01<00:00, 166.39it/s]
# Validation DataLoader 0:  98%|██████████████▊| 236/240 [00:01<00:00, 166.44it/s]
# Validation DataLoader 0:  99%|██████████████▊| 237/240 [00:01<00:00, 166.40it/s]
# Validation DataLoader 0:  99%|██████████████▉| 238/240 [00:01<00:00, 166.43it/s]
# Validation DataLoader 0: 100%|██████████████▉| 239/240 [00:01<00:00, 166.41it/s]
# Validation DataLoader 0: 100%|███████████████| 240/240 [00:01<00:00, 166.36it/s]Val-Acc=16.430665969848633
#
# Epoch 4: 100%|█| 960/960 [00:12<00:00, 77.63it/s, v_num=0, val/loss=0.525, val/a
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|█| 960/960 [00:12<00:00, 77.57it/s, v_num=0, val/loss=0.525, val/a

# %% [markdown]
# ### Observations
#
# Take a look at TensorBoard to compare the performance of both networks:

# %%
# %load_ext tensorboard
# !/Users/tigrangaplanyan/anaconda3/envs/Homeworks/bin/tensorboard --logdir dropout_logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# TensorFlow installation not found - running with reduced feature set.
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.9.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %% [markdown]
# As you can see, by using Dropout we can see that the Training Loss would increase but the model would perform better on the Validation Set. Like Batch Normalization, Dropout also has different behavior at Train and Test time.
